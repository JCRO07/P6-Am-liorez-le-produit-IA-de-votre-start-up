# %%
from urllib import request
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn import decomposition
from sklearn import preprocessing
sns.set()
# Python program to read 
# json file 
 
import json

# %% [markdown]
# # Données textes

# %% [markdown]
# # Données Lyon

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon1a20 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon1a20 = json_normalize(DataDictLyon1a20['search']['business'] , 'reviews',  max_level=1)
DataLyon1a20
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We'll be careful with the " OLDER" review this...       5
# 1   Everything about this place is great. Low key ...       5
# 2   French food. Good. Table wine was inexpensive,...       5
# 3   It was a misty December night in Place Belleco...       5
# 4   I chose this restaurant after reading the othe...       5
# 5   Hey you're in Lyon so you might as well have s...       3
# 6   Informal and cozy little restaurant specializi...       5
# 7   One of my favorite meals in Lyon! Lyon is appa...       5
# 8   Must visit this place if you're looking for a ...       5
# 9   Amazing Italian food, exceptional service and ...       5
# 10  Such a great dinning experience in Leon. We we...       5
# ...

# %%
DataLyon1a20[DataLyon1a20.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon1a20[DataLyon1a20.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 34  Staff was unbelievably rude - there are plenty...       1
# 46  After 2 weeks in France, we have craving for r...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 21 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon21a40 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon21a40 = json_normalize(DataDictLyon21a40['search']['business'] , 'reviews',  max_level=1)
DataLyon21a40
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   This was our first Lyonnaise bouchon - it seem...       5
# 1   A very quaint Lyonnaise restaurant in the hear...       5
# 2   Eh.\nWas recommended by our hotel concierge an...       2
# 3   The Mère Mounier restaurant is with no doubt o...       5
# 4   My mother and I went to this place and we were...       3
# 5   I was a little harsh on this place. The sausag...       3
# 6   I expected a lot from Mamasan after having rea...       3
# 7   This is a quaint small establishment that offe...       4
# 8   Nothing special, they acted like they could ca...       2
# 9   I am traveling quite frequently to Lyon and I ...       4
# 10  Great place for lunch.  They have a limited me...       5
# ...

# %%
DataLyon21a40[DataLyon21a40.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 2   Eh.\nWas recommended by our hotel concierge an...       2
# 8   Nothing special, they acted like they could ca...       2
# 28  It's been a long time since my last visit. The...       2>

# %%
DataLyon21a40[DataLyon21a40.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 22  If you crave all of the arrogance that can kil...       1
# 23  Why is Asian food so crap in France?  The pork...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 41 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon41a60 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon41a60 = json_normalize(DataDictLyon41a60['search']['business'] , 'reviews',  max_level=1)
DataLyon41a60
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   On a hot afternoon this restaurant was on the ...       4
# 1   Omg this place was amazing and delicious, True...       5
# 2   Simple menu. Food is delicious. I had the salm...       4
# 3   Fabulous and memorable experience! My partner ...       5
# 4   This is the burger house we had originally mea...       4
# 5   These young, up and coming chefs and restauran...       5
# 6   Les Frangins is a must if you are visiting Lyo...       5
# 7   This is one of my favorites in Lyon. I conside...       5
# 8   We had a great time as guests of Nadine and He...       5
# 9   This charming bistro served me the best salad ...       5
# 10  If I closed my eyes I will think I'm in Korea ...       5
# ...

# %%
DataLyon41a60[DataLyon41a60.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 11  The owner was unkind, he made me and my friend...       2
# 14  another choice on restaurant heavy Rue Mercier...       2>

# %%
DataLyon41a60[DataLyon41a60.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 61 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon61a80 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon61a80 = json_normalize(DataDictLyon61a80['search']['business'] , 'reviews',  max_level=1)
DataLyon61a80
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   The food was pretty good. The staff is friendl...       5
# 1   This is probably our favorite Thai in Lyon (ti...       4
# 2   This restaurant is the best, my favorite!! The...       5
# 3   We went into this place with no expectations, ...       4
# 4   Our next stop on our trip was Lyon, France. We...       5
# 5   This is a great little hidden spot on a hidden...       5
# 6   Great ambience. We had a prebooking, so were s...       4
# 7   WARNING: this IS NOT Korean BBQ. This is a sad...       1
# 8   (la version française en bas)\n\nTHIS PLACE IS...       4
# 9   The food there is excellent, the coffee and ju...       5
# 10  This new place is a fabulous Scandanavian café...       4
# ...

# %%
DataLyon61a80[DataLyon61a80.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon61a80[DataLyon61a80.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 7   WARNING: this IS NOT Korean BBQ. This is a sad...       1
# 18  Horrible experience. We came from states and s...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 81 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon81a100 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon81a100 = json_normalize(DataDictLyon81a100['search']['business'] , 'reviews',  max_level=1)
DataLyon81a100
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   The food and service here is absolutely amazin...       5
# 1   (la version française en bas)\n\nI went for lu...       5
# 2   As an optional excursion on my guided tour of ...       4
# 3   Very reasonably priced, well-done classic Fren...       5
# 4   I loved this place. Very authentic Lyon food a...       5
# 5   I recently spent two weeks in Europe visiting ...       5
# 6   Enjoyed a nice meal here that was quite pleasa...       5
# 7   This was the best French Restaurant we dined a...       5
# 8   Amazing! Very friendly staff, healthy, and mos...       5
# 9   Very nice cafe with a good atmosphere, lots of...       4
# 10  Very, very average. I had the mezza which was ...       2
# ...

# %%
DataLyon81a100[DataLyon81a100.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 10  Very, very average. I had the mezza which was ...       2>

# %%
DataLyon81a100[DataLyon81a100.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 101 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon101a120 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon101a120= json_normalize(DataDictLyon101a120['search']['business'] , 'reviews',  max_level=1)
DataLyon101a120
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Greasy as fuck, especially the veggy burger. T...       2
# 1   A local friend recommended this place to us. S...       5
# 2   I had read good things about Les Apothicaires....       4
# 3   Reservation only. Doesn't answer the phone for...       1
# 4   Exactly the kind of hearty meal I longed for w...       5
# 5   An authentic, no frills French restaurant! Thi...       4
# 6   This was the best meal we had in France! I had...       5
# 7   This place let us down.\nThe donuts are greasy...       1
# 8   Under cooked hamburger and limp, soggy fries b...       2
# 9   We had the L'original Fromage and L'original b...       5
# 10  Ok this was quite amazing. I got the Butcher b...       4
# ...

# %%
DataLyon101a120[DataLyon101a120.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 0   Greasy as fuck, especially the veggy burger. T...       2
# 8   Under cooked hamburger and limp, soggy fries b...       2
# 31  Meh. We ordered a la carte and the plat du jou...       2>

# %%
DataLyon101a120[DataLyon101a120.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 3   Reservation only. Doesn't answer the phone for...       1
# 7   This place let us down.\nThe donuts are greasy...       1
# 16  We arrived the day before. I speak French halt...       1
# 33  What a disappointment!!!\nI am in Lyon the gas...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 121 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon121a140 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon121a140= json_normalize(DataDictLyon121a140['search']['business'] , 'reviews',  max_level=1)
DataLyon121a140
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   After living in China for three years, it's wo...       4
# 1   So, so, so delicious. The staff was so nice. W...       5
# 2   Such an excellent restaurant! Amazing service....       5
# 3   Lovely space, lovely staff!\n\nThe SO doesn't ...       4
# 4   Zero complaints. A cute bistro with different ...       5
# 5   This place was a gem that we found in the old ...       5
# 6   You will find rich, buttery, and homestyle lyo...       4
# 7   Fun bouchon in the North East corner of old Ly...       4
# 8   Don't be deceived by the appearance as you pee...       5
# 9   The old city of Lyon certainly has charm. But ...       2
# 10  The best restaurant we visited in Lyon!  Our f...       5
# ...

# %%
DataLyon121a140[DataLyon121a140.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 9  The old city of Lyon certainly has charm. But ...       2>

# %%
DataLyon121a140[DataLyon121a140.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 11  I can't believe I went here based on yelp revi...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 141 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon141a160 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon141a160= json_normalize(DataDictLyon141a160['search']['business'] , 'reviews',  max_level=1)
DataLyon141a160
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   2.5 stars, if I can. Another yelp disappointme...       3
# 1   My wife, daughter, and I ate here for dinner. ...       5
# 2   I was craving a Burger and I came here given t...       3
# 3   My family and I came to Cosy Corner on our fir...       4
# 4   It ain't cheap, but you probably already knew ...       5
# 5   Probably the most anticipated meal of our trip...       2
# 6   We were trying to decide between La Mere Brazi...       3
# 7   As a vegetarian, I did not get my hopes up abo...       2
# 8   My co-worker and I just ate here and it was am...       5
# 9   We heard so many good things about this place....       3
# 10  This was one of the many highlights of our gas...       5
# ...

# %%
DataLyon141a160[DataLyon141a160.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 5  Probably the most anticipated meal of our trip...       2
# 7  As a vegetarian, I did not get my hopes up abo...       2>

# %%
DataLyon141a160[DataLyon141a160.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 161 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon161a180 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon161a180= json_normalize(DataDictLyon161a180['search']['business'] , 'reviews',  max_level=1)
DataLyon161a180
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Delicious homemade almond/pear cake & good cof...       5
# 1   Excellent place for molecular gastronomy  food...       5
# 2   Came here with a big party on a trip. The food...       5
# 3   A new Frite Alors opened up near me! Hooray!\n...       3
# 4   Great Irish pub on my street in Lyon. Sunday n...       4
# 5   Alright pub. They speak English here and I saw...       3
# 6   A nice British Pub in the heart of Lyon. A wid...       4
# 7   Yabio was the very first restaurant that we vi...       4
# 8   Hi\nThis a great place to enjoy great food wit...       5
# 9   The best ever!! Don't even need any effort to ...       5
# 10  After years of research, I finally found the b...       5
# ...

# %%
DataLyon161a180[DataLyon161a180.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon161a180[DataLyon161a180.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 18  You can't serve Asian cuisine and be unable to...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 181 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon181a200 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon181a200= json_normalize(DataDictLyon181a200['search']['business'] , 'reviews',  max_level=1)
DataLyon181a200
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Charming atmosphere.  Great welcoming service ...       5
# 1   Food was fresh. Perfect quantity, unique flavo...       4
# 2   Very nice and cozy place for couples ... too s...       5
# 3   Best pizza in Lyon! Service was great! Bon app...       5
# 4   I was here for dinner on April 27, 2016 and th...       5
# 5   The Fork or Laforchette in French always help ...       5
# 6   Typical friday night strolling with visitors i...       3
# 7   Nice place. Tables outside, seafood stall to b...       5
# 8   Had a quality lunch here. The mussels and the ...       4
# 9   Great place in all different ways!\nThey have ...       5
# 10  Absolutely amazing. Food and wine. The service...       5
# ...

# %%
DataLyon181a200[DataLyon181a200.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 11  I just moved to Lyon and was very excited to s...       2
# 22  This place was so disappointing. Yes, the déco...       2>

# %%
DataLyon181a200[DataLyon181a200.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 201 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon201a220 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon201a220 = json_normalize(DataDictLyon201a220['search']['business'] , 'reviews',  max_level=1)
DataLyon201a220
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I was a little nervous reading some of the oth...       5
# 1   I really wanted to love this! At the end of th...       3
# 2   Ate here last time when I was here in Lyon 2 y...       4
# 3   Amazing restaurant! The menu was on the wall a...       5
# 4   I'm sad to report that we were unable to try t...       3
# 5   This restaurant specializes in "panozzos."\nPa...       5
# 6   Hands down the best meal we've had--or will ha...       5
# 7   A bouchon is a Lyonnaise institution serving t...       4
# 8   Incredible Lyonnaise food!  The chicken with m...       5
# 9   The menu was small but everything we ordered w...       5
# 10  Not that great. The cold cuts plater was a bit...       1
# ...

# %%
DataLyon201a220[DataLyon201a220.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon201a220[DataLyon201a220.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 10  Not that great. The cold cuts plater was a bit...       1
# 20  Said it closes at 11:30 but it was already clo...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 221 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon221a240 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon221a240 = json_normalize(DataDictLyon221a240['search']['business'] , 'reviews',  max_level=1)
DataLyon221a240
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   You could say that the main draw of Autour d'u...       5
# 1   Delicious and accommodating to our gluten-free...       5
# 2   A nice surprise lunch on a saturday for under ...       4
# 3   Loved this restaurant....found it on our last ...       5
# 4   There are three things that we look for in a p...       4
# 5   Delicious! fresh food, and great service. We h...       5
# 6   What a find!!! Steak and lobster... that's it....       5
# 7   This is such a great place to get together wit...       5
# 8   WiFi and chicken wings. What more could you as...       4
# 9   Last night we went here for dinner, it was fab...       5
# 10  We walked past Le Desjeuneur several times and...       5
# ...

# %%
DataLyon221a240[DataLyon221a240.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon221a240[DataLyon221a240.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 16  Expensive, too expensive place for the small p...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 241 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon241a260 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon241a260 = json_normalize(DataDictLyon241a260['search']['business'] , 'reviews',  max_level=1)
DataLyon241a260
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Pardon my review in English but if you go to s...       4
# 1   The place has an artistic touch to it and the ...       3
# 2   Average place. The decor is kinda cool but the...       3
# 3   Had the brunch on Sunday and it was quite disa...       2
# 4   We arrived in Lyon shortly before lunch and af...       4
# 5   Restaurant is located on a pretty busy tourist...       3
# 6   Very Lyonnais\nFrom the minute you step in unt...       4
# 7   Le Sud is by the Rhône river and next to the l...       4
# 8   My first visit ever to a Paul Bocuse restauran...       4
# 9   On the recommendation of our cruise director, ...       5
# 10  Loved this restaurant. Perfect atmosphere and ...       5
# ...

# %%
DataLyon241a260[DataLyon241a260.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  Had the brunch on Sunday and it was quite disa...       2>

# %%
DataLyon241a260[DataLyon241a260.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 261 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon261a280 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon261a280 = json_normalize(DataDictLyon261a280['search']['business'] , 'reviews',  max_level=1)
DataLyon261a280
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I'm torn between 3 and  4 stars.  I like this ...       3
# 1   Great staff, friendly place but only one bathr...       4
# 2   Mexicans can finally scratch the itch when the...       4
# 3   What a gem and cute little cafe.   On top of t...       5
# 4   The owner is absolutely lovely and personable....       5
# 5   It was getting a little colder in Lyon by now ...       3
# 6   Now there will be a review in English!  What a...       5
# 7   Food here is just fantastic, although they don...       5
# 8   Excellent 2 star Michelin meal. Reminds me of ...       5
# 9   One of the best meals I've ever had for this 2...       5
# 10  Walking into the store the vibe is way fancier...       5
# ...

# %%
DataLyon261a280[DataLyon261a280.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 18  I'm only giving them 2 stars instead of 1 beca...       2>

# %%
DataLyon261a280[DataLyon261a280.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 281 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon281a300 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon281a300 = json_normalize(DataDictLyon281a300['search']['business'] , 'reviews',  max_level=1)
DataLyon281a300
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   This very cute bouchon provided the perfect am...       5
# 1   My wife and I visited the Café du Soleil on ou...       5
# 2   This was a lovely restaurant, small, cozy and ...       4
# 3   If you are looking for some traditional  "crêp...       5
# 4   Wonderful creperie away from the tourist mecca...       5
# 5   Fantastic interior - rustic and cute with nice...       5
# 6   Location for Pimprenelle can't be beat. Howeve...       3
# 7   What a joke!  This place is the definition of ...       1
# 8   Good funky atmosphere, slow and friendly servi...       4
# 9   Formidable! :) I wish I were here, right now. ...       5
# 10  Great place to grab a bite and drink. There's ...       4
# ...

# %%
DataLyon281a300[DataLyon281a300.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon281a300[DataLyon281a300.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 7  What a joke!  This place is the definition of ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 301 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon301a320 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon301a320 = json_normalize(DataDictLyon301a320['search']['business'] , 'reviews',  max_level=1)
DataLyon301a320
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Great lunch spot near the silk museum. Can't r...       4
# 1   My new favorite restaurant in Lyon. It calls i...       5
# 2   Great little French restaurant with a clock ob...       4
# 3   Oh hey first English review! We were pointed t...       5
# 4   Hooray for a fresh salad bar down the street f...       4
# 5   The food is authentic. The place is clean and ...       5
# 6   Really great Thai salad and lotus tea. Strong ...       5
# 7   Hip Wine bar. Great music. Knowledgeable staff...       5
# 8   I can't believe this place is just around the ...       4
# 9   Nice Chinese food. We haven't tried the Szechu...       4
# 10  The place itself is very interesting  . They g...       5
# ...

# %%
DataLyon301a320[DataLyon301a320.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon301a320[DataLyon301a320.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 321 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon321a340 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon321a340 = json_normalize(DataDictLyon321a340['search']['business'] , 'reviews',  max_level=1)
DataLyon321a340
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We had Tom Yan Kum soup and beef/sea food gree...       4
# 1   Sorry for putting a damper on all the enthusia...       3
# 2   It's good. Good flavors, though nothing specta...       4
# 3   A warm respite on a cold, rainy morning. Good ...       4
# 4   A simple restaurant at the first sight, the mo...       5
# 5   I can't believe I got dragged into a Chinese r...       5
# 6   Small cozy Sichuan eatery with some rare found...       4
# 7   Dinner tonight at Carnet Gourmand was a great ...       4
# 8   Simply the best beef Tartar you will probably ...       5
# 9   Great authentic Mexican!   Super low key spot,...       5
# 10  Our youngest son wanted taco's at any price. S...       4
# ...

# %%
DataLyon321a340[DataLyon321a340.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon321a340[DataLyon321a340.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 341 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon341a360 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon341a360 = json_normalize(DataDictLyon341a360['search']['business'] , 'reviews',  max_level=1)
DataLyon341a360
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Excellent place for a dinner with your " copin...       5
# 1   I wanted to be impressed but sadly the experie...       2
# 2   We completely stumbled into this place on a bu...       5
# 3   Stylish without being intimidating, with an up...       5
# 4   Says it is open except there is a sign on the ...       1
# 5   There's only one way to correctly experience t...       5
# 6   I've had quite a few Philly in various places ...       5
# 7   Its THE place to be. A lil noisy on Saturdays ...       5
# 8   It's a nice place to get a beer. The pizza was...       4
# 9   Loved this hotel. Took my Boyfriend here for a...       5
# 10  Bugs crawling in my breakfast delivered to roo...       1
# ...

# %%
DataLyon341a360[DataLyon341a360.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 1   I wanted to be impressed but sadly the experie...       2
# 15  The food is very good. The service is performe...       2>

# %%
DataLyon341a360[DataLyon341a360.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 4   Says it is open except there is a sign on the ...       1
# 10  Bugs crawling in my breakfast delivered to roo...       1
# 11  Very bad customer service. We have booked one ...       1
# 17  The first half of the dinner was a Michelin 1 ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 361 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon361a380 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon361a380 = json_normalize(DataDictLyon361a380['search']['business'] , 'reviews',  max_level=1)
DataLyon361a380
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Great views, service and burgers were very jui...       4
# 1   My friends and I needed a place for lunch. Joh...       5
# 2   Look forward to seeing you again around July 2...       5
# 3   I've been here twice, both times for birthday ...       5
# 4   For weeks I've been wanting to try Okawali, en...       4
# 5   I LOVE PANI JO!! I recently had the pleasure o...       5
# 6   Pretty good vegetarian pizza. \n\nI had the Or...       3
# 7   Pizza made to order with some good options for...       3
# 8   Waitress was very attentive. Many choices and ...       4
# 9   GREAT pizza! Hearty portions, friendly staff, ...       5
# 10  Typical Thai food. Good service and hot food. ...       4
# ...

# %%
DataLyon361a380[DataLyon361a380.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 29  Decent enough meal. Certainly get your money's...       2>

# %%
DataLyon361a380[DataLyon361a380.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 22  Was very excited to eat here. Food looked deli...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 381 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon381a400 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon381a400 = json_normalize(DataDictLyon381a400['search']['business'] , 'reviews',  max_level=1)
DataLyon381a400
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   The Good:\n  :: local business!\n  :: service ...       5
# 1   Simply amazing. Every dish was spectacular- we...       5
# 2   This is the best Vietnamese food We've ever ha...       5
# 3   Excellent meal and service.  Our waiter was ve...       5
# 4   Stumbled across this place while looking for T...       4
# 5   Awesome thai food outside of Southern Californ...       5
# 6   Looking for a place to go during our brief Chr...       5
# 7   After two years, we are back in lovely Lyon ag...       5
# 8   excellent food and service. picked the "relaxe...       5
# 9   I'm always looking for delicious Chinese food ...       5
# 10  Excellent fresh sushi in a casual non pretenti...       5
# ...

# %%
DataLyon381a400[DataLyon381a400.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon381a400[DataLyon381a400.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 401 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon401a420 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon401a420 = json_normalize(DataDictLyon401a420['search']['business'] , 'reviews',  max_level=1)
DataLyon401a420
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   This is one of the restaurants in the food hal...       3
# 1   Great spot to get lunch at Les Halles de Lyon....       5
# 2   Best meal of our trip, fantastic escargot in a...       5
# 3   Went back here again on my last night in Lyon....       5
# 4   It's a good *fast food* option for Asian.  Kee...       4
# 5   Absolutely authentic and delicious seschuan st...       5
# 6   Found this spot for lunch after walking by. De...       5
# 7   It was our first time in Lyon, France and we h...       3
# 8   Never had the shrimps that big. They are fresh...       5
# 9   Great oyster seafood restaurant inside the foo...       4
# 10  After being in France for a week, we were look...       5
# ...

# %%
DataLyon401a420[DataLyon401a420.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon401a420[DataLyon401a420.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 421 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon421a440 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon421a440= json_normalize(DataDictLyon421a440['search']['business'] , 'reviews',  max_level=1)
DataLyon421a440
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Delicious food prepared well! Was pleasantly s...       5
# 1   Great experience. Recommended from a foodie fr...       5
# 2   I'm very glad to know of this place from the h...       5
# 3                 Best pizza I've had so far in Lyon.       4
# 4   Great place for pizza , there are many places ...       4
# 5   Pretty poor pizza (I ordered a margherita pizz...       1
# 6   A lovely family business, all home made and fr...       5
# 7   We went for our first dinner in Lyon. I would ...       4
# 8   An amazingly mild and clement day turned into ...       4
# 9   A wonderful place to eat. The service was grea...       4
# 10  Great place to get some Lyonnaise cuisine.  Th...       5
# ...

# %%
DataLyon421a440[DataLyon421a440.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 15  Came on a recommendation from a co-worker.  Ve...       2
# 19  The place is run by a mother/son duo. The mom ...       2>

# %%
DataLyon421a440[DataLyon421a440.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 5  Pretty poor pizza (I ordered a margherita pizz...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 441 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon441a460 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon441a460 = json_normalize(DataDictLyon441a460['search']['business'] , 'reviews',  max_level=1)
DataLyon441a460
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I ordered a vegetarian burrito, it was excelle...       5
# 1   This is a beautifully decorated restaurant wit...       5
# 2   We loved this place! It was our first find in ...       5
# 3   Mouth watering food! Good service, Nice deco!!...       4
# 4   We came here with family that lives in Lyon. T...       5
# 5   We had been planning to go here for ages and t...       4
# 6   Great crepes here. I am celiac so the galettes...       5
# 7   I am not a urban food/fast food guy\nI was bro...       5
# 8   This little restaurant is a gem of a place.  T...       5
# 9   After our reservation next door couldn't accom...       4
# 10  Really good Nepalese good with friendly servic...       4
# ...

# %%
DataLyon441a460[DataLyon441a460.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon441a460[DataLyon441a460.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 461 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon461a480 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon461a480 = json_normalize(DataDictLyon461a480['search']['business'] , 'reviews',  max_level=1)
DataLyon461a480
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   A bit hidden behind part dieu you find this sm...       4
# 1   One of my favourite sushi restaurants in Lyon....       4
# 2   If I could give this place zero stars I would....       1
# 3             Tourist trap with mediocre food. Avoid!       1
# 4   Great atmosphere, very laid-back environment. ...       5
# 5   When your S.O. is vegan, and you're in Lyon, t...       5
# 6   We came in for a late lunch/ dinner combinatio...       5
# 7   Not many vegan hideouts in Lyon, but this one ...       5
# 8   Great cakes, drinks and of course kitties.\n\n...       5
# 9   Let me start this review by saying that I have...       3
# 10  Thank you for a pleasant morning of tea and sh...       5
# ...

# %%
DataLyon461a480[DataLyon461a480.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon461a480[DataLyon461a480.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  If I could give this place zero stars I would....       1
# 3            Tourist trap with mediocre food. Avoid!       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 481 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon481a500 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon481a500 = json_normalize(DataDictLyon481a500['search']['business'] , 'reviews',  max_level=1)
DataLyon481a500
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Came here due to it's proximity to the nearby ...       3
# 1   After an early run by the river today, I reser...       5
# 2   I just had two entrees here, the gratinee l'on...       2
# 3   Visited this cafe with a couple of Italian cow...       5
# 4   This cute little Alsacian cafe/restaurant enco...       4
# 5   Had an awesome lunch here - food was great and...       5
# 6   This was my first time eating at a French rest...       5
# 7   I don't usually like fusion food because it is...       5
# 8   3 course japoniase French cushion dinner.  Not...       3
# 9   The place is great if you want to eat outside ...       4
# 10  Horrible! Stay away!\n45 min wait for a burger...       1
# ...

# %%
DataLyon481a500[DataLyon481a500.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  I just had two entrees here, the gratinee l'on...       2>

# %%
DataLyon481a500[DataLyon481a500.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 10  Horrible! Stay away!\n45 min wait for a burger...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 501 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon501a520 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon501a520 = json_normalize(DataDictLyon501a520['search']['business'] , 'reviews',  max_level=1)
DataLyon501a520
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Very friendly service and nice outside seating...       4
# 1   This was our first stop in Lyon and we loved i...       5
# 2   Great food at a great price! Had some of the b...       5
# 3   We came here because the gourmand menu for 48 ...       4
# 4   My wife and I went here for lunch, it was a gr...       4
# 5   We visited today for lunch and we definitely e...       3
# 6   This place did well on TripAdvisor, but this s...       1
# 7   All vegan, all delicious. Finally a vegan rest...       5
# 8   LOVE. THIS. PLACE.\n\nI love the pizza. I love...       5
# 9   They say that the west of France houses all th...       5
# 10  The first time we ate Les Bobos pizza, we looo...       4
# ...

# %%
DataLyon501a520[DataLyon501a520.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon501a520[DataLyon501a520.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 6  This place did well on TripAdvisor, but this s...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 521 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon521a540 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon521a540 = json_normalize(DataDictLyon521a540['search']['business'] , 'reviews',  max_level=1)
DataLyon521a540
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   May 11, 2017 Thursday - 8:15 PM for dinner\n4 ...       5
# 1   This restaurant seems to be a popular restaura...       3
# 2   This place was the very first burger restauran...       5
# 3   I really enjoyed my meal and the service and t...       5
# 4   We happened to be out walking and found this p...       4
# 5   I don't have enough good things to say about t...       5
# 6   Okay food, terrible service. We waited two hou...       1
# 7   At a tapas place you never can be sure how big...       5
# 8   Fantastic food!!! Melon salad was delicate and...       5
# 9   LOVE this little restaurant in Vieux Lyon.   T...       5
# 10  Recommended by friends we went to this lovely ...       3
# ...

# %%
DataLyon521a540[DataLyon521a540.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon521a540[DataLyon521a540.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 6  Okay food, terrible service. We waited two hou...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 541 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon541a560 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon541a560 = json_normalize(DataDictLyon541a560['search']['business'] , 'reviews',  max_level=1)
DataLyon541a560
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I am sorry to say that Les Burgers de Papa has...       2
# 1   Not sure why we stopped for fast food chicken....       3
# 2   Who doesn't love rotisserie chicken?\nDeliciou...       5
# 3   Lyon never disappoints me when it comes to foo...       5
# 4   We went here for our first dinner in Lyon as w...       3
# 5   Our group stumbled upon this restaurant and we...       5
# 6   What a great find! This seemed to be the only ...       4
# 7   Refined French-Japanese fusion cuisine in an e...       5
# 8   Place is to be found at the side streets of Pe...       4
# 9   The food was nothing to write home about. Howe...       4
# 10  The service from the 3 staff (waiter, chef and...       4
# ...

# %%
DataLyon541a560[DataLyon541a560.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 0  I am sorry to say that Les Burgers de Papa has...       2>

# %%
DataLyon541a560[DataLyon541a560.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 561 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon561a580 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon561a580 = json_normalize(DataDictLyon561a580['search']['business'] , 'reviews',  max_level=1)
DataLyon561a580
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Awesome location, great pizza. Salad Cesar was...       4
# 1   The best pizza I have had in a long time and g...       5
# 2   Ended up here not by choice, but out of  conve...       2
# 3   Uhm, I am divided. Food at dinner was not bad ...       3
# 4   Tried to have dinner here last night and was v...       1
# 5   I really, really, really wanted to like this p...       2
# 6   Very cozy restaurant with a vibrant, original ...       4
# 7   I do not understand the hype about this place ...       2
# 8   Fast casual Vietnamese food.   Good seating an...       3
# 9   Je ne pensais pas mettre une si bonne apprécia...       5
# 10  Love this little place. Great tasty asian food...       4
# ...

# %%
DataLyon561a580[DataLyon561a580.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 2   Ended up here not by choice, but out of  conve...       2
# 5   I really, really, really wanted to like this p...       2
# 7   I do not understand the hype about this place ...       2
# 15  This place looks very nice but leaves a lot to...       2>

# %%
DataLyon561a580[DataLyon561a580.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 4   Tried to have dinner here last night and was v...       1
# 21  Our server moved past service-oriented directl...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 581 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon581a600 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon581a600 = json_normalize(DataDictLyon581a600['search']['business'] , 'reviews',  max_level=1)
DataLyon581a600
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   My first real restaurant visit in France was h...       5
# 1   We went to celebrate our wedding anniversary a...       5
# 2   This place is awesome! Everything was so delic...       5
# 3   Oysters are fantastic, so fresh and sweet, ser...       5
# 4   Didn't get a chance to sit inside, but at the ...       3
# 5   Amazing beer, great ambiance, and super friend...       5
# 6   I have a lot of positive things to say about t...       4
# 7   We went out for dinner in ChinaTown, and found...       5
# 8   Five stars!! I've you're looking for a super  ...       5
# 9   Good vietnamese food! Coming from the bay area...       5
# 10  May 12, 2017 Friday - 7:30 PM for a dinner\n4 ...       4
# ...

# %%
DataLyon581a600[DataLyon581a600.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 15  Pros:\n- Food was tasty\n- Food on menu (like ...       2>

# %%
DataLyon581a600[DataLyon581a600.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 601 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon601a620 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon601a620 = json_normalize(DataDictLyon601a620['search']['business'] , 'reviews',  max_level=1)
DataLyon601a620
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We tried Le Blind Pig based on the reviews and...       5
# 1   On a big time FAIL attempt to find cassoulet i...       4
# 2   Good selection of drinks and decent enough foo...       4
# 3   Love the beer selections.  Service is great.  ...       3
# 4   Italian epicerie par defaut for a coffee or lu...       5
# 5   I love this place! Price is not so expensive b...       5
# 6   Food ok, bad service, got our order wrong, we ...       1
# 7   Very good restaurant and service was excellent...       5
# 8   A small restaurant off the beaten path with ma...       5
# 9   I think that if you are a meat eater, this pla...       2
# 10  This place is beautiful.\nLocated on the top f...       5
# ...

# %%
DataLyon601a620[DataLyon601a620.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 9  I think that if you are a meat eater, this pla...       2>

# %%
DataLyon601a620[DataLyon601a620.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 6  Food ok, bad service, got our order wrong, we ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 621 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon621a640 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon621a640 = json_normalize(DataDictLyon621a640['search']['business'] , 'reviews',  max_level=1)
DataLyon621a640
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Wonderful restaurant in Vieux de Lyon.\n\nA fe...       5
# 1   While in Lyon, Hector was recommended to us as...       5
# 2   My girlfriend and I were looking for a place t...       5
# 3   I can't speak to the food, but we were happy w...       4
# 4   The food was fantastic. They use emmental inst...       5
# 5   This pizza place is the reason I joined yelp. ...       5
# 6   Très bonne pizza. Pâte et dessert fait maison ...       5
# 7   This turned out to be an absolutely delicious ...       5
# 8   Great small family owned sushi spot. We had so...       5
# 9   After moving here from the US, I have been loo...       5
# 10  I tried this place my first night in Lyon and ...       5
# ...

# %%
DataLyon621a640[DataLyon621a640.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon621a640[DataLyon621a640.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 13  Historic restaurant with outdated menu choices...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 641 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon641a660 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon641a660 = json_normalize(DataDictLyon641a660['search']['business'] , 'reviews',  max_level=1)
DataLyon641a660
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Was in a dinner with friends. Tried fondue, a ...       4
# 1   The staff is friendly and welcoming! Our serve...       4
# 2   Great wait staff friendly attentive offered wi...       5
# 3   Exceptionaly good! Refined Thai cuisine. Too b...       5
# 4   Highly recommend this place in Lyon. Pretty in...       5
# 5   WARNING! Bad food and violence! Food was discu...       1
# 6   Don't eat here. Pleasant appearing location ca...       1
# 7   Sometimes it would be good to check Yelp in ad...       1
# 8   These guys are passionate about wine! They spe...       5
# 9   If you are looking for a place to enjoy local ...       4
# 10  Worst Indian food ever!!! You don't get to cho...       1
# ...

# %%
DataLyon641a660[DataLyon641a660.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon641a660[DataLyon641a660.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 5   WARNING! Bad food and violence! Food was discu...       1
# 6   Don't eat here. Pleasant appearing location ca...       1
# 7   Sometimes it would be good to check Yelp in ad...       1
# 10  Worst Indian food ever!!! You don't get to cho...       1
# 12  After buying a €10 cocktail and waiting 40 min...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 661 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon661a680 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon661a680 = json_normalize(DataDictLyon661a680['search']['business'] , 'reviews',  max_level=1)
DataLyon661a680
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Warm, cozy and happy after my meal at Yabio. V...       4
# 1   I am all about a really good burger. I'm kind ...       4
# 2   Delicious burgers, awesome homemade fries, eve...       5
# 3   Firstly, we were served muscat wine and bread....       1
# 4   Went here for lunch As it was recommended by o...       5
# 5   Best Falafel in town! Amazing taste and full o...       5
# 6   What a gem in the city of Lyon, Paris! When yo...       4
# 7   Very good food. Excellent portion size. Host r...       5
# 8   Friendly corner restaurant with pleasant servi...       3
# 9   Nice Food!\nFull of locals and affordable pric...       4
# 10  Its in a small street just next to the quai in...       4

# %%
DataLyon661a680[DataLyon661a680.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon661a680[DataLyon661a680.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  Firstly, we were served muscat wine and bread....       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 681 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon681a700 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon681a700 = json_normalize(DataDictLyon681a700['search']['business'] , 'reviews',  max_level=1)
DataLyon681a700
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Pierre made my night. I had the sole and a gre...       5
# 1   Lyon lives up to its world class cuisine reput...       3
# 2   Tried 33 Cité after a recommendation from my h...       3
# 3   Wow!! A fantastic place. We wandered for an ho...       5
# 4   Ordered regional menu with salad, sea bass and...       2
# 5   Stare into the windows of Le Grand Cafe des Né...       1
# 6   OMG! This place should be shut down before the...       1
# 7   I dine here each time in Lyon. Their andouiett...       5
# 8   Our experience here was awesome! Everything ab...       5
# 9   The tandoori sandwich was a delicious spin on ...       4
# 10  Excellent food for the wandering traveler sick...       5
# ...

# %%
DataLyon681a700[DataLyon681a700.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 4  Ordered regional menu with salad, sea bass and...       2>

# %%
DataLyon681a700[DataLyon681a700.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 5   Stare into the windows of Le Grand Cafe des Né...       1
# 6   OMG! This place should be shut down before the...       1
# 28  Hands down the worst experience in service tha...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 701 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon701a720 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon701a720 = json_normalize(DataDictLyon701a720['search']['business'] , 'reviews',  max_level=1)
DataLyon701a720
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I had a lovely time at sushido this past weeke...       5
# 1   Nice Bouchon with an enjoyable atmosphere. I o...       4
# 2   Ordered a Lasagna for lunch. Was quite OK. The...       3
# 3   Love this pizza!  Family owned business... 100...       5
# 4   This is not your typical Asian restaurant!\nFi...       5
# 5   I stopped by this restaurant on my day trip to...       5
# 6   Excellent lunch today - had buon bo nem which ...       5
# 7   I stumbled upon Hansel & Gretel after leaving ...       3
# 8   I LOLed when I saw this place!!! It takes its ...       4
# 9   Amazingly delicious! I asked the chef (who tur...       5
# 10  Visiting from the States and decided to have s...       5
# ...

# %%
DataLyon701a720[DataLyon701a720.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon701a720[DataLyon701a720.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 12  Extremely rude service!!!! I went in with my 2...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 721 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon721a740 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon721a740 = json_normalize(DataDictLyon721a740['search']['business'] , 'reviews',  max_level=1)
DataLyon721a740
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Very nice place with outdoor seating and air c...       4
# 1  If you love meat, specifically bacon, then thi...       5
# 2  Had dinner at La Tete de Lard last Friday, whi...       5
# 3  I was excited to be in Lyon for a dining exper...       2
# 4  A nice and friendly place. A menu that changes...       4
# 5  This is probably my favorite Indian restaurant...       5
# 6  So happy this place is finally open again. Has...       5
# 7  Simply, the best Thaï cuisine in town !\nAtmos...       5
# 8  A little piece of Thailand in Lyon. Make sure ...       4
# 9  This place is so close to a 4. \nBecause the f...       4

# %%
DataLyon721a740[DataLyon721a740.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  I was excited to be in Lyon for a dining exper...       2>

# %%
DataLyon721a740[DataLyon721a740.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 741 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon741a760 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon741a760 = json_normalize(DataDictLyon741a760['search']['business'] , 'reviews',  max_level=1)
DataLyon741a760
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I liked this place. I got there at the sunset ...       3
# 1   We loved it.  One of our best meals in Lyon.  ...       5
# 2   Very nice little restaurant with excellent foo...       5
# 3   Lovely restaurant with a beautiful small terra...       5
# 4   I struggle to find good food when I travel and...       5
# 5   This is a great example of a Lyonnaise restaur...       4
# 6   Cute little cafe that opens up to an entire co...       4
# 7   3.5 Stars \n-\nI LOVE Le Bistrot de Lyon for t...       3
# 8   Excellent service, friendly and curteao\nGood ...       5
# 9   I've tried Le Bistrot de Lyon several times no...       3
# 10  Il fallait le trouver ce petit coin de paradis...       5
# ...

# %%
DataLyon741a760[DataLyon741a760.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon741a760[DataLyon741a760.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 15  I had been traveling through the country, and ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 761 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon761a780 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon761a780 = json_normalize(DataDictLyon761a780['search']['business'] , 'reviews',  max_level=1)
DataLyon761a780
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Fresh food prepared daily, nothing is frozen, ...       5
# 1   Great english pub. Scott was a great host and ...       4
# 2   The place has gone from great to proper shitho...       1
# 3   To reach the Basilica Fourvière,it's an arduou...       4
# 4   Awesome place, very good food. \nExcellent ent...       5
# 5   It has been a really nice evening in this very...       4
# 6   I went to Bodeguita Cubana several months ago ...       4
# 7   Quaint spot. Good food and atmosphere. We orde...       4
# 8   This restaurant really exceeded my expectation...       5
# 9   If you're visiting my ex-hometown, you can giv...       4
# 10  9/8/15: We found out very quickly that the ver...       5
# ...

# %%
DataLyon761a780[DataLyon761a780.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon761a780[DataLyon761a780.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  The place has gone from great to proper shitho...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 781 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon781a800 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon781a800 = json_normalize(DataDictLyon781a800['search']['business'] , 'reviews',  max_level=1)
DataLyon781a800
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Overpriced for what you get. All dishes were l...       1
# 1   After reading TripAdvisor reviews, we settled ...       3
# 2   This was the best meal I had over a month in F...       5
# 3   Guy & Sons is a delicious burger place in Lyon...       4
# 4   Burgers are very subjective. I like mine juicy...       3
# 5   Why does Guy & Sons get five stars? \n\nThey m...       5
# 6   It seems to be a popular place from local coz ...       3
# 7   No joke, but this hole in the wall bouchon was...       5
# 8   We are visitors from Texas, USA. We found Les ...       5
# 9   Very pleasant afternnon on board watching the ...       4
# 10  Hape was an unexpectedly nice surprise. I coul...       4
# ...

# %%
DataLyon781a800[DataLyon781a800.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon781a800[DataLyon781a800.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 0   Overpriced for what you get. All dishes were l...       1
# 11  Very slow service - 45 min wait for group lunc...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 801 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon801a820 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon801a820 = json_normalize(DataDictLyon801a820['search']['business'] , 'reviews',  max_level=1)
DataLyon801a820
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   A cozy little café with great food anf coffee....       5
# 1   Good coffee, excellent hot chocolate, and we s...       4
# 2   Cute, small, cozy place to grab a latte or esp...       4
# 3   Extremely crowded and long waiting time on a S...       2
# 4   Service was friendly.  They speak English and ...       3
# 5   Stick with the fresh oisters and seafood and y...       4
# 6   I loved the Hank Burger in Paris, and this one...       5
# 7   When in Lyon, be sure to make a few reservatio...       5
# 8   PRaiRiaL is located in the center of everythin...       4
# 9   The boyfriend and I had a fantastic meal here ...       4
# 10  Close to my b&b and didn't want to go all the ...       4

# %%
DataLyon801a820[DataLyon801a820.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  Extremely crowded and long waiting time on a S...       2>

# %%
DataLyon801a820[DataLyon801a820.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 821 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon821a840 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon821a840 = json_normalize(DataDictLyon821a840['search']['business'] , 'reviews',  max_level=1)
DataLyon821a840
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   The food here is delicious and the guys that w...       4
# 1   Destroyed the All Pollo pizza. Pretty dayum go...       4
# 2   So the pizza was pretty good, the service too....       5
# 3   A group of us went. I got the lasagna with sal...       3
# 4   Great service, Great food, Amazing atmosphere,...       5
# 5   SIX Stars!  I am not certain That I am articul...       5
# 6   This restaurant is amazing. You walk up to the...       5
# 7   As someone who is absolutely happy to drop cop...       2
# 8   We were looking for something lighter with sha...       5
# 9   Delicious menu and great concept! Service was ...       5
# 10  Not good food for the price paid. We told them...       2
# ...

# %%
DataLyon821a840[DataLyon821a840.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 7   As someone who is absolutely happy to drop cop...       2
# 10  Not good food for the price paid. We told them...       2>

# %%
DataLyon821a840[DataLyon821a840.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 841 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon841a860 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon841a860 = json_normalize(DataDictLyon841a860['search']['business'] , 'reviews',  max_level=1)
DataLyon841a860
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   my wife and I visited this restaurant last wee...       5
# 1   I am told by the locals who took us here that ...       5
# 2   Recommended by the gal at the hop on hop off b...       4
# 3   I had the first meal in Lyon there. I don't kn...       4
# 4   Best pub ambience. Lively and cozy. You might ...       4
# 5   The burgers my wife and I ordered were the bes...       3
# 6   All in all a great little store at the most fa...       4
# 7   Good food and overwhelmed servers.  We had duc...       4
# 8   Christophe and Dominique created in the Halles...       5
# 9   Delicious bouchon.  Was brought here by a loca...       5
# 10  We chose this as our target Bouchon during our...       4
# ...

# %%
DataLyon841a860[DataLyon841a860.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon841a860[DataLyon841a860.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 861 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon861a880 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon861a880 = json_normalize(DataDictLyon861a880['search']['business'] , 'reviews',  max_level=1)
DataLyon861a880
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Amazing falafel sandwiches! My wife and I are ...       5
# 1  We came into Lyon late and were looking for so...       5
# 2  Tried of whining and dining in Lyon? Had your ...       4
# 3  Very good value for money. The menu Lyonnaise ...       4
# 4  Good meal overall. I got the salad lyonnaise, ...       3
# 5  A classic bouchon Lyonnais serving abundant fo...       4
# 6  This was our first time out in Lyon trying Jap...       5
# 7  A wonderful restaurant with local foods and ex...       5
# 8  In the old city: this is a nice place situated...       4
# 9  A good restaurant of Chinese Northern cuisine,...       3

# %%
DataLyon861a880[DataLyon861a880.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon861a880[DataLyon861a880.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 881 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon881a900 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon881a900 = json_normalize(DataDictLyon881a900['search']['business'] , 'reviews',  max_level=1)
DataLyon881a900
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I have always enjoyed a visit to Le Silk while...       4
# 1   Come for the breakfast AND the view! After two...       5
# 2   The service was absolute terrible. The filet m...       2
# 3   Chineese and Taiwaneese food wich is so good.\...       5
# 4   If you're looking for authentic Chinese food i...       5
# 5   Heh heh long time since I have written a revie...       3
# 6   4 1/2 stars.\n\nJeannine & Suzanne is a charmi...       4
# 7   wonderful salad plates and dessert. A perfect ...       5
# 8   Our cappuccino and matcha latte were xpensive ...       2
# 9   The people that work here make the place such ...       5
# 10  Highly recommend this pizza place.  Clean and ...       4
# ...

# %%
DataLyon881a900[DataLyon881a900.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  The service was absolute terrible. The filet m...       2
# 8  Our cappuccino and matcha latte were xpensive ...       2>

# %%
DataLyon881a900[DataLyon881a900.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 13  Yeah so I know it was late but I ended up payi...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 901 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon901a920 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon901a920 = json_normalize(DataDictLyon901a920['search']['business'] , 'reviews',  max_level=1)
DataLyon901a920
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Very nice place, food is excellent.\nI came wi...       4
# 1   I am not sure where this stands on the hierarc...       4
# 2   A true hidden gem Lyon! Great service, tight t...       4
# 3   I walked past this bouchon Lyonnais the day be...       1
# 4   Our first three dinners in Lyon were meticulou...       5
# 5   Very good value, and a very pleasant meal, unp...       4
# 6   I was in Lyon for the day had looked up a few ...       4
# 7   The restaurant is decorated very well, and the...       2
# 8   I lean vegan with a focus on unprocessed, whol...       5
# 9   Stopped here because the menu had some quality...       4
# 10  The food was, at best, mediocre. But I write t...       1
# ...

# %%
DataLyon901a920[DataLyon901a920.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 7  The restaurant is decorated very well, and the...       2>

# %%
DataLyon901a920[DataLyon901a920.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 3   I walked past this bouchon Lyonnais the day be...       1
# 10  The food was, at best, mediocre. But I write t...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 921 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon921a940 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon921a940 = json_normalize(DataDictLyon921a940['search']['business'] , 'reviews',  max_level=1)
DataLyon921a940
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We needed a break from French food. I'm ashame...       4
# 1   I really liked this place, and I wanted to giv...       4
# 2   Incredible. Imaginative plates,  we loved what...       5
# 3   Food was actually not bad, but my handbag was ...       1
# 4   Despite being located on the touristy rue marr...       3
# 5   The moules et frites prix fixe lunch is a wond...       4
# 6   Honestly this place was overpriced. I had a ch...       3
# 7   This is an awesome place to hang out with frie...       5
# 8   English speaking good mixologist (bartender) a...       4
# 9   Exceptional food and service. Have tried brunc...       5
# 10  Best original chinese in town .., marmite de n...       5

# %%
DataLyon921a940[DataLyon921a940.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon921a940[DataLyon921a940.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  Food was actually not bad, but my handbag was ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 941 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon941a960 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon941a960 = json_normalize(DataDictLyon941a960['search']['business'] , 'reviews',  max_level=1)
DataLyon941a960
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  I'm very surprised this restaurant wasn't on Y...       5
# 1  I don't usually write reviews, but the owner o...       1
# 2  Great experience and excellent service. Really...       4
# 3  Very interesting setting. Each table has its o...       5
# 4  We went here on a monday noon... only 2-3 tabl...       1
# 5  Good quality, they speak english. Tartiflette ...       4
# 6  It's a 4-star rating based on my order: Beef P...       4
# 7  The worst Pho I have ever had. the beef was to...       1
# 8  The fried noodle was really good! (You can add...       4

# %%
DataLyon941a960[DataLyon941a960.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataLyon941a960[DataLyon941a960.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 1  I don't usually write reviews, but the owner o...       1
# 4  We went here on a monday noon... only 2-3 tabl...       1
# 7  The worst Pho I have ever had. the beef was to...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 961 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon961a980 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon961a980 = json_normalize(DataDictLyon961a980['search']['business'] , 'reviews',  max_level=1)
DataLyon961a980
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   May 13, 2017 Saturday - 6:30 for dinner\n4 Adu...       5
# 1   We arrived early, like the kitchen hadn't open...       5
# 2   I love their food! Their place is really full,...       5
# 3   We were looking for traditional Lyonnese food ...       5
# 4   There are many nice reviews here that focus on...       3
# 5   Real Bouchon lyonais with good quality kitchen...       4
# 6   I came here one night after catching the train...       4
# 7   Two stars is being nice... the food was just t...       2
# 8   We enjoyed the restaurant so much that we ate ...       5
# 9   Good service , innovative kitchen , fair in pr...       4
# 10  Excellent savory and sweet crepes! Note that t...       5
# ...

# %%
DataLyon961a980[DataLyon961a980.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 7  Two stars is being nice... the food was just t...       2>

# %%
DataLyon961a980[DataLyon961a980.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Lyon", limit: 20, offset: 980 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictLyon980a999 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataLyon980a999 = json_normalize(DataDictLyon980a999['search']['business'] , 'reviews',  max_level=1)
DataLyon980a999
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Fantastic restaurant.\nDishes use fantastic in...       5
# 1   The only reason went there was it was close to...       3
# 2   Definitely worth a visit. The staff was cordia...       5
# 3   Classy and quiet atmosphere. The appetisers, s...       4
# 4   Mexican place in Lyon with a decent Burger. Qu...       4
# 5   I was so happy to see a Mojito bar, so I stopp...       3
# 6   Horrible. Do not go there.\n\nThe food was tot...       1
# 7   Great Argentinian place! \nThe meat is just ve...       5
# 8   Disappointed. Nice place bad food. It's a pity...       1
# 9   Old dry ingredients. Rice was dry and sushi we...       2
# 10  Himalia is perfect for lunch and exactly what ...       5

# %%
DataLyon980a999[DataLyon980a999.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 9  Old dry ingredients. Rice was dry and sushi we...       2>

# %%
DataLyon980a999[DataLyon980a999.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 6  Horrible. Do not go there.\n\nThe food was tot...       1
# 8  Disappointed. Nice place bad food. It's a pity...       1>

# %% [markdown]
# # Données Strasbourg

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg1a20 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg1a20 = json_normalize(DataDictStrasbourg1a20['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg1a20
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   To me things get magical when I descend into a...       5
# 1   surprisingly good as a place right in the midd...       4
# 2   Caveau Gurtlerhoft has one of the most romanti...       4
# 3   Simple and delicious, casual atmosphere, vinta...       5
# 4   Great cozy place ! The tartine are to die for ...       5
# 5   This is as french as you can get.  I loved thi...       5
# 6   This place has amazing food and the price was ...       5
# 7   With only 24 hours in Strasbourg, I was forced...       5
# 8   Call ahead - it's a tiny place with amazing fo...       5
# 9   The most amazing Onion Tarte Flambé.  As an Am...       5
# 10  I died and went to cheese heaven. A restaurant...       5
# ...

# %%
DataStrasbourg1a20[DataStrasbourg1a20.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 19  This place is a dream for middle school kid wh...       2
# 32  I'm only giving this place two stars because o...       2
# 48  We waited for a server for 10 minutes to take ...       2>

# %%
DataStrasbourg1a20[DataStrasbourg1a20.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 47  Stopped by to watch the FIFA game for a moment...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 21 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg21a40 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg21a40 = json_normalize(DataDictStrasbourg21a40['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg21a40
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   If you can get a seat - it's one of the best s...       5
# 1   This place looked very promising, and appears ...       3
# 2   Large choice of draft beers from around the wo...       5
# 3   Home made hand-pulled noodles made on the spot...       5
# 4   We were walking around Strasbourg looking for ...       5
# 5   Had an excellent experience there last night. ...       5
# 6   We decided to try this place for brunch after ...       4
# 7   * Service: RUDE and condescending. \n* Ambienc...       1
# 8   Wow. We stepped in for a couple of hot chocola...       5
# 9   Came to Strasbourg for a day trip. Wanted to f...       4
# 10  Cozy little spot in Strasbourg.  Thankfully wa...       4
# ...

# %%
DataStrasbourg21a40[DataStrasbourg21a40.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 26  I ordered a 2011 Syrah which they substituted ...       2
# 40  Cheap place but wow do you really get what you...       2>

# %%
DataStrasbourg21a40[DataStrasbourg21a40.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 7  * Service: RUDE and condescending. \n* Ambienc...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 41 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg41a60 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg41a60 = json_normalize(DataDictStrasbourg41a60['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg41a60
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   nice little place. had a lovely meal with my w...       3
# 1   This is an intimate restaurant away from the m...       4
# 2   I looovveee Indian food, it's my absolute favo...       5
# 3   What a wonderful place! We were craving Indian...       5
# 4   This was a welcome oasis of spice in our trip ...       4
# 5   Had breakfast here and the selection is limite...       4
# 6   The food and atmosphere were amazing, all the ...       4
# 7   Have visited for years from Rochester, NY\nThe...       5
# 8   This was one of the few places that were open ...       5
# 9   Â very nice place with a lovely terrace \nI wo...       4
# 10  Delicious food with classic French service. Li...       4
# ...

# %%
DataStrasbourg41a60[DataStrasbourg41a60.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 32  The Internet is vey poor. It is provided by or...       2>

# %%
DataStrasbourg41a60[DataStrasbourg41a60.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 11  Saw the place had good reviews so my boyfriend...       1
# 18  Dear restaurant owner, consider CLOSING your r...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 61 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg61a80 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg61a80 = json_normalize(DataDictStrasbourg61a80['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg61a80
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We stopped in this cafe for a quick bite while...       3
# 1   We came as a family and were able to grab a se...       4
# 2   In a very touristy area but that shouldn't sto...       5
# 3   Exceeded expectations as our group thought tha...       4
# 4   It was délicieux  ! I cleaned up every bit of ...       5
# 5   Chez Tante Liesel offers Alsacienne Cuisine in...       4
# 6   It's in the reasonably priced category. Highly...       5
# 7   This cute little shop is a perfect place for a...       5
# 8   A French take at the high-quality Fast Food wi...       5
# 9   Very good quality for a very good price! Fresh...       5
# 10  Highly recommended !\n\nLooking for a French w...       5
# ...

# %%
DataStrasbourg61a80[DataStrasbourg61a80.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 15  we didnt stay it was very young place my hubby...       2
# 23  Nah fam. If you get the Thai dish you will be ...       2
# 31  Went to restaurant on reviews- very disappoint...       2>

# %%
DataStrasbourg61a80[DataStrasbourg61a80.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 17  Not authentic. Most waiters do not speak Chine...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 81 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg81a100 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg81a100 = json_normalize(DataDictStrasbourg81a100['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg81a100
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We really enjoyed the food.  A wide range of d...       5
# 1   Lovely find. Fantastic food so close to our ho...       5
# 2   No service, no food. 2 houtrs waiting for non ...       1
# 3   This place lives up to the great reviews. The ...       5
# 4   Went here when I was visiting for a couple day...       5
# 5   Such a great Burger joint! \nMake a reservatio...       4
# 6   Great burger, cooked correctly and a tasty, fr...       4
# 7   I had to review this newly opened burger joint...       4
# 8   Excellent low key pub away from the main touri...       5
# 9   Great burgers, kid friendly, and they even let...       5
# 10  If you're out and about in Strasbourg and you'...       5
# ...

# %%
DataStrasbourg81a100[DataStrasbourg81a100.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 37  At first I thought wow a great place, they can...       2>

# %%
DataStrasbourg81a100[DataStrasbourg81a100.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 2   No service, no food. 2 houtrs waiting for non ...       1
# 14  We had reservations for 1900 on Christmas Day....       1
# 19  DO NOT EAT HERE - intoxication alimentaire - N...       1
# 20  Cheap, gross food in a cramped space. We went ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 101 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg101a120 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg101a120= json_normalize(DataDictStrasbourg101a120['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg101a120
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   So, we asked ourselves: where in Strasbourg do...       5
# 1   Good, fresh Asian fusion fare in a quiet neigh...       4
# 2   East Canteen is so delicious!!! The staff is s...       5
# 3   A small restaurant with a contemporary decor. ...       4
# 4   We booked this restaurant for my husband's bir...       5
# 5   I came from New York City to visit my best fri...       5
# 6   Wife booked this place as a bro date for and o...       5
# 7   This is now an Indian restaurant called Namast...       1
# 8   Loved this - it's very small but very special ...       5
# 9   In Strasbourg and want something else than tra...       5
# 10  This review is for Rohan restaurant. On a busy...       4
# ...

# %%
DataStrasbourg101a120[DataStrasbourg101a120.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 21  This review is only based on their lack of any...       2>

# %%
DataStrasbourg101a120[DataStrasbourg101a120.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 7   This is now an Indian restaurant called Namast...       1
# 14  The service was good, however my husband's foi...       1
# 16  It's closed or the address is wrong takes you ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 121 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg121a140 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg121a140= json_normalize(DataDictStrasbourg121a140['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg121a140
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Delicious flamkuche and craft beer. However th...       4
# 1   Charming little restaurant with authentic alsc...       5
# 2   This hidden gem is a tiny Alsatian restaurant ...       4
# 3   Ran by a non profit organization, and staffed ...       5
# 4   Spacious coffee shop with good selection of dr...       4
# 5   Great cheese cake ( I was so full from lunch a...       5
# 6   This place is amazing. Great prices, and taste...       4
# 7   Great option for lunch or dinner.\nLots of opt...       5
# 8   Casual Lebanese food that's full of flavor is ...       4
# 9   Lovely little sandwich place behind the cathed...       5
# 10  If you like libanese food or you want to try s...       5
# ...

# %%
DataStrasbourg121a140[DataStrasbourg121a140.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 24  Negatives: \n1. The special teas were not tast...       2>

# %%
DataStrasbourg121a140[DataStrasbourg121a140.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 17  The Restaurant was very old fashion, the food ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 141 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg141a160 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg141a160= json_normalize(DataDictStrasbourg141a160['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg141a160
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Can't believe this restaurant only had 3.5 sta...       5
# 1   This is a small Vietnamese restaurant run by a...       4
# 2   Nice place for Strasbourg. Waitress could use ...       5
# 3   The thing that makes this place special is tha...       4
# 4   Very nice and friendly Alsace restaurant in th...       5
# 5   What can I say about Winstub Pfifferbriader? M...       3
# 6   Authentic style, good service, but cuisine fee...       3
# 7   Charming and rustic place near the cathedral o...       3
# 8   An enjoyable location for lunch -- excellent A...       4
# 9   This was our favorite go to restaurant each ye...       2
# 10  This is my favorite place in Strasburg. The st...       5
# ...

# %%
DataStrasbourg141a160[DataStrasbourg141a160.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 9  This was our favorite go to restaurant each ye...       2>

# %%
DataStrasbourg141a160[DataStrasbourg141a160.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 12  They actually served this to my husband!  It w...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 161 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg161a180 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg161a180= json_normalize(DataDictStrasbourg161a180['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg161a180
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   great place for lunch, good food, nice ambient...       5
# 1   One of the best chocolate cakes I've had befor...       3
# 2   Have you seen Harry Potter? You know the Weasl...       4
# 3   The food did look good but after being seated ...       1
# 4   A small restaurant with typical Alsacian food....       3
# 5   A good Korean restaurant: ambience & taste & s...       4
# 6   We came here with the recommendation from our ...       3
# 7   Good place to get a taste of some traditional ...       4
# 8   I don't get it.\n\nFlammekuchen, or tarte-flam...       1
# 9   The food is ok French modern but the place is ...       3
# 10  Beautiful modern restaurant - amazing wide spi...       4
# ...

# %%
DataStrasbourg161a180[DataStrasbourg161a180.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataStrasbourg161a180[DataStrasbourg161a180.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  The food did look good but after being seated ...       1
# 8  I don't get it.\n\nFlammekuchen, or tarte-flam...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 181 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg181a200 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg181a200= json_normalize(DataDictStrasbourg181a200['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg181a200
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We enjoyed the meal and the nice Alsace Riesli...       4
# 1   I was on a brief study abroad trip in Strasbou...       2
# 2   I was in search of Choucroute Garnie while in ...       4
# 3   Ate here one night for dinner and really enjoy...       4
# 4   The second time we came in here and we love it...       4
# 5   Perfect little restaurant in the very heart of...       5
# 6   Great restaurant in Strasbourg and perfect rel...       5
# 7   Good falafel!! Amazing service! He made sure o...       5
# 8   More or less have to agree on all reviewers wh...       1
# 9   Not that great to be honest. We were a group o...       1
# 10  Just finished eating here.  Food is decent, se...       2
# ...

# %%
DataStrasbourg181a200[DataStrasbourg181a200.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 1   I was on a brief study abroad trip in Strasbou...       2
# 10  Just finished eating here.  Food is decent, se...       2>

# %%
DataStrasbourg181a200[DataStrasbourg181a200.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 8  More or less have to agree on all reviewers wh...       1
# 9  Not that great to be honest. We were a group o...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 201 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg201a220 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg201a220 = json_normalize(DataDictStrasbourg201a220['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg201a220
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Wow! The best Lebanese food in all of France. ...       5
# 1   Excellent Lebanese food. We had the "Best of L...       5
# 2   We wanted to visit the place based on the revi...       5
# 3   Excellent Italian food in an authentic setting...       5
# 4   Food was good and staff were even better. We h...       4
# 5   If you're looking for Italian food, real Itali...       4
# 6   Favorite restaurant that I have eaten here in ...       5
# 7   Nice bistro with a modern touch. Atmosphere bu...       4
# 8   A well thought out menu with something for eve...       5
# 9   Cute place. Good food. Nice staff. We ordered ...       5
# 10  Great italian food, the menu provides a good s...       4
# ...

# %%
DataStrasbourg201a220[DataStrasbourg201a220.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataStrasbourg201a220[DataStrasbourg201a220.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 18  The waiter was racist. We left after waiting 3...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 221 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg221a240 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg221a240 = json_normalize(DataDictStrasbourg221a240['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg221a240
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Went for dinner while in the city. Food was gr...       4
# 1   Not that I have any idea what Alsatian food sh...       4
# 2   Had a nice lunch there a couple of Weeks ago, ...       4
# 3   L'Ancienne Douane offers some traditional Alsa...       4
# 4   Stopped in for lunch with my husband and in-la...       4
# 5   Conveniently located within a stone's throw of...       4
# 6   Nice place, the atmosphere is pretty good, foo...       3
# 7   The Wife and I arrived without reservations an...       4
# 8   We went here based on comments that it was veg...       2
# 9   Sandwiches, desserts and coffee.  We needed a ...       5
# 10  La Brioche Dorée is more common than Starbucks...       3

# %%
DataStrasbourg221a240[DataStrasbourg221a240.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 8  We went here based on comments that it was veg...       2>

# %%
DataStrasbourg221a240[DataStrasbourg221a240.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 241 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg241a260 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg241a260 = json_normalize(DataDictStrasbourg241a260['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg241a260
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   The best lasagna I have ever had! Great staff,...       4
# 1   Everything in me wants to find something super...       2
# 2   great food, delicious dishes,fresh and prepare...       4
# 3   A little pricy but VERY GOOD! I used deliveroo...       4
# 4   It's harder to find a better place for a typic...       4
# 5   We wanted traditional Alsacien food and this r...       5
# 6   So glad we found this place! It's smaller and ...       5
# 7   I have been coming to that place since at leas...       4
# 8   Worst restaurant I have been to in a long time...       1
# 9   I like this spot. I have been going there sinc...       4
# 10  It's okay, not that impressive , like Tonkatsu...       2
# ...

# %%
DataStrasbourg241a260[DataStrasbourg241a260.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 1   Everything in me wants to find something super...       2
# 10  It's okay, not that impressive , like Tonkatsu...       2>

# %%
DataStrasbourg241a260[DataStrasbourg241a260.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 8   Worst restaurant I have been to in a long time...       1
# 17  First day in Strasbourg we had lunch here.  Pi...       1
# 18  Our daughter threw up at this restaurant, not ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 261 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg261a280 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg261a280 = json_normalize(DataDictStrasbourg261a280['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg261a280
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We loved our Petite France Salad with duck. Th...       5
# 1   Le Dix is a popular restaurant for many reason...       3
# 2   This was the first meal that I had when I got ...       4
# 3   While waiting for my train back to Germany, I ...       5
# 4   Great vegan Köftesi, taste like eating in the ...       5
# 5   Its delicious vegetarian turkish street food a...       5
# 6   The wine selection was a good, simple variety....       3
# 7   Didn't expect much of this restaurant but I re...       4
# 8   This was our best dining experience in Strasbo...       5
# 9   Love love love this place. Best gluten free pl...       5
# 10  We were freezing after touring the city and th...       4
# ...

# %%
DataStrasbourg261a280[DataStrasbourg261a280.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 16  Went in the afternoon to get a snack. Terrible...       2>

# %%
DataStrasbourg261a280[DataStrasbourg261a280.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 17  The food was absolutely horrible and it was a ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 281 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg281a300 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg281a300 = json_normalize(DataDictStrasbourg281a300['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg281a300
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Doesn't even deserve a one. The food remains o...       1
# 1   If you fancy feeling properly French, come to ...       5
# 2   Grabbed a quick lunch here. This wasnt my firs...       4
# 3   I ordered the C4 Chriashi Assorted bowl. It co...       3
# 4   We stopped here for lunch on a rainy Strasbour...       4
# 5   There are loads of sushi places in Strasbourg ...       4
# 6   Raven bar near the raven brige, justa a few me...       4
# 7   Great location and ambience. It was quite crow...       3
# 8   Drinks were ok, but the service wasn't the bes...       2
# 9   Food was excellent! Best omelettes my husband ...       4
# 10  Marie and husband Christophe are owners of the...       5
# ...

# %%
DataStrasbourg281a300[DataStrasbourg281a300.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 8  Drinks were ok, but the service wasn't the bes...       2>

# %%
DataStrasbourg281a300[DataStrasbourg281a300.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 0   Doesn't even deserve a one. The food remains o...       1
# 13  TERRIBLE customer service. We tried to have di...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 301 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg301a320 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg301a320 = json_normalize(DataDictStrasbourg301a320['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg301a320
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   My husband and I wandered in off the street fo...       5
# 1   Super restaurant.\nWaiting time was a bit long...       4
# 2   Fabulous restaurant in the heart of the Le pet...       5
# 3   We happened upon this two year old French rest...       5
# 4   Poor service, nice place, average food\nWe wen...       2
# 5   Cool dining experience by the water that gives...       4
# 6   Charming, little cafe on boat with delicious L...       5
# 7   definitely not my fav place nothing was impres...       1
# 8   Great little place to visit in Strasbourg, but...       3
# 9   Food was delicious- paella and salmon skewers....       4
# 10  After walking in Strasbourg, France we stopped...       5
# ...

# %%
DataStrasbourg301a320[DataStrasbourg301a320.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 4   Poor service, nice place, average food\nWe wen...       2
# 14  Poor meal here. \nTotal disappointment. \nI ha...       2>

# %%
DataStrasbourg301a320[DataStrasbourg301a320.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 7  definitely not my fav place nothing was impres...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 321 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg321a340 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg321a340 = json_normalize(DataDictStrasbourg321a340['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg321a340
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Great location by the cathedral and good ice c...       3
# 1   Not great.  Had thin crust pizza (way too much...       2
# 2   Adorable shop! Their store design is absolutel...       5
# 3   Fantastic food!  I recommend le boef anglais w...       5
# 4   I had an overall good experience at Le Fossile...       3
# 5   An amazing casual restaurant that has tons of ...       5
# 6   We had a very uncomfortable experience at La P...       1
# 7   We went there in a big group of about 13 in th...       4
# 8   Where the soul meets the body :)\n\nBy far my ...       5
# 9   I have spent a lot of time in Japan for school...       5
# 10  There are certainly more charming places to ea...       5
# ...

# %%
DataStrasbourg321a340[DataStrasbourg321a340.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 1  Not great.  Had thin crust pizza (way too much...       2>

# %%
DataStrasbourg321a340[DataStrasbourg321a340.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 6  We had a very uncomfortable experience at La P...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 341 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg341a360 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg341a360 = json_normalize(DataDictStrasbourg341a360['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg341a360
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We were so disappointed.  The staff are rude a...       1
# 1   Favorite Vietnamese restaurant.  Cozy  atmosph...       5
# 2   I'm going to keep it short and sweet and get r...       2
# 3   Fantastic french food! A colleague took me her...       5
# 4   A must try in Strasbourg if you are  not into ...       5
# 5   I wasn't sure what to expect. We had the shrim...       5
# 6   On our trip to Straßburg we where looking for ...       4
# 7   Stopped in Strasbourg on the way to Paris. Had...       3
# 8   Went in at 11:30 for 2 coffees the place was c...       1
# 9   Great foie gras, blood sausage, sauerkraut and...       5
# 10  I dont know why this place has such poor revie...       3
# ...

# %%
DataStrasbourg341a360[DataStrasbourg341a360.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  I'm going to keep it short and sweet and get r...       2>

# %%
DataStrasbourg341a360[DataStrasbourg341a360.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 0   We were so disappointed.  The staff are rude a...       1
# 8   Went in at 11:30 for 2 coffees the place was c...       1
# 12  I would not recommend this fast food restauran...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 361 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg361a380 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg361a380 = json_normalize(DataDictStrasbourg361a380['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg361a380
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Went there for breakfast while visiting the ci...       4
# 1   Im disgusted. I ordered 3 tarte flambee and in...       1
# 2   Ignore ignore ignore that place !!! Outside an...       2
# 3   a favorite brasserie for terrific cuisine Alsa...       4
# 4   Great place to taste the lebanese restaurent. ...       5
# 5   Beautifully designed hotel with a very special...       5
# 6   This hotel is no joke is a PERFECT place if yo...       4
# 7   Hotel was paid by orbitz account and charged m...       1
# 8   Poorly prepared food and expensive. I'll cut t...       2
# 9   Came here on a Monday, most other places were ...       4
# 10  Visited Strasbourg on a rainy, dreary day and ...       4
# ...

# %%
DataStrasbourg361a380[DataStrasbourg361a380.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 2   Ignore ignore ignore that place !!! Outside an...       2
# 8   Poorly prepared food and expensive. I'll cut t...       2
# 14  For me I came to this location twice. I eat a ...       2>

# %%
DataStrasbourg361a380[DataStrasbourg361a380.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 1   Im disgusted. I ordered 3 tarte flambee and in...       1
# 7   Hotel was paid by orbitz account and charged m...       1
# 12  It is really sad, how some restaurants serve u...       1
# 17  We were really excited to try MiTo. We drove 2...       1
# 22  We waited 40min to receive our food. They mixe...       1
# 23  Torricelli Restaurant\nAvoid this restaurant -...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 381 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg381a400 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg381a400 = json_normalize(DataDictStrasbourg381a400['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg381a400
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I am very disappointed from this place. We are...       1
# 1   We ordered two tartes flambees, one traditiona...       4
# 2   We asked to be seated outside and they said ou...       1
# 3   One of the more known and older chines in Stra...       3
# 4   Definitely do not recommend if you are of chin...       1
# 5   Best Chinese in Strasbourg\nExcellent atmosphe...       5
# 6   This was easily the best cappuccino of my life...       5
# 7   A proper coffee shop proudly using high qualit...       5
# 8   Wonderful outdoor seating in the middle of pet...       2
# 9   Wonderful little restaurant that is a few step...       5
# 10  Our ONE meal in Strasbourg while on a Viking C...       5
# ...

# %%
DataStrasbourg381a400[DataStrasbourg381a400.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 8  Wonderful outdoor seating in the middle of pet...       2>

# %%
DataStrasbourg381a400[DataStrasbourg381a400.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 0  I am very disappointed from this place. We are...       1
# 2  We asked to be seated outside and they said ou...       1
# 4  Definitely do not recommend if you are of chin...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 401 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg401a420 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg401a420 = json_normalize(DataDictStrasbourg401a420['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg401a420
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Typical Thai food, but when you're far from ho...       3
# 1   It is so hard to find healthy food (aka organi...       5
# 2   Stopped by for a quick lunch.   Good atmospher...       3
# 3   We walked away with half the sushi on the plat...       1
# 4   We walked by several creperies on our walk abo...       5
# 5   Best crepes in town!!! Friendly service staff ...       5
# 6   We went for a late lunch and wine. It was near...       4
# 7   Aww, Pizzeria Chez Matteo just brings back hap...       4
# 8   A nice restaurant in a bit of a strange place....       5
# 9   The terrace is a wonderful, unpretentious plac...       5
# 10  Had a few hours before our train up to Paris, ...       4
# ...

# %%
DataStrasbourg401a420[DataStrasbourg401a420.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataStrasbourg401a420[DataStrasbourg401a420.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  We walked away with half the sushi on the plat...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 421 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg421a440 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg421a440= json_normalize(DataDictStrasbourg421a440['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg421a440
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Really juicy burger! Lovely quick service .\nI...       4
# 1  Great burger and even better fries! \nIt was j...       5
# 2  It's a young student bar - one of the many of ...       4
# 3  We were looking for something light and vegeta...       5
# 4  The only Turkish I know is "Merhaba" - greetin...       5
# 5  Beautiful garden. Pity they open it just durin...       3
# 6  I wish i read the reviews before entering!\nTh...       1
# 7  The food was OK. I had Chicken Tikka and it wa...       3

# %%
DataStrasbourg421a440[DataStrasbourg421a440.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataStrasbourg421a440[DataStrasbourg421a440.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 6  I wish i read the reviews before entering!\nTh...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 441 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg441a460 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg441a460 = json_normalize(DataDictStrasbourg441a460['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg441a460
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Stay away from this place! My impression is al...       1
# 1  While strolling the streets of Strasbourg, my ...       3
# 2  Special Brazilian restaurant. Sometimes life m...       5
# 3  We were visiting Strasbourg FR, and wanted to ...       5
# 4  We made a reservation in August for November a...       1
# 5  Rotten vegetables in sushi. "Beef fromage' ske...       1
# 6  Filet steak was delicious!  Salad and potatoes...       4
# 7  The attendant was the meanest waitress I have ...       1
# 8  A traditional looking restaurant with nice ser...       3

# %%
DataStrasbourg441a460[DataStrasbourg441a460.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataStrasbourg441a460[DataStrasbourg441a460.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 0  Stay away from this place! My impression is al...       1
# 4  We made a reservation in August for November a...       1
# 5  Rotten vegetables in sushi. "Beef fromage' ske...       1
# 7  The attendant was the meanest waitress I have ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 461 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg461a480 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg461a480 = json_normalize(DataDictStrasbourg461a480['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg461a480
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Very good! Very welcoming and family friendly....       5
# 1  Unpretentious Italian place on the river. Not ...       4
# 2  While visiting Strasbourg recently, my husband...       1
# 3  Cute little cafe with a friendly waitstaff. It...       4
# 4  Selon moi la pizzeria des theatres reste la me...       5
# 5  Never having been to Straussberg, Fischerstub ...       4

# %%
DataStrasbourg461a480[DataStrasbourg461a480.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataStrasbourg461a480[DataStrasbourg461a480.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  While visiting Strasbourg recently, my husband...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 481 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg481a500 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg481a500 = json_normalize(DataDictStrasbourg481a500['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg481a500
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Very nice guys working there. The food is good...       4
# 1  The owner is very rude and impolite, when my m...       1
# 2  This is a small, intimate place, a little out ...       4

# %%
DataStrasbourg481a500[DataStrasbourg481a500.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataStrasbourg481a500[DataStrasbourg481a500.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 1  The owner is very rude and impolite, when my m...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 501 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg501a520 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg501a520 = json_normalize(DataDictStrasbourg501a520['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg501a520
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  This is a great Pakistani restaurant. I have t...       5
# 1  What a delight! We came on a very busy day (Ba...       5
# 2  Jet-lagged as all hell, my wife and I stopped ...       3
# 3  My husband and I were wandering around Strasbo...       2

# %%
DataStrasbourg501a520[DataStrasbourg501a520.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  My husband and I were wandering around Strasbo...       2>

# %%
DataStrasbourg501a520[DataStrasbourg501a520.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 521 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg521a540 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg521a540 = json_normalize(DataDictStrasbourg521a540['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg521a540
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Plentiful power outlets, nice decor, English-s...       5
# 1   It's a nice family owned and run vegetarian re...       4
# 2   We went early for France but they were happy t...       1
# 3   great quality, value and presentation. the wai...       5
# 4   Avoid this restaurant. Clearly have tables and...       1
# 5   We decided to escape the Marche de Noel crowds...       4
# 6   The place is nice but both food and service su...       1
# 7   This place is amazing, the personnel is super ...       5
# 8   We enjoyed the crepes at La Bolée. I ordered t...       4
# 9   This place is not a crepe shop, it's a restaur...       1
# 10  Delicious galettes. We were staying at a hotel...       5
# ...

# %%
DataStrasbourg521a540[DataStrasbourg521a540.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataStrasbourg521a540[DataStrasbourg521a540.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  We went early for France but they were happy t...       1
# 4  Avoid this restaurant. Clearly have tables and...       1
# 6  The place is nice but both food and service su...       1
# 9  This place is not a crepe shop, it's a restaur...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 541 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg541a560 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg541a560 = json_normalize(DataDictStrasbourg541a560['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg541a560
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  This is just a couple steps from the river and...       4
# 1  We been here with a big group(16p). They were ...       3
# 2  We had a wonderful lunch of salade Cardinal (c...       5
# 3  The doner kebab was disappointing as the bread...       2

# %%
DataStrasbourg541a560[DataStrasbourg541a560.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  The doner kebab was disappointing as the bread...       2>

# %%
DataStrasbourg541a560[DataStrasbourg541a560.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 561 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg561a580 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg561a580 = json_normalize(DataDictStrasbourg561a580['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg561a580
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  When we stayed at the Chateau de Pourtales, th...       5
# 1  We weren't able to access Yelp before selectin...       3
# 2  the worst service and one of the worst coffey ...       1
# 3  After being indecisive about where we wanted t...       5
# 4  This has to rank as one of the worst dining ex...       1
# 5  I wish I could review the food. I eat out ofte...       1
# 6  This restaurant is under correct, the noodles ...       1

# %%
DataStrasbourg561a580[DataStrasbourg561a580.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataStrasbourg561a580[DataStrasbourg561a580.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  the worst service and one of the worst coffey ...       1
# 4  This has to rank as one of the worst dining ex...       1
# 5  I wish I could review the food. I eat out ofte...       1
# 6  This restaurant is under correct, the noodles ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 581 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg581a600 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg581a600 = json_normalize(DataDictStrasbourg581a600['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg581a600
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  A couple friends were hungry after their drive...       2
# 1  This was a nice place for a sit down meal.  Ou...       4
# 2  Best omelette ever. Price 9Euro during high se...       5

# %%
DataStrasbourg581a600[DataStrasbourg581a600.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 0  A couple friends were hungry after their drive...       2>

# %%
DataStrasbourg581a600[DataStrasbourg581a600.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Strasbourg", limit: 20, offset: 601 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictStrasbourg601a620 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg601a620 = json_normalize(DataDictStrasbourg601a620['search']['business'] , 'reviews',  max_level=1)
DataStrasbourg601a620
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Speed restaurant just beside the train station...       3
# 1  I never have a good luck with german food, oth...       2
# 2  The pizza is not really Italian pizza and it a...       4
# 3  I would give this place no stars if I could. I...       1

# %%
DataStrasbourg601a620[DataStrasbourg601a620.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 1  I never have a good luck with german food, oth...       2>

# %%
DataStrasbourg601a620[DataStrasbourg601a620.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  I would give this place no stars if I could. I...       1>

# %% [markdown]
# # Sélection des 200 restaurants  avec avis d'insatisfaction

# %%
from pandas.io.json import json_normalize
DataStrasbourg81a100b = json_normalize(DataDictStrasbourg81a100['search'] , 'business',  max_level=1)
DataStrasbourg81a100b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                             name                      id  \
# 0                Le Tire Bouchon  CDluJvPmtgSo1n-PuNJ5rw
# 1                     Fou d'café  RF49NNRR3dZamjGyyfkhsw
# 2               Les Sales Gosses  HDxFdXq08cLRWVkxydVkxg
# 3            Le Pied de Mammouth  SpmAyUZgQhUD9urnLtoe0A
# 4                  Abattoir Café  5OtdFJDyJcP5H1z-Lq9lbg
# 5   Crêperie Le Moulin du Diable  QkO4BBxmWazCa4iMTNcEzQ
# 6             Restaurant Le Dome  315GWD9oQReR6vW2grqCag
# 7            Les Savons d'Hélène  6SS4DKLKwZBnz67rkvcIrQ
# 8                       Paradiso  FxT9ypZRkIuYRLe40-dgMQ
# 9                     Tapas Café  YppX2NjHAaCzOrSHzS5K8w
# 10         Copains comme Cochons  FfC55NPXmjAEetRg4k2DKQ
# 11                         Bloom  cF_pibT53vNf4SDpj-WNpg
# ...

# %%
DataStrasbourg81a100
# Out:
#                                                  text  rating
# 0   We really enjoyed the food.  A wide range of d...       5
# 1   Lovely find. Fantastic food so close to our ho...       5
# 2   No service, no food. 2 houtrs waiting for non ...       1
# 3   This place lives up to the great reviews. The ...       5
# 4   Went here when I was visiting for a couple day...       5
# 5   Such a great Burger joint! \nMake a reservatio...       4
# 6   Great burger, cooked correctly and a tasty, fr...       4
# 7   I had to review this newly opened burger joint...       4
# 8   Excellent low key pub away from the main touri...       5
# 9   Great burgers, kid friendly, and they even let...       5
# 10  If you're out and about in Strasbourg and you'...       5
# 11  Lauren and I stumbled upon this cozy jewel whi...       5
# 12  I went to this Crêperie during Christmas. So f...       5
# 13  Delicious!!!! And so quaint, we went for deser...       5
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg101a120b = json_normalize(DataDictStrasbourg101a120['search'] , 'business',  max_level=1)
DataStrasbourg101a120b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                         name                      id  \
# 0        Chez l'Oncle Freddy  cgxbeMk5wRuaC2z16Bo6uw
# 1               East Canteen  enVV_Sk4BbHx7BTGDtM2qQ
# 2   Le Banquet des Sophistes  TlbGiAVw5JSgasYkXLXBTA
# 3      Les Garçons Parisiens  5WIoWvLc4HSmGJUCxPlTFA
# 4                       1741  sPQugtvuQV2LOoOhcKtheA
# 5                 Chiang Mai  AfrdppXXlLUGnGAAliTH7A
# 6             Momos Tibétain  Y2jnHXEI3KT7TIZbrtIq3Q
# 7                 2 Faubourg  7iru3duriRd3SNPw_pUpZg
# 8                      Rohan  kv15rXPTRWJ5Fwl520cA7Q
# 9         Les Toqués du Coin  o5-2uN3UN57HJ8B3-1f7Ng
# 10               Matsumotoya  _d2KnlhY1ZSTcpVChBdsLQ
# 11               Dim Sum Sam  az59i2UxCU0rTwJ42IEJKQ
# 12                 Ostreidae  MF1FWe5LcItbxJyUnefsEQ
# ...

# %%
DataStrasbourg101a120
# Out:
#                                                  text  rating
# 0   So, we asked ourselves: where in Strasbourg do...       5
# 1   Good, fresh Asian fusion fare in a quiet neigh...       4
# 2   East Canteen is so delicious!!! The staff is s...       5
# 3   A small restaurant with a contemporary decor. ...       4
# 4   We booked this restaurant for my husband's bir...       5
# 5   I came from New York City to visit my best fri...       5
# 6   Wife booked this place as a bro date for and o...       5
# 7   This is now an Indian restaurant called Namast...       1
# 8   Loved this - it's very small but very special ...       5
# 9   In Strasbourg and want something else than tra...       5
# 10  This review is for Rohan restaurant. On a busy...       4
# 11  Great place to come sit and relax. Very nice s...       5
# 12  Delicious and affordable all-you-can-eat-and-d...       5
# 13  It's good, for real, the texture of the meat i...       5
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg241a260b = json_normalize(DataDictStrasbourg241a260['search'] , 'business',  max_level=1)
DataStrasbourg241a260b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                name                      id  \
# 0                      Le Picobello  9YvYO49HGyvNTsprYqOHkw
# 1                         Velicious  hAuaif7bYTSHggdLNRlK0A
# 2                            Lohkäs  bmHRJOLHb2Uq5oPAUWaBAQ
# 3                           Sushido  B2MdFVq1MZ_pX7LbzPA6gg
# 4                          Fujiyama  zoq68tjRbpg0A-NC3pIluA
# 5                       LaParticule  Qipy0LnE900fDNregB_iHQ
# 6                Le Pont des Vosges  ffRgCqWDe-uI4a4q9xBZPA
# 7                La Folie des Pâtes  cg-wbSAYHDsoC6DM1OOlRg
# 8             Harmonie Bowl & Juice  8wBVbOVKkPHuWDKWeWtn1w
# 9                  Pizzéria Antonio  17eADCeAn4rd1E5jI-koyw
# 10            La Taverne Cathédrale  ba1latVhjmpUgFP7TX1Q0A
# 11  Restaurant Les 2 Petits Canards  vAr9yNtTPB6owr11XhXefQ
# ...

# %%
DataStrasbourg241a260
# Out:
#                                                  text  rating
# 0   The best lasagna I have ever had! Great staff,...       4
# 1   Everything in me wants to find something super...       2
# 2   great food, delicious dishes,fresh and prepare...       4
# 3   A little pricy but VERY GOOD! I used deliveroo...       4
# 4   It's harder to find a better place for a typic...       4
# 5   We wanted traditional Alsacien food and this r...       5
# 6   So glad we found this place! It's smaller and ...       5
# 7   I have been coming to that place since at leas...       4
# 8   Worst restaurant I have been to in a long time...       1
# 9   I like this spot. I have been going there sinc...       4
# 10  It's okay, not that impressive , like Tonkatsu...       2
# 11  This restaurant is an institution in Strasbour...       4
# 12  Tiffany location, I had the impresion no touri...       4
# 13  Very good, old restaurant. Everything you eat ...       4
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg361a380b = json_normalize(DataDictStrasbourg361a380['search'] , 'business',  max_level=1)
DataStrasbourg361a380b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                      name                      id  \
# 0                  Dreher  vz4mzWMzcZNIU08X-CCdog
# 1   Restaurant La Rotonde  0wLE-wJTDv8DQxPsQYWUeQ
# 2              PerloDrink  LhLmdMVXeOtv9fMWQHlkmQ
# 3               La Bourse  XhSJ8iIHX17hCLDTj2AMaw
# 4                 Helixir  JpyqWqVJ1nKMdRhhqcEssA
# 5                  Dana R  9YaKn0oEeBR1RIGPusL1sQ
# 6              Mont Liban  Y6kQy2aEWn1RM3Oa--Yvhg
# 7                    Boma  lZsbMJKbJyIvOVg9XrjQRA
# 8             Le Libanais  o9-t0Ggr0w75woV2XYh6-w
# 9        La Petite Alsace  59YQ8yyZ3IIkRxyBt8VR5A
# 10              Le Penjab  -uwGfeOmOslIpAJR91JXPQ
# 11              Le Madras  I6WqzY8NVSOvO2X4D0FSEQ
# 12                   MiTo  9U09iUMUvJYxDLszBrbkwA
# 13   La Maison des Mezzés  7LhgtijG9Vjq0rL4IzZzzA
# ...

# %%
DataStrasbourg361a380
# Out:
#                                                  text  rating
# 0   Went there for breakfast while visiting the ci...       4
# 1   Im disgusted. I ordered 3 tarte flambee and in...       1
# 2   Ignore ignore ignore that place !!! Outside an...       2
# 3   a favorite brasserie for terrific cuisine Alsa...       4
# 4   Great place to taste the lebanese restaurent. ...       5
# 5   Beautifully designed hotel with a very special...       5
# 6   This hotel is no joke is a PERFECT place if yo...       4
# 7   Hotel was paid by orbitz account and charged m...       1
# 8   Poorly prepared food and expensive. I'll cut t...       2
# 9   Came here on a Monday, most other places were ...       4
# 10  Visited Strasbourg on a rainy, dreary day and ...       4
# 11  We stumbled upon this place while searching fo...       4
# 12  It is really sad, how some restaurants serve u...       1
# 13  Where's the heat?\nI've been to this restauran...       3
# ...

# %%
from pandas.io.json import json_normalize
DataStrasbourg441a460b = json_normalize(DataDictStrasbourg441a460['search'] , 'business',  max_level=1)
DataStrasbourg441a460b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                            name                      id  \
# 0          Le Bouchon Brionnais  LZ1OElDWWzlovyFGdLQ96Q
# 1                       L'Atlas  Qx1VszoEU7Prhszsm1KMRg
# 2             Le Roi Et Son Fou  fYKAHwC_4MsPpP10th0BBQ
# 3                    Le Monceau  WD6q7pRgu7ig67U1mLU3gQ
# 4                     Au Pigeon  7sGiNtgXjfELduUZhy3XCw
# 5       Le Bistrot du Boulanger  5l5vSdM2S9k3UfMnO30SHg
# 6   Acerola - Cozinha Do Brasil  4scDeHFpiNSEgU9vr42VYw
# 7                   Zehnerglock  g48mpmfvdFjeGTi8SpFVDw
# 8                        Silver  o8HVhRNtRvisbcIedBj2tg
# 9                      La Scala  DzfYsBZ-zege0zTPT-iuBg
# 10                      Sushido  aQnxFRAndIj1rLbSq0DxFw
# 11                   Vert Olive  VCo8DdXjC-FY1r9E19uCWw
# 12                 La Palmeraie  Z8ZthJxzcW36rczHRGRBDg
# ...

# %%
DataStrasbourg441a460
# Out:
#                                                 text  rating
# 0  Stay away from this place! My impression is al...       1
# 1  While strolling the streets of Strasbourg, my ...       3
# 2  Special Brazilian restaurant. Sometimes life m...       5
# 3  We were visiting Strasbourg FR, and wanted to ...       5
# 4  We made a reservation in August for November a...       1
# 5  Rotten vegetables in sushi. "Beef fromage' ske...       1
# 6  Filet steak was delicious!  Salad and potatoes...       4
# 7  The attendant was the meanest waitress I have ...       1
# 8  A traditional looking restaurant with nice ser...       3

# %%
from pandas.io.json import json_normalize
DataLyon101a120b = json_normalize(DataDictStrasbourg101a120['search'] , 'business',  max_level=1)
DataLyon101a120b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                         name                      id  \
# 0        Chez l'Oncle Freddy  cgxbeMk5wRuaC2z16Bo6uw
# 1               East Canteen  enVV_Sk4BbHx7BTGDtM2qQ
# 2   Le Banquet des Sophistes  TlbGiAVw5JSgasYkXLXBTA
# 3      Les Garçons Parisiens  5WIoWvLc4HSmGJUCxPlTFA
# 4                       1741  sPQugtvuQV2LOoOhcKtheA
# 5                 Chiang Mai  AfrdppXXlLUGnGAAliTH7A
# 6             Momos Tibétain  Y2jnHXEI3KT7TIZbrtIq3Q
# 7                 2 Faubourg  7iru3duriRd3SNPw_pUpZg
# 8                      Rohan  kv15rXPTRWJ5Fwl520cA7Q
# 9         Les Toqués du Coin  o5-2uN3UN57HJ8B3-1f7Ng
# 10               Matsumotoya  _d2KnlhY1ZSTcpVChBdsLQ
# 11               Dim Sum Sam  az59i2UxCU0rTwJ42IEJKQ
# 12                 Ostreidae  MF1FWe5LcItbxJyUnefsEQ
# ...

# %%
DataLyon101a120
# Out:
#                                                  text  rating
# 0   Greasy as fuck, especially the veggy burger. T...       2
# 1   A local friend recommended this place to us. S...       5
# 2   I had read good things about Les Apothicaires....       4
# 3   Reservation only. Doesn't answer the phone for...       1
# 4   Exactly the kind of hearty meal I longed for w...       5
# 5   An authentic, no frills French restaurant! Thi...       4
# 6   This was the best meal we had in France! I had...       5
# 7   This place let us down.\nThe donuts are greasy...       1
# 8   Under cooked hamburger and limp, soggy fries b...       2
# 9   We had the L'original Fromage and L'original b...       5
# 10  Ok this was quite amazing. I got the Butcher b...       4
# 11  My friend and I made our way to Butcher based ...       5
# 12  The 'fat' burger was very juicy and cooked per...       5
# 13  Wonderful Café! \n\nNewTree Café has a healthy...       5
# ...

# %%
from pandas.io.json import json_normalize
DataLyon341a360b = json_normalize(DataDictStrasbourg341a360['search'] , 'business',  max_level=1)
DataLyon341a360b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                               name                      id  \
# 0                    Villa Casella  9dhdSiQa_5z10194L2okgA
# 1             Restaurant Thuy Tien  dZQo8sfILtbj7CT0uSZ96g
# 2                 Restaurant Rio's  oVL34FJ7zFrZcDQJxk2lTA
# 3             Au Bonheur des Dames  AXq7Lt4Ya8GS178m25B6Tg
# 4                       La Kulture  mYY1gCmhNkhGrqo35_8OQg
# 5                     Il Pinocchio  tpqQeLstEi24SJgJc388kw
# 6               La Rose des Sables  -3J0OxcMJF80I5wd0CRz3w
# 7                         Lucullus  SJlyxdnWmHBVUUD19QuRzQ
# 8                     Le Cappadoce  JFSx2P6QcBO0G8Lt5pwR9g
# 9                         Le Gecko  --3JoKQDVnlIG_m75Me5UA
# 10                       La Grappa  wgDUJd7j7UvAB6xWwLnf5A
# 11               restaurant kasmir  PbXC_yZYHUFKNANhT5bt6Q
# ...

# %%
DataLyon341a360
# Out:
#                                                  text  rating
# 0   Excellent place for a dinner with your " copin...       5
# 1   I wanted to be impressed but sadly the experie...       2
# 2   We completely stumbled into this place on a bu...       5
# 3   Stylish without being intimidating, with an up...       5
# 4   Says it is open except there is a sign on the ...       1
# 5   There's only one way to correctly experience t...       5
# 6   I've had quite a few Philly in various places ...       5
# 7   Its THE place to be. A lil noisy on Saturdays ...       5
# 8   It's a nice place to get a beer. The pizza was...       4
# 9   Loved this hotel. Took my Boyfriend here for a...       5
# 10  Bugs crawling in my breakfast delivered to roo...       1
# 11  Very bad customer service. We have booked one ...       1
# 12  We stopped here for brunch on the way to the p...       5
# 13  I have made this one of my favorite wine bars ...       4
# ...

# %%
from pandas.io.json import json_normalize
DataLyon561a580b = json_normalize(DataDictLyon561a580['search'] , 'business',  max_level=1)
DataLyon561a580b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                         name                      id  \
# 0                   Macanudo  P1t0FzbJJ8KyEVskovJQwQ
# 1        La Table en Braille  3d8Ky2megzM3iwrFlHAXYA
# 2     L'Atelier du Pizzaiolo  _79AxkaFvcQmdn_m8Zstag
# 3                      Zucca  lAwICZgibJ3Etp63gXTmHg
# 4               Candy Cookie  Ge4y1gZwruERHNDxo5mUFw
# 5           L'Esprit Bistrot  eFYNSghfXdEs4XinAPCZXw
# 6                  Indo Café  n31mSG_RXLqFNH_d_biPdw
# 7   Diggers - Bar à Chocolat  1n8urGKvJj02m5mnxEOmaA
# 8                       Woko  PkBH4aGXtoNI54KcWvzE7A
# 9       Bistrot du Boulevard  Nkv3n3oZJ7J4sZqyzYShkQ
# 10                    Soline  N9HD1qL3_26Xxmmw_MJanA
# 11                 Le Cintra  CBHuAE2SkuVG6RYcSybQEw
# 12                    Sintra  xMVy7zDDkEMszJ_sJIIyfw
# ...

# %%
DataLyon561a580
# Out:
#                                                  text  rating
# 0   Awesome location, great pizza. Salad Cesar was...       4
# 1   The best pizza I have had in a long time and g...       5
# 2   Ended up here not by choice, but out of  conve...       2
# 3   Uhm, I am divided. Food at dinner was not bad ...       3
# 4   Tried to have dinner here last night and was v...       1
# 5   I really, really, really wanted to like this p...       2
# 6   Very cozy restaurant with a vibrant, original ...       4
# 7   I do not understand the hype about this place ...       2
# 8   Fast casual Vietnamese food.   Good seating an...       3
# 9   Je ne pensais pas mettre une si bonne apprécia...       5
# 10  Love this little place. Great tasty asian food...       4
# 11  The absolute best atmosphere in la XRousse tha...       5
# 12  Found Soline while looking for a good vegetari...       5
# 13  Yum! I finally got to try Soline with a friend...       4
# ...

# %%
from pandas.io.json import json_normalize
DataLyon641a660b = json_normalize(DataDictLyon641a660['search'] , 'business',  max_level=1)
DataLyon641a660b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                             name                      id  \
# 0                         Fiston  F1wXhqReRUUmkKIhXlVYZg
# 1                   Rivière Kwaï  Lo71HWHMjjxy3xDLGEaEJw
# 2                     21 Sur Vin  38YWO9dbIrb2xxGSLo_A_A
# 3                Gourmets d'Asie  MRI78HBxmq9ZY_UgZ00m8g
# 4   La Boutique - Nos Bons Plats  k_WgnkgQB1MrqcZT4NG6sQ
# 5            Symphonie Orientale  2LKNnh-htQc5BcxLbjpbvw
# 6                     La Gamelle  lVtpyX7X0XUxZtX4B7VxNQ
# 7                      Café Nova  kRCr-FXXPX7A5PYsqEDEHQ
# 8          Bistrot du Potager #2  FS2rG_yqAFn4RALE7rtuGw
# 9                     Le Marélie  UuizEux7yO2KqtWoaVihAQ
# 10             Aux Bons Sauvages  hwfmuKZ_qqSSlpVqr9yZjg
# 11              Bouchon Lyonnais  fss7QFYueLqvv-mtevVclw
# ...

# %%
DataLyon641a660
# Out:
#                                                  text  rating
# 0   Was in a dinner with friends. Tried fondue, a ...       4
# 1   The staff is friendly and welcoming! Our serve...       4
# 2   Great wait staff friendly attentive offered wi...       5
# 3   Exceptionaly good! Refined Thai cuisine. Too b...       5
# 4   Highly recommend this place in Lyon. Pretty in...       5
# 5   WARNING! Bad food and violence! Food was discu...       1
# 6   Don't eat here. Pleasant appearing location ca...       1
# 7   Sometimes it would be good to check Yelp in ad...       1
# 8   These guys are passionate about wine! They spe...       5
# 9   If you are looking for a place to enjoy local ...       4
# 10  Worst Indian food ever!!! You don't get to cho...       1
# 11  This place has surprisingly excellent shareabl...       4
# 12  After buying a €10 cocktail and waiting 40 min...       1
# 13  Cute  ramen place that's brightly lighted, ser...       3
# ...

# %%
from pandas.io.json import json_normalize
DataLyon681a700b = json_normalize(DataDictLyon681a700['search'] , 'business',  max_level=1)
DataLyon681a700b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                             name                      id  \
# 0                        33 Cité  aCpmmvtP-2vWFx_2MnM_gg
# 1                          Buldo  iJ-axbf7P4hB3JScTs1YKw
# 2   Le Bistrot de La Gourgandine  ialJCKlrU1lRs7O94P5TZw
# 3      Grand Café des Négociants  DeBJxNRyQPePB0gEOAUAWQ
# 4                     Chez Jules  CiSwcgtjkJiK7h91Mdvafg
# 5                    Etche Berry  7xrqZI5mtEPCVLjfOydWPQ
# 6            Le Rouge et le Noir  ic0zS-X5_uMWV7tzdJAsmg
# 7                 La Traboulerie  aGH8uNP-fGgc0fTF52s6ig
# 8                 Rawal Tandoori  g6NxLZ49Ia4RgGCcxAAx5A
# 9                  Le Cèdre Bleu  O_k1Qjf1mnPX1PqpDSlQwQ
# 10                    La Cuisine  Yxdg96toE2HvcbOe-1K2Jg
# 11             Arômes et Saveurs  dnUHu8BXhQkLYXzgZ7-YYQ
# ...

# %%
DataLyon681a700
# Out:
#                                                  text  rating
# 0   Pierre made my night. I had the sole and a gre...       5
# 1   Lyon lives up to its world class cuisine reput...       3
# 2   Tried 33 Cité after a recommendation from my h...       3
# 3   Wow!! A fantastic place. We wandered for an ho...       5
# 4   Ordered regional menu with salad, sea bass and...       2
# 5   Stare into the windows of Le Grand Cafe des Né...       1
# 6   OMG! This place should be shut down before the...       1
# 7   I dine here each time in Lyon. Their andouiett...       5
# 8   Our experience here was awesome! Everything ab...       5
# 9   The tandoori sandwich was a delicious spin on ...       4
# 10  Excellent food for the wandering traveler sick...       5
# 11  Best Lebanese place in Lyon. Up to standard an...       5
# 12  Yes. Yes. And definitely yes. For those that o...       5
# 13  I was really intent on visiting La Cuisine whe...       5
# ...

# %%
DataAvisInsatisfaction1 = pd.concat([DataStrasbourg81a100, DataStrasbourg101a120])
DataAvisInsatisfaction1
# Out:
#                                                  text  rating
# 0   We really enjoyed the food.  A wide range of d...       5
# 1   Lovely find. Fantastic food so close to our ho...       5
# 2   No service, no food. 2 houtrs waiting for non ...       1
# 3   This place lives up to the great reviews. The ...       5
# 4   Went here when I was visiting for a couple day...       5
# ..                                                ...     ...
# 19  The first time I had foie gras was here and th...       4
# 20  Food is very good and the ambiance next to the...       3
# 21  This review is only based on their lack of any...       2
# 22  It's a decent bar just off the main island in ...       4
# 23  Wonderful find, an easy walk across a beautifu...       4
#
# [65 rows x 2 columns]

# %%
DataAvisInsatisfaction2 = pd.concat([DataStrasbourg241a260, DataStrasbourg361a380])
DataAvisInsatisfaction2
# Out:
#                                                  text  rating
# 0   The best lasagna I have ever had! Great staff,...       4
# 1   Everything in me wants to find something super...       2
# 2   great food, delicious dishes,fresh and prepare...       4
# 3   A little pricy but VERY GOOD! I used deliveroo...       4
# 4   It's harder to find a better place for a typic...       4
# 5   We wanted traditional Alsacien food and this r...       5
# 6   So glad we found this place! It's smaller and ...       5
# 7   I have been coming to that place since at leas...       4
# 8   Worst restaurant I have been to in a long time...       1
# 9   I like this spot. I have been going there sinc...       4
# 10  It's okay, not that impressive , like Tonkatsu...       2
# 11  This restaurant is an institution in Strasbour...       4
# 12  Tiffany location, I had the impresion no touri...       4
# 13  Very good, old restaurant. Everything you eat ...       4
# ...

# %%
DataAvisInsatisfaction3 = pd.concat([DataStrasbourg441a460, DataLyon101a120])
DataAvisInsatisfaction3
# Out:
#                                                  text  rating
# 0   Stay away from this place! My impression is al...       1
# 1   While strolling the streets of Strasbourg, my ...       3
# 2   Special Brazilian restaurant. Sometimes life m...       5
# 3   We were visiting Strasbourg FR, and wanted to ...       5
# 4   We made a reservation in August for November a...       1
# 5   Rotten vegetables in sushi. "Beef fromage' ske...       1
# 6   Filet steak was delicious!  Salad and potatoes...       4
# 7   The attendant was the meanest waitress I have ...       1
# 8   A traditional looking restaurant with nice ser...       3
# 0   Greasy as fuck, especially the veggy burger. T...       2
# 1   A local friend recommended this place to us. S...       5
# 2   I had read good things about Les Apothicaires....       4
# 3   Reservation only. Doesn't answer the phone for...       1
# 4   Exactly the kind of hearty meal I longed for w...       5
# ...

# %%
DataAvisInsatisfaction4 = pd.concat([DataLyon341a360, DataLyon561a580])
DataAvisInsatisfaction4
# Out:
#                                                  text  rating
# 0   Excellent place for a dinner with your " copin...       5
# 1   I wanted to be impressed but sadly the experie...       2
# 2   We completely stumbled into this place on a bu...       5
# 3   Stylish without being intimidating, with an up...       5
# 4   Says it is open except there is a sign on the ...       1
# 5   There's only one way to correctly experience t...       5
# 6   I've had quite a few Philly in various places ...       5
# 7   Its THE place to be. A lil noisy on Saturdays ...       5
# 8   It's a nice place to get a beer. The pizza was...       4
# 9   Loved this hotel. Took my Boyfriend here for a...       5
# 10  Bugs crawling in my breakfast delivered to roo...       1
# 11  Very bad customer service. We have booked one ...       1
# 12  We stopped here for brunch on the way to the p...       5
# 13  I have made this one of my favorite wine bars ...       4
# ...

# %%
DataAvisInsatisfaction5 = pd.concat([DataLyon641a660, DataLyon681a700])
DataAvisInsatisfaction5
# Out:
#                                                  text  rating
# 0   Was in a dinner with friends. Tried fondue, a ...       4
# 1   The staff is friendly and welcoming! Our serve...       4
# 2   Great wait staff friendly attentive offered wi...       5
# 3   Exceptionaly good! Refined Thai cuisine. Too b...       5
# 4   Highly recommend this place in Lyon. Pretty in...       5
# 5   WARNING! Bad food and violence! Food was discu...       1
# 6   Don't eat here. Pleasant appearing location ca...       1
# 7   Sometimes it would be good to check Yelp in ad...       1
# 8   These guys are passionate about wine! They spe...       5
# 9   If you are looking for a place to enjoy local ...       4
# 10  Worst Indian food ever!!! You don't get to cho...       1
# 11  This place has surprisingly excellent shareabl...       4
# 12  After buying a €10 cocktail and waiting 40 min...       1
# 13  Cute  ramen place that's brightly lighted, ser...       3
# ...

# %%
DataAvisInsatisfactionA = pd.concat([DataAvisInsatisfaction1, DataAvisInsatisfaction2])
DataAvisInsatisfactionA
# Out:
#                                                  text  rating
# 0   We really enjoyed the food.  A wide range of d...       5
# 1   Lovely find. Fantastic food so close to our ho...       5
# 2   No service, no food. 2 houtrs waiting for non ...       1
# 3   This place lives up to the great reviews. The ...       5
# 4   Went here when I was visiting for a couple day...       5
# ..                                                ...     ...
# 19  On a recent visit to Strasbourg, a friend was ...       5
# 20  very nice place, for 30+ yrs... good atmospher...       4
# 21  The place is clean and quaint. Service was ter...       3
# 22  We waited 40min to receive our food. They mixe...       1
# 23  Torricelli Restaurant\nAvoid this restaurant -...       1
#
# [115 rows x 2 columns]

# %%
DataAvisInsatisfactionB = pd.concat([DataAvisInsatisfaction3, DataAvisInsatisfaction4])
DataAvisInsatisfactionB
# Out:
#                                                  text  rating
# 0   Stay away from this place! My impression is al...       1
# 1   While strolling the streets of Strasbourg, my ...       3
# 2   Special Brazilian restaurant. Sometimes life m...       5
# 3   We were visiting Strasbourg FR, and wanted to ...       5
# 4   We made a reservation in August for November a...       1
# ..                                                ...     ...
# 19  I love the experience of dining where the loca...       4
# 20  To be honest,the food is amazing,but I didn't ...       3
# 21  Our server moved past service-oriented directl...       1
# 22  Great Indian food on the river.  The portions ...       4
# 23  Bistro des Voraces was the only restaurant we ...       5
#
# [91 rows x 2 columns]

# %%
DataAvisInsatisfactionAB = pd.concat([DataAvisInsatisfactionA, DataAvisInsatisfactionB])
DataAvisInsatisfactionAB
# Out:
#                                                  text  rating
# 0   We really enjoyed the food.  A wide range of d...       5
# 1   Lovely find. Fantastic food so close to our ho...       5
# 2   No service, no food. 2 houtrs waiting for non ...       1
# 3   This place lives up to the great reviews. The ...       5
# 4   Went here when I was visiting for a couple day...       5
# ..                                                ...     ...
# 19  I love the experience of dining where the loca...       4
# 20  To be honest,the food is amazing,but I didn't ...       3
# 21  Our server moved past service-oriented directl...       1
# 22  Great Indian food on the river.  The portions ...       4
# 23  Bistro des Voraces was the only restaurant we ...       5
#
# [206 rows x 2 columns]

# %%
DataAvisInsatisfactionLyonStrasbourg = pd.concat([DataAvisInsatisfactionAB, DataAvisInsatisfaction5])
DataAvisInsatisfactionLyonStrasbourg
# Out:
#                                                  text  rating
# 0   We really enjoyed the food.  A wide range of d...       5
# 1   Lovely find. Fantastic food so close to our ho...       5
# 2   No service, no food. 2 houtrs waiting for non ...       1
# 3   This place lives up to the great reviews. The ...       5
# 4   Went here when I was visiting for a couple day...       5
# ..                                                ...     ...
# 24  Came here 4adults and 4 kids for a late lunch ...       3
# 25  A bit of a hike from the main tourist area, bu...       3
# 26  Fab place! Big tasty pizzas, and great staff. ...       5
# 27  My husband and I were craving pizza after a fo...       5
# 28  Hands down the worst experience in service tha...       1
#
# [251 rows x 2 columns]

# %%
DataAvisInsatisfactionLyonStrasbourg.to_csv('P6_01_2_DataAvisInsatisfactionLyonStrasbourg.csv', index = False)

# %%
#  Données  DataAvisInsatisfactionParisMarseille
DataAvisInsatisfactionParisMarseille = pd.read_csv('P6_01_2_DataAvisInsatisfactionParisMarseille.csv', sep = ',', low_memory=False )
print('forme des données DataAvisInsatisfactionParisMarseille: ', DataAvisInsatisfactionParisMarseille.shape)
DataAvisInsatisfactionParisMarseille.head(10)
# Out:
# forme des données DataAvisInsatisfactionParisMarseille:  (423, 2)
#                                                 text  rating
# 0  Wanna snuggle up to someone while sharing an i...       5
# 1  Went here on a whim and it was a wise choice! ...       5
# 2  Stumbled upon Freddy's on our first night in P...       5
# 3  La Poule au Pot made our last night in Paris r...       5
# 4  Our experience was excellent. The food was ter...       4
# 5  Noooooo, no no. Was really excited to try this...       1
# 6  Stopped by for a very late dinner a few evenin...       4
# 7  *Caveat- this is a review from an American tou...       2
# 8  Le Bonaparte is fine. Nothing incredible. Food...       3
# 9  MUMI is seriously such an awesome place! And i...       5

# %%
#  Données  DataAvisInsatisfactionLyonStrasbourg
DataAvisInsatisfactionLyonStrasbourg = pd.read_csv('P6_01_2_DataAvisInsatisfactionLyonStrasbourg.csv', sep = ',', low_memory=False )
print('forme des données DataAvisInsatisfactionLyonStrasbourg: ', DataAvisInsatisfactionLyonStrasbourg.shape)
DataAvisInsatisfactionLyonStrasbourg.head(10)
# Out:
# forme des données DataAvisInsatisfactionLyonStrasbourg:  (251, 2)
#                                                 text  rating
# 0  We really enjoyed the food.  A wide range of d...       5
# 1  Lovely find. Fantastic food so close to our ho...       5
# 2  No service, no food. 2 houtrs waiting for non ...       1
# 3  This place lives up to the great reviews. The ...       5
# 4  Went here when I was visiting for a couple day...       5
# 5  Such a great Burger joint! \nMake a reservatio...       4
# 6  Great burger, cooked correctly and a tasty, fr...       4
# 7  I had to review this newly opened burger joint...       4
# 8  Excellent low key pub away from the main touri...       5
# 9  Great burgers, kid friendly, and they even let...       5

# %%
DataAvisInsatisfaction = pd.concat([DataAvisInsatisfactionParisMarseille, DataAvisInsatisfactionLyonStrasbourg])
DataAvisInsatisfaction
# Out:
#                                                   text  rating
# 0    Wanna snuggle up to someone while sharing an i...       5
# 1    Went here on a whim and it was a wise choice! ...       5
# 2    Stumbled upon Freddy's on our first night in P...       5
# 3    La Poule au Pot made our last night in Paris r...       5
# 4    Our experience was excellent. The food was ter...       4
# ..                                                 ...     ...
# 246  Came here 4adults and 4 kids for a late lunch ...       3
# 247  A bit of a hike from the main tourist area, bu...       3
# 248  Fab place! Big tasty pizzas, and great staff. ...       5
# 249  My husband and I were craving pizza after a fo...       5
# 250  Hands down the worst experience in service tha...       1
#
# [674 rows x 2 columns]

# %%
DataAvisInsatisfaction.shape
# Out:
# (674, 2)

# %%
DataAvisInsatisfaction.to_csv('P6_01_2_DataAvisInsatisfaction.csv', index = False)

# %%
#  Données  DataAvisInsatisfaction
DataAvisInsatisfaction = pd.read_csv('P6_01_2_DataAvisInsatisfaction.csv', sep = ',', low_memory=False )
print('forme des données DataAvisInsatisfaction: ', DataAvisInsatisfaction.shape)
DataAvisInsatisfaction.head(10)
# Out:
# forme des données DataAvisInsatisfaction:  (674, 2)
#                                                 text  rating
# 0  Wanna snuggle up to someone while sharing an i...       5
# 1  Went here on a whim and it was a wise choice! ...       5
# 2  Stumbled upon Freddy's on our first night in P...       5
# 3  La Poule au Pot made our last night in Paris r...       5
# 4  Our experience was excellent. The food was ter...       4
# 5  Noooooo, no no. Was really excited to try this...       1
# 6  Stopped by for a very late dinner a few evenin...       4
# 7  *Caveat- this is a review from an American tou...       2
# 8  Le Bonaparte is fine. Nothing incredible. Food...       3
# 9  MUMI is seriously such an awesome place! And i...       5

# %%
DataAvisInsatisfaction[DataAvisInsatisfaction.rating == 5].sum
# Out:
# <bound method DataFrame.sum of                                                   text  rating
# 0    Wanna snuggle up to someone while sharing an i...       5
# 1    Went here on a whim and it was a wise choice! ...       5
# 2    Stumbled upon Freddy's on our first night in P...       5
# 3    La Poule au Pot made our last night in Paris r...       5
# 9    MUMI is seriously such an awesome place! And i...       5
# ..                                                 ...     ...
# 664  If you are in Lyon this is the best place to e...       5
# 665  Simply fantastic. Wonderful service. Excellent...       5
# 667  Very friendly and Delicious food!  Good place ...       5
# 671  Fab place! Big tasty pizzas, and great staff. ...       5
# 672  My husband and I were craving pizza after a fo...       5
#
# [349 rows x 2 columns]>

# %%
DataAvisInsatisfaction[DataAvisInsatisfaction.rating == 4].sum
# Out:
# <bound method DataFrame.sum of                                                   text  rating
# 4    Our experience was excellent. The food was ter...       4
# 6    Stopped by for a very late dinner a few evenin...       4
# 14   Small cafe offering lunch and dinner in a bist...       4
# 18   Great little neighborhood spot serving organic...       4
# 35   Man, AT beat me to this one! He was the first ...       4
# ..                                                 ...     ...
# 659  Enjoyed dinner with three other folks here yes...       4
# 661  Aklé (the food truck) is at my nearby market e...       4
# 662  I searched for this food truck for hours and o...       4
# 666  I've been here twice with my family. The staff...       4
# 668  Great selection of wines, actually so many you...       4
#
# [161 rows x 2 columns]>

# %%
DataAvisInsatisfaction[DataAvisInsatisfaction.rating == 3].sum
# Out:
# <bound method DataFrame.sum of                                                   text  rating
# 8    Le Bonaparte is fine. Nothing incredible. Food...       3
# 11   Great food. Great service. Bad sommelier. Cork...       3
# 49   My husband and I popped into this cute cafe af...       3
# 52   Located on the northern tip of the Ile de la C...       3
# 71   This place i just OK.  No idea why people give...       3
# 87   No pretense ~ this restaurant delivers on exac...       3
# 91   The restaurant is setup like a giant cafeteria...       3
# 112  The atmosphere was nice and it seemed to attra...       3
# 152  OVERALL: I really debated about this rating, b...       3
# 175  Good burgers, but the fries were dry.\nThe moj...       3
# 180  Ducked into A Jean Nicot after a day at the Lo...       3
# 191  The atmosphere was very calm. Nice place to un...       3
# 206  Slow service..ok food, small portions \n\nRude...       3
# ...

# %%
DataAvisInsatisfaction[DataAvisInsatisfaction.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                   text  rating
# 7    *Caveat- this is a review from an American tou...       2
# 40   What a let down! Stuffy, old fashioned, past i...       2
# 41   Here's what is great about Tour d"Argent. The ...       2
# 73   Very nice service and good appetizers, unfortu...       2
# 74   This place was just average. The mushroom soup...       2
# 90   We are Ramen Lovers, we have tried ramen in ma...       2
# 109  We were, of course, drawn by the history of th...       2
# 135  We had a nice sneeze platter to start. That wa...       2
# 200  Happened to stumble upon this cute restaurant,...       2
# 212  They are open from 10.30 am - not from 8.30 li...       2
# 228  This place was extremely busy on a Saturday ni...       2
# 256  I ended up here without a plan, just chose it ...       2
# 270  Meh. Very inattentive and at times even brusk ...       2
# ...

# %%
DataAvisInsatisfaction[DataAvisInsatisfaction.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                   text  rating
# 5    Noooooo, no no. Was really excited to try this...       1
# 22   This place succeeded in one thing with flying ...       1
# 44   I came. I sat after speaking to wait staff abo...       1
# 67   I ate here many years ago, when I lived in Par...       1
# 96   Reused bread in basket w jam on it. When told ...       1
# ..                                                 ...     ...
# 639  Worst Indian food ever!!! You don't get to cho...       1
# 641  After buying a €10 cocktail and waiting 40 min...       1
# 650  Stare into the windows of Le Grand Cafe des Né...       1
# 651  OMG! This place should be shut down before the...       1
# 673  Hands down the worst experience in service tha...       1
#
# [74 rows x 2 columns]>

# %%
#  Données  DataAvisInsatisfaction
DataAvisInsatisfaction = pd.read_csv('P6_01_2_DataAvisInsatisfaction.csv', sep = ',', low_memory=False )
print('forme des données DataAvisInsatisfaction: ', DataAvisInsatisfaction.shape)
DataAvisInsatisfaction.head(10)
# Out:
# forme des données DataAvisInsatisfaction:  (674, 2)
#                                                 text  rating
# 0  Wanna snuggle up to someone while sharing an i...       5
# 1  Went here on a whim and it was a wise choice! ...       5
# 2  Stumbled upon Freddy's on our first night in P...       5
# 3  La Poule au Pot made our last night in Paris r...       5
# 4  Our experience was excellent. The food was ter...       4
# 5  Noooooo, no no. Was really excited to try this...       1
# 6  Stopped by for a very late dinner a few evenin...       4
# 7  *Caveat- this is a review from an American tou...       2
# 8  Le Bonaparte is fine. Nothing incredible. Food...       3
# 9  MUMI is seriously such an awesome place! And i...       5
