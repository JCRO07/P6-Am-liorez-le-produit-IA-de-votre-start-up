# %%
from urllib import request
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn import decomposition
from sklearn import preprocessing
sns.set()
# Python program to read 
# json file 
 
import json

# %% [markdown]
# # Données textes

# %% [markdown]
# # Données Paris

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis1a20 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis1a20 = json_normalize(DataDictParis1a20['search']['business'] , 'reviews',  max_level=1)
DataParis1a20
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I've been meaning to review this place forever...       5
# 1   This restaurant is simply amazing!!! If you ar...       5
# 2   I can't believe I never posted a review for my...       5
# 3   We loved this place - great food, reasonable, ...       5
# 4   They are known for their gratin and they sure ...       5
# 5   When I find myself in Paris, I am always a few...       5
# 6   Excellent falafel and shawarma joint. They hav...       5
# 7   This place is world famous!!! \n\nIt really is...       5
# 8   After seeing all the hype on the internet and ...       4
# 9   One of the best food I've ever had in Paris. O...       5
# 10  Paris is a place where food held at a high sta...       5
# ...

# %%
DataParis1a20[DataParis1a20.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 56  Let me start by saying the service was great a...       2>

# %%
DataParis1a20[DataParis1a20.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 22  What a bad experience. After waiting for an ho...       1
# 34  I went into this place because other Yelpers s...       1
# 35  To be quite honest, please pass on this spot, ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 21 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis21a40 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis21a40 = json_normalize(DataDictParis21a40['search']['business'] , 'reviews',  max_level=1)
DataParis21a40
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   A little hidden gem that is to die for! No jok...       5
# 1   Positives:\nFortnum and Mason Tea\nFriendly an...       4
# 2   Really cool environment, all the seating is up...       5
# 3   So I really wanted welks and this restaurant w...       4
# 4   Came here for the lobster roll and it wasn't t...       3
# 5   I'm from New York, where we pretty much made l...       5
# 6   Great sit down place with baguette sandwiches....       5
# 7   A gem in a super touristy section of town.  On...       4
# 8   Great food made with care and attention.  They...       4
# 9   I came here before the pandemic and needed to ...       5
# 10  Can't be in Paris without eating soufflé.\n\nB...       5
# ...

# %%
DataParis21a40[DataParis21a40.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 13  Rude service. But then again we are tourists i...       2>

# %%
DataParis21a40[DataParis21a40.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 17  Disappointing experience at Le Fumoir. \n\nYou...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 41 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis41a60 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis41a60 = json_normalize(DataDictParis41a60['search']['business'] , 'reviews',  max_level=1)
DataParis41a60
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I have come here multiple times.  Although it ...       5
# 1   Best dinner spot of my last trip to Paris, my ...       5
# 2   Love this place!  We went twice during our two...       5
# 3   This was one of our favorite restaurants in Pa...       5
# 4   My heart breaks that I'm giving this restauran...       2
# 5   We had a long layover in Paris and we found ou...       5
# 6   This is awesome. We love the food and the serv...       5
# 7   Absolutely amazingly cooked steak and fries wh...       5
# 8   OMG yesss! This place has it. Just go! Perfect...       5
# 9   Yelp 100 challenge 2020 #6\n\nThis one of the ...       4
# 10  Very typical Parisian decor and style, comfort...       4
# ...

# %%
DataParis41a60[DataParis41a60.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 4   My heart breaks that I'm giving this restauran...       2
# 30  My then Boyfriend had me sit here, while he we...       2>

# %%
DataParis41a60[DataParis41a60.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 61 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis61a80 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis61a80 = json_normalize(DataDictParis61a80['search']['business'] , 'reviews',  max_level=1)
DataParis61a80
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Really good waiters who are friendly and welco...       4
# 1   We had brunch here. It is just as it is on ins...       4
# 2   When I travel (esp internationally) I research...       5
# 3   During our weeklong Parisian stay, this place ...       5
# 4   Carpe Diem is a beautiful cafe. The atmosphere...       4
# 5   I was a little incredulous about how good this...       5
# 6   The falafels at this place are decent. It woul...       4
# 7   Breaking my yelp silence to argue that this mi...       5
# 8   Best breakfast we had in Paris!\n\nWe went twi...       5
# 9   We did not eat here, but I wanted to write thi...       4
# 10  Note this location doesn't have brunch food (t...       4
# ...

# %%
DataParis61a80[DataParis61a80.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 22  What a let down after reading the other review...       2>

# %%
DataParis61a80[DataParis61a80.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 81 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis81a100 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis81a100 = json_normalize(DataDictParis81a100['search']['business'] , 'reviews',  max_level=1)
DataParis81a100
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   It was 10pm and we were jet lagged and draggin...       5
# 1   I've been here twice and the noodles haven't d...       4
# 2   Some friends recommenced this restaurant. It h...       3
# 3   I'm a big fan of the Big Mamma Group restauran...       5
# 4   Nice and Cozy Place\n\nMy friend and I came he...       3
# 5   First thing first, the food here is DELICIOUS....       4
# 6   I dined here alone on a solo trip to Paris. Th...       5
# 7   #TakeMeBackTuesday - Remembering Paris...\n\nE...       4
# 8   We dropped in for an early pre-dinner drink bu...       5
# 9   For our last full day in Paris we decided to g...       5
# 10  Nothing special, it wasn't bad, just ABSOLUTEL...       4
# ...

# %%
DataParis81a100[DataParis81a100.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 25  Touristy crap food. There is no excuse for eat...       2>

# %%
DataParis81a100[DataParis81a100.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 11  We were looking forward to having dinner here,...       1
# 31  The dim sum has a lot of carb, no real meat in...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 101 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis101a120 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis101a120= json_normalize(DataDictParis101a120['search']['business'] , 'reviews',  max_level=1)
DataParis101a120
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Great customer service , warm welcoming and I ...       5
# 1   This was right around the corner from our apar...       5
# 2   So after subconsciously avoiding Breakfast in ...       5
# 3   I just had a wonderful lunch menu with full te...       5
# 4   I've been to quite a few award-winning restaur...       5
# 5   One star for restaurant inflexibility. \nMade ...       1
# 6   I don't care what the other reviews say, the f...       5
# 7   Absolutely perfect experience. Hidden behind t...       5
# 8   #2 best meal I have ever had! \n\nTook a recom...       5
# 9   Stopped here for dinner on our first night in ...       5
# 10  Delicious light airy pizza food but better. Th...       5
# ...

# %%
DataParis101a120[DataParis101a120.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 13  The food here was really bizarre. I love great...       2
# 32  As an Indonesian I was so excited to come acro...       2>

# %%
DataParis101a120[DataParis101a120.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 5   One star for restaurant inflexibility. \nMade ...       1
# 22  If I could give a negative 1 star I would. I'v...       1
# 52  I'm a tourist and I'm unfamiliar with the loca...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 121 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis121a140 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis121a140= json_normalize(DataDictParis121a140['search']['business'] , 'reviews',  max_level=1)
DataParis121a140
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Fantastic northern Thai cuisine on a side stre...       5
# 1   Lovely new Thai restaurant in the heart of Par...       5
# 2   After a long search for a quaint, local dinner...       5
# 3   Charming little spot with wonderful breakfast ...       5
# 4   Easy feeling cafe with friendly staff and supe...       4
# 5   We had a perfect eggs Benedict here!:-) we als...       5
# 6   Outstanding, quaint, Italian owned and managed...       5
# 7   Little restaurant \nAmazing food\nVery yummy\n...       5
# 8   Back again!! Returned after two years and had ...       5
# 9   Delicious food. Amazing staff. We had the thre...       5
# 10  Excellent food and service. No English menus, ...       5
# ...

# %%
DataParis121a140[DataParis121a140.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 51  My first review in yelp. This is a very nice p...       2>

# %%
DataParis121a140[DataParis121a140.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 18  My wife and I came here after hiking around Mo...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 141 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis141a160 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis141a160= json_normalize(DataDictParis141a160['search']['business'] , 'reviews',  max_level=1)
DataParis141a160
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Stopped in for lunch and we were glad we did. ...       4
# 1   They offer the possibility to try all three ty...       4
# 2   I FEEL IN LOVE WITH somek  (soju + beer), gogc...       4
# 3   Nice location to have a drink outside near Pom...       4
# 4   My wife and I enjoyed an excellent lunch here ...       5
# 5   We stopped here for lunch (myself, wife, daugh...       3
# 6   Cute and intimate space. We sat on the patio a...       4
# 7   Definitely one of our favorites in Paris - we'...       5
# 8   This place was recommended to me by a friend. ...       5
# 9   My husband and I discovered Bistrot Henri on o...       5
# 10  The hot chocolate here is indeed all that you'...       5
# ...

# %%
DataParis141a160[DataParis141a160.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 19  This was probably my most disappointing meal w...       2
# 44  Not sure how this place has a Michelin Star. S...       2
# 51  This was a disappointing experience. We had a ...       2>

# %%
DataParis141a160[DataParis141a160.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 32  Wow. Just wow. Let's start by saying we checke...       1
# 50  My boyfriend and I had the chicken and the duc...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 161 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis161a180 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis161a180= json_normalize(DataDictParis161a180['search']['business'] , 'reviews',  max_level=1)
DataParis161a180
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Wanna snuggle up to someone while sharing an i...       5
# 1   Went here on a whim and it was a wise choice! ...       5
# 2   Stumbled upon Freddy's on our first night in P...       5
# 3   La Poule au Pot made our last night in Paris r...       5
# 4   Our experience was excellent. The food was ter...       4
# 5   Noooooo, no no. Was really excited to try this...       1
# 6   Stopped by for a very late dinner a few evenin...       4
# 7   *Caveat- this is a review from an American tou...       2
# 8   Le Bonaparte is fine. Nothing incredible. Food...       3
# 9   MUMI is seriously such an awesome place! And i...       5
# 10  This restaurant is a find.  We had an amazing ...       5
# ...

# %%
DataParis161a180[DataParis161a180.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 7   *Caveat- this is a review from an American tou...       2
# 40  What a let down! Stuffy, old fashioned, past i...       2
# 41  Here's what is great about Tour d"Argent. The ...       2>

# %%
DataParis161a180[DataParis161a180.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 5   Noooooo, no no. Was really excited to try this...       1
# 22  This place succeeded in one thing with flying ...       1
# 44  I came. I sat after speaking to wait staff abo...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 181 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis181a200 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis181a200= json_normalize(DataDictParis181a200['search']['business'] , 'reviews',  max_level=1)
DataParis181a200
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   If you're looking for traditional hearty and u...       5
# 1   Took a long walk to get there but the food was...       5
# 2   Fun place. Food was basic bistro style. Beef s...       3
# 3   This place is the real deal. Casual (very casu...       5
# 4   Oh my god! The service was amazing. Our waiter...       5
# 5   Very good French food. Definitely try this pla...       5
# 6   Amazing food. Super coffee and friendly staff....       5
# 7   TINY but seating outside.  I was in Amsterdam ...       4
# 8   Neighbours is amazing! I loved this place. The...       5
# 9   I never imagined myself going to Paris to eat ...       5
# 10  Spotted this Japanese gem when eating at an am...       5
# ...

# %%
DataParis181a200[DataParis181a200.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 29  We had late lunch. We trusted the fact that th...       2>

# %%
DataParis181a200[DataParis181a200.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 201 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis201a220 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis201a220 = json_normalize(DataDictParis201a220['search']['business'] , 'reviews',  max_level=1)
DataParis201a220
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Classic french breakfast done right. \n\nFello...       4
# 1   Cute restaurant. Wonderful wait staff. Food is...       4
# 2   Very good but wished they had a lunch menu. I ...       4
# 3   So good! As a Texan, this definitely was Texas...       5
# 4   We were visiting from Texas and our apartment ...       5
# 5   Just like a little bit of the US in Paris (alt...       5
# 6   Wonderful, flavorful, plentiful meals in a stu...       5
# 7   I knew this Moroccan place for many years unde...       4
# 8   We felt the food was good but not exceptional....       3
# 9   Awesome pasta with mushrooms!!!  Pizza was goo...       5
# 10  Thought the place was open because it was brig...       1
# ...

# %%
DataParis201a220[DataParis201a220.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 58  TL:DR It's a TRAP!!! Find another French resta...       2>

# %%
DataParis201a220[DataParis201a220.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 10  Thought the place was open because it was brig...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 221 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis221a240 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis221a240 = json_normalize(DataDictParis221a240['search']['business'] , 'reviews',  max_level=1)
DataParis221a240
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   After 12 days in Europe these Californians wer...       5
# 1   Fajitas had quick service, friendly staff and ...       4
# 2   The food and service was very good! Definitely...       5
# 3   We had to get the snails since that is what al...       5
# 4   Wonderful food and kind and friendly service. ...       4
# 5   Le Relais du Louvre is a small, casual brasser...       4
# 6   I am a big fan of hidden gems. The Les Halles ...       5
# 7   I ate here many years ago, when I lived in Par...       1
# 8   Stopped into this bistro for lunch on a rainy ...       5
# 9   Just got back to my Airbnb from brunch here an...       5
# 10  An absolute must if you love fresh amazing foo...       5
# ...

# %%
DataParis221a240[DataParis221a240.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 13  Very nice service and good appetizers, unfortu...       2
# 14  This place was just average. The mushroom soup...       2
# 30  We are Ramen Lovers, we have tried ramen in ma...       2
# 49  We were, of course, drawn by the history of th...       2>

# %%
DataParis221a240[DataParis221a240.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 7   I ate here many years ago, when I lived in Par...       1
# 36  Reused bread in basket w jam on it. When told ...       1
# 58  Horrible experience.  Sat at the bar for 90 mi...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 241 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis241a260 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis241a260 = json_normalize(DataDictParis241a260['search']['business'] , 'reviews',  max_level=1)
DataParis241a260
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   More like 4.5 stars. \n\nSuper solid burger jo...       5
# 1   This burger spot is highly talked about, but t...       3
# 2   Such a great place! Went here on a Saturday wh...       5
# 3   When I moved in upstairs, I thought that it wa...       5
# 4   Hadn't realised it had been so long since our ...       4
# 5   This place was excellent. We had brunch and th...       5
# 6   I went to this restaurant back in 2014 and was...       5
# 7   What can I say about dinner at this restaurant...       5
# 8   So I did extensive research on all the platfor...       5
# 9   It's a REALLY tight space but has great oyster...       5
# 10  Friendly service but the oysters did not live ...       3
# ...

# %%
DataParis241a260[DataParis241a260.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataParis241a260[DataParis241a260.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 261 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis261a280 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis261a280 = json_normalize(DataDictParis261a280['search']['business'] , 'reviews',  max_level=1)
DataParis261a280
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   It's been a while since I have visited this pl...       5
# 1   This is a small neighborhood cafe. For that,  ...       4
# 2   Everything written is spot on. Love this place...       5
# 3   Great Thai food with authentic flavor, althoug...       4
# 4   Really friendly hosts. They speak English and ...       5
# 5   Food was nothing shy of amazing. I had the shr...       5
# 6   Stayed in Paris for 5 beautiful days and on th...       5
# 7   Here I am in Paris craving for asian food and ...       5
# 8   The best and our favorite is the "Riz au Boeuf...       5
# 9   I was at Roland Garros for the whole day...it ...       5
# 10  Fantastic little brasserie just a few blocks n...       4
# ...

# %%
DataParis261a280[DataParis261a280.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 20  Had the Mam'zelle and thought it was overly to...       2>

# %%
DataParis261a280[DataParis261a280.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 47  If you know what Mexican food taste like stay ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 281 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis281a300 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis281a300 = json_normalize(DataDictParis281a300['search']['business'] , 'reviews',  max_level=1)
DataParis281a300
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   The French don't mess with brunch. We got two ...       5
# 1   We only speak English but they explained they ...       5
# 2   Amazing food!! SUPER Friendly staff. It is dif...       5
# 3   Can we still be objective when we have known a...       5
# 4   Made a reservation for 7pm on Sunday evening, ...       5
# 5   I didn't make reservations but it seemed that ...       5
# 6   Amazing breakfast with a great selection of fu...       5
# 7   Lockwood was the best hidden gem in Paris! Thi...       5
# 8   Great chicken sandwich, and cocktails. Had the...       5
# 9   I thoroughly enjoyed my solo dinner here. I ma...       5
# 10  Just perfect. This restaurant is based on a gr...       5
# ...

# %%
DataParis281a300[DataParis281a300.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 11  Average at best compared to GOOD burritos, and...       2
# 14  We had reservations for a 7pm cruise along the...       2>

# %%
DataParis281a300[DataParis281a300.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 35  What do you do when you crave Korean food whil...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 301 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis301a320 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis301a320 = json_normalize(DataDictParis301a320['search']['business'] , 'reviews',  max_level=1)
DataParis301a320
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   The chicken here is done extremely well! The c...       5
# 1   A good find from your walk to the Pantheon. We...       5
# 2   Great food, even better service. Sirloin steak...       5
# 3   I figured Le Mary Celeste would be a popular p...       5
# 4   We were at a speakeasy and this place was reco...       4
# 5   Fantastic cocktail bar with exceptional small ...       5
# 6   Outstanding little gastro restaurant.  Chef fr...       5
# 7   Stopped here for a snack and cappuccino after ...       4
# 8   Our first meal in Paris, and among the very be...       5
# 9   This was my first true Parisian meal and it di...       5
# 10  I could probably live off two Choux and tea, i...       5
# ...

# %%
DataParis301a320[DataParis301a320.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 45  Waiter didn't speak English which is fine but ...       2>

# %%
DataParis301a320[DataParis301a320.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 15  A Ball of Béchamel. \n\nVery cute, cozy and co...       1
# 27  Not sure why this place has a 4 star rating. W...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 321 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis321a340 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis321a340 = json_normalize(DataDictParis321a340['search']['business'] , 'reviews',  max_level=1)
DataParis321a340
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Be prepared and most definitely have an open p...       4
# 1   Very good restaurant \n\nThe service was amazi...       3
# 2   Came here for our anniversary dinner.  Very ea...       5
# 3   So many cheeses and only one lunch to sample. ...       5
# 4   A great concept, cheese sourcing at its best f...       3
# 5   This place has one of the best cheese selectio...       5
# 6   I was walking around in the 9th arrondissement...       5
# 7   Yelp 100 challenge 2020 #15\n\nOmg!!!! I have ...       5
# 8   I loved this place! We had discovered it by ac...       5
# 9   I have never had such an incredible meal and w...       5
# 10  For three weeks my Parisian apartment was half...       5
# ...

# %%
DataParis321a340[DataParis321a340.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataParis321a340[DataParis321a340.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 341 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis341a360 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis341a360 = json_normalize(DataDictParis341a360['search']['business'] , 'reviews',  max_level=1)
DataParis341a360
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Wonderful meal with vegetables. Quick, tastefu...       5
# 1   Great food. Quick service. Friendly staff. Bes...       5
# 2   Amazing place! Great food- they speak English ...       5
# 3   First day in Paris and WOW!! This breakfast wa...       5
# 4   This restaurant is located near by the Sacrè- ...       4
# 5   Fantastic crepes! Any type of crepe, any way y...       4
# 6   My friend and I were looking for crêpes while ...       5
# 7   Exactly what it claims to be, a delicious crep...       5
# 8   So we decided this was going to be the place t...       4
# 9   Great find. The service was great and our serv...       5
# 10  This place is good for kids but I cannot recom...       2
# ...

# %%
DataParis341a360[DataParis341a360.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 10  This place is good for kids but I cannot recom...       2
# 18  Just ok. Had the crepe, artichoke cream (which...       2>

# %%
DataParis341a360[DataParis341a360.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 30  If I had to describe this meal in one word I t...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 361 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis361a380 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis361a380 = json_normalize(DataDictParis361a380['search']['business'] , 'reviews',  max_level=1)
DataParis361a380
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Great fancy atmosphere for dinner/drinks! We s...       4
# 1   My grandparents ate here over 30 years ago on ...       5
# 2   I made a reservation for a very late dinner on...       3
# 3   Sorza was a lovely experience! We made a reser...       4
# 4   Amazing restaurant. \n\nWe got the burrata sal...       5
# 5   From 12-7pm there are 1-3 course meal options ...       5
# 6   We had an amazing time here. The history alone...       5
# 7   Stunning Parisian restaurant - recently renova...       4
# 8   Honestly we were really disappointed. We came ...       3
# 9   Stopped into Norma for a pre-dinner cocktail. ...       4
# 10  I come here for a crepe every time I visit Par...       5
# ...

# %%
DataParis361a380[DataParis361a380.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataParis361a380[DataParis361a380.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 35  We stopped here for a glass of wine with a gro...       1
# 46  One of the worst experiences I've ever had in ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 381 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis381a400 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis381a400 = json_normalize(DataDictParis381a400['search']['business'] , 'reviews',  max_level=1)
DataParis381a400
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We just discovered a place that we will come b...       5
# 1   If you are going to be in Paris do yourself a ...       5
# 2   We've dined at L'Epigramme every time we're in...       5
# 3   Loved this place! Very close to the metro (sub...       5
# 4   Reservations for 8pm dinner on TheFork but rea...       3
# 5   Couldn't ask for better first meal in Paris. w...       4
# 6   We sat down outside and was waiting to be serv...       1
# 7   So happy I stumbled upon this restaurant!\n\nT...       4
# 8   Handmade Asian noodles and you could definitel...       3
# 9   Location: In the heart of the Marais, a short ...       2
# 10  Service was great, as was the food.  We ordere...       5
# ...

# %%
DataParis381a400[DataParis381a400.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 9   Location: In the heart of the Marais, a short ...       2
# 20  This is a very sad representation of French cu...       2
# 51  I am a total brunch fanatic and must try one p...       2>

# %%
DataParis381a400[DataParis381a400.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 6   We sat down outside and was waiting to be serv...       1
# 23  I am very disappointed here. I walked in alrea...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 401 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis401a420 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis401a420 = json_normalize(DataDictParis401a420['search']['business'] , 'reviews',  max_level=1)
DataParis401a420
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I really wanted to like this place.  However, ...       3
# 1   Had lunch here on our second to last day in Pa...       5
# 2   Exceptional in every way. Lan & Chef Denis con...       5
# 3   So, my wife and I were looking for a sushi/mak...       5
# 4   Food was ok. It was my first time having sushi...       3
# 5   I am a bit confused why this place has great r...       3
# 6   What a nice, satisfying change from traditiona...       4
# 7   Tried the duck confit entree which came with g...       4
# 8   I want to go back already & it's been less tha...       5
# 9   A bit of a trek from the tourist spots, this l...       5
# 10  All round good casual food with a fun local ec...       4
# ...

# %%
DataParis401a420[DataParis401a420.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 13  Ok this place is way over rated. We searched "...       2
# 39  Good food, friendly staff. Terribly place to g...       2>

# %%
DataParis401a420[DataParis401a420.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 36  We were looking forward to trying Senegalese f...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 421 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis421a440 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis421a440= json_normalize(DataDictParis421a440['search']['business'] , 'reviews',  max_level=1)
DataParis421a440
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Stepped off a tour bus at almost 930pm in sear...       5
# 1   When A TON of Paris is closed in August, Saigo...       5
# 2   Hidden place that you can feel like your back ...       5
# 3   A gastronomic delight for lovers of fine dinin...       5
# 4   Experience of a lifetime for me! The staff was...       5
# 5   Unbelievable food coupled with unmatched servi...       5
# 6   I was a bit unsure when we first got to La Com...       5
# 7   Hit or miss at La Comete, the first time I wen...       3
# 8   So... I just don't understand all the terrific...       2
# 9   My absolute FAVORITE restaurant in Paris!  Whe...       5
# 10  Le Petit Pontoise was a fabulous first meal in...       5
# ...

# %%
DataParis421a440[DataParis421a440.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 8   So... I just don't understand all the terrific...       2
# 14  The restaurant's architecture, stained glass c...       2>

# %%
DataParis421a440[DataParis421a440.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 20  This was bad! Our waiter explained that \n"Ooh...       1
# 51  This is an open letter to the owner of L'Auber...       1
# 52  So yelp filtered this place out as having a Mi...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 441 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis441a460 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis441a460 = json_normalize(DataDictParis441a460['search']['business'] , 'reviews',  max_level=1)
DataParis441a460
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   This is an awesome Korean restaurant in Le Mar...       5
# 1   This is an elegant, up-scale Korean bbq restau...       4
# 2   I have been to korean restaurants all over the...       5
# 3   The most delicious gluten free bread, the vari...       5
# 4   100% gluten free restaurant and bakery in Pari...       5
# 5   My girlfriend has a gluten allergy and we stum...       5
# 6   We came here based on Yelp reviews and were lo...       5
# 7   You gotta try this place! They are popular for...       5
# 8   I was brought here by a friend who promised me...       4
# 9   I'm surprised I'm only the second review in ni...       5
# 10  I came here with my husband to meet a few of h...       5
# ...

# %%
DataParis441a460[DataParis441a460.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 53  We stopped to eat here after hours of walking ...       2>

# %%
DataParis441a460[DataParis441a460.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 42  Terrible experience. The service was very bad ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 461 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis461a480 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis461a480 = json_normalize(DataDictParis461a480['search']['business'] , 'reviews',  max_level=1)
DataParis461a480
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Lovely place for a meal & dessert!! Wine and c...       5
# 1   I don't dole our 5 stars randomly. It represen...       5
# 2   Those little hot pockets of gem!!! It was a li...       4
# 3   4-1/2 stars.\n\nIt'd been a long while since I...       4
# 4   A great find about a 5 minute walk from the Lo...       5
# 5   If and when you need a break from all that del...       5
# 6   Simple breakfast options perfect for a day out...       5
# 7   Good place to eat while visiting the Latin Qua...       5
# 8   Outstanding restaurant near our hotel.. we hav...       5
# 9   I came here with my foodie friends who praised...       5
# 10  A last minute surge in RSVPs for a monthly ent...       5
# ...

# %%
DataParis461a480[DataParis461a480.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 49  I changed my original dinner reservation after...       2>

# %%
DataParis461a480[DataParis461a480.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 38  That was the worst meal I've ever had. \n\nSer...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 481 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis481a500 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis481a500 = json_normalize(DataDictParis481a500['search']['business'] , 'reviews',  max_level=1)
DataParis481a500
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Le Jardin Francais, located at the beautiful B...       5
# 1   Hotel recommendation. They were very accommoda...       5
# 2   I went there for lunch during my stay in paris...       4
# 3   Le Paris Halles Cafe was next door to my apart...       5
# 4   Half bottle of rose wine and an entire Regina ...       4
# 5   French food is almost a mythical thing ... you...       4
# 6   Good food, excellent service. Seating on the p...       5
# 7   One of the best places I ate at in France.  Th...       5
# 8   Delicious Italian. We were spoiled by 5-star f...       5
# 9   Thank you Yelp for helping us find this gem of...       5
# 10  What a treat ! I've been to so many restaurant...       4
# ...

# %%
DataParis481a500[DataParis481a500.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 27  Skip this place. Not very expensive, about ~18...       2
# 38  We were warned not to dine in Montmartre becau...       2
# 54  After a long day of walking around, we had no ...       2>

# %%
DataParis481a500[DataParis481a500.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 26  French Breakfast is a scam. 7.5 Euros for a ti...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 501 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis501a520 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis501a520 = json_normalize(DataDictParis501a520['search']['business'] , 'reviews',  max_level=1)
DataParis501a520
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Comptoir Colonial is a wonderful, charming lit...       5
# 1   Incredibly expensive but very good.  Let's get...       4
# 2   Love the decor and the food. Made same day res...       5
# 3   The best Chinese restaurant in all of Paris (o...       5
# 4   We ate here 3 times in one week.... it was tha...       5
# 5   This is my favorite restaurant in the Marais. ...       5
# 6   This quaint little restaurant is a place where...       4
# 7   More like 3.75 stars - A bit pricey but good s...       4
# 8   This place has a great location going for it a...       4
# 9   Been craving xio long bao and was pleasantly s...       5
# 10  Ohhhh I just love it!!! Great classic French f...       5
# ...

# %%
DataParis501a520[DataParis501a520.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 52  Food: Concierge at Hotel du Louvre recommended...       2>

# %%
DataParis501a520[DataParis501a520.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 41  It tasted funny, simply funny. I had a stomach...       1
# 51  Service is non existent.   I was shown to a ta...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 521 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis521a540 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis521a540 = json_normalize(DataDictParis521a540['search']['business'] , 'reviews',  max_level=1)
DataParis521a540
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We stopped in for coffee and crepes. Very nice...       5
# 1   A nice little spot right on the Seine river ac...       4
# 2   I have ordered the crepe Eiffel Tower which su...       1
# 3   Cute place by Jardin de Luxembourg.\nWe were l...       5
# 4   Some of the best food we've eaten in Paris. A ...       5
# 5   This place is a treasure. We are Americans in ...       5
# 6   Walked in on a Thursday night without a reserv...       4
# 7   I am happy to say that Ralph has improved sinc...       4
# 8   My mom and I are regulars at RL in Chicago so ...       4
# 9   Ambiance 5 star --\nThrow back music and great...       5
# 10  Had lunch here two days ago. Lovely location o...       1
# ...

# %%
DataParis521a540[DataParis521a540.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 16  We had a nice sneeze platter to start. That wa...       2>

# %%
DataParis521a540[DataParis521a540.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 2   I have ordered the crepe Eiffel Tower which su...       1
# 10  Had lunch here two days ago. Lovely location o...       1
# 19  Went here yesterday because of the great revie...       1
# 43  Stopped by for a Matcha Croissant and it was t...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 541 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis541a560 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis541a560 = json_normalize(DataDictParis541a560['search']['business'] , 'reviews',  max_level=1)
DataParis541a560
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Handydandy yelp Paris has pointed us in the ri...       5
# 1   After reading reviews of Verjus my impression ...       4
# 2   A great experience for a decadent night in Par...       5
# 3   We went to this restaurant after a recommendat...       5
# 4   Chez Marcel was recommendended by the concierg...       4
# 5   Rude front staff, we didn't have a reservation...       1
# 6   Yumm! All I can say. Real American burgers and...       5
# 7   You come here for...\n- An amazing happy hour:...       4
# 8   Good burgers, but the fries were dry.\nThe moj...       3
# 9   Came here for lunch and it exceeded all expect...       5
# 10  When I say I had the best meal of my life here...       5
# ...

# %%
DataParis541a560[DataParis541a560.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 33  Happened to stumble upon this cute restaurant,...       2
# 45  They are open from 10.30 am - not from 8.30 li...       2>

# %%
DataParis541a560[DataParis541a560.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 5   Rude front staff, we didn't have a reservation...       1
# 26  This is the absolute worst "Italian" restauran...       1
# 30  I was here with my 2 sisters, one of which it ...       1
# 32  Our experience was horrible. The taller man sa...       1
# 49  AMERICANS BEWARE. Our server ripped us off by ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 561 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis561a580 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis561a580 = json_normalize(DataDictParis561a580['search']['business'] , 'reviews',  max_level=1)
DataParis561a580
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   After going to a number of the busy cafe/brass...       5
# 1   It's so so so delicious which is beyond words....       5
# 2   Great dining experience with unbelievable serv...       5
# 3   It was like walking out of a movie theater bec...       2
# 4   Jus when we thought there could not be more at...       5
# 5   My monthly supper club made its way to this qu...       4
# 6   So after about a week of eating "French" and d...       5
# 7   After eating french food for every meal, I was...       5
# 8   We were so happy to have tried Vietnamese food...       5
# 9   Outstanding Dinner.\nWe came one Tuesday eveni...       5
# 10  Truly spectacular! My entree of slow cooked po...       5
# ...

# %%
DataParis561a580[DataParis561a580.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 3   It was like walking out of a movie theater bec...       2
# 45  As a New Yorker, I was excited when I stumbled...       2>

# %%
DataParis561a580[DataParis561a580.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 49  Not sure if this place changed hands or what, ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 581 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis581a600 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis581a600 = json_normalize(DataDictParis581a600['search']['business'] , 'reviews',  max_level=1)
DataParis581a600
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I don't know what to say except to say this pl...       5
# 1   Came here for dinner due to its vicinity to my...       2
# 2   My husband and I always love going to mom and ...       5
# 3   My fiancé was responsible for and quite obsess...       4
# 4   Good food.  Nice people.  We enjoyed dinner th...       5
# 5   All this was good:\n**snails \n**duck carpacci...       4
# 6   Love this place. We chose to come here because...       5
# 7   Very nice place, and the staff is very friendl...       3
# 8   By far one of the best places we ate at while ...       5
# 9   This restaurant is located in Marché in the Ma...       5
# 10  so far the best french meal i had in paris.\nt...       5
# ...

# %%
DataParis581a600[DataParis581a600.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 1  Came here for dinner due to its vicinity to my...       2>

# %%
DataParis581a600[DataParis581a600.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 601 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis601a620 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis601a620 = json_normalize(DataDictParis601a620['search']['business'] , 'reviews',  max_level=1)
DataParis601a620
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We stopped in for a glass of wine before dinne...       5
# 1   Very tight space - 5 seats at the bar and 6-8 ...       4
# 2   My favorite wine bar in Paris with a great sel...       5
# 3   Came here recently while my boyfriend and I we...       4
# 4   After my friend and I RESERVED a table at the ...       1
# 5   My husband and I had dinner at this restaurant...       5
# 6   It's a hole in the wall. 10 tables tops. Altho...       5
# 7   You had a great adventure today in paris and n...       5
# 8   I was in Europe for about a week and started t...       4
# 9   Amazing meal in a petite bistro. The owner see...       5
# 10  Such a wonderful evening.  The dinner was exce...       5
# ...

# %%
DataParis601a620[DataParis601a620.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 29  It's a typical, cheap cafe that you'd find in ...       2
# 45  There's five tables in this place. We didn't h...       2>

# %%
DataParis601a620[DataParis601a620.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 4   After my friend and I RESERVED a table at the ...       1
# 13  I'd give it no star if I could.\n\nThe worst r...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 621 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis621a640 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis621a640 = json_normalize(DataDictParis621a640['search']['business'] , 'reviews',  max_level=1)
DataParis621a640
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I had scoped out Blackburn as the closest coff...       5
# 1   This place was awful!  Service was disinterest...       1
# 2   If I could give this place 6 stars I would. Fr...       5
# 3   Made a reservation almost a month in advance. ...       5
# 4   So hubby and I dined here eight years ago and ...       4
# 5   Can't say enough about the team working here!\...       5
# 6   Don't let the lack of white table cloth fool y...       5
# 7   Taking the advice of Frederic, we got the  5 c...       5
# 8   Don't try to make your own decision from the m...       5
# 9   Bao + Burgers = MIND BLOWN\n\nWe ordered the "...       5
# 10  After a couple of days of French food we wante...       4
# ...

# %%
DataParis621a640[DataParis621a640.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataParis621a640[DataParis621a640.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 1   This place was awful!  Service was disinterest...       1
# 40  No one was in the restaurant.  \n\nWe came in,...       1
# 42  Only go there if you want your girlfriend to b...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 641 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis641a660 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis641a660 = json_normalize(DataDictParis641a660['search']['business'] , 'reviews',  max_level=1)
DataParis641a660
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   This open-air cafe became our go-to spot for l...       5
# 1   On our first full day in Paris, we woke up som...       4
# 2   We found this place last night during their ha...       5
# 3   CUTEST PLACE EVER!\nI miss this restaurant so ...       5
# 4   Came here on the recommendation of a friend wh...       3
# 5   The foie gras as an appetizer- this was the be...       3
# 6   Came here as a recommendation from a few frien...       5
# 7   I thought this restaurant was going to be a "t...       5
# 8   1 - MUST make Reservations Unless you are a CE...       5
# 9   We had a wonderful dinner at this lovely Bistr...       5
# 10  WOW! The marinated hangar steak is legitimatel...       5
# ...

# %%
DataParis641a660[DataParis641a660.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 17  I understand people are charmed by this cute, ...       2>

# %%
DataParis641a660[DataParis641a660.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 661 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis661a680 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis661a680 = json_normalize(DataDictParis661a680['search']['business'] , 'reviews',  max_level=1)
DataParis661a680
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Pain Perduuuu... this girl has been in France ...       5
# 1   After an initial bumpy first impression shortl...       5
# 2   You know what - when I come to Paris this is e...       4
# 3   We stayed in Paris for 9 days.. we had 5 meals...       5
# 4   We stumbled upon this cafe after wandering aro...       5
# 5   I had the best experience here. Down the stree...       5
# 6   If I had enough money (and patience), I would ...       5
# 7   Stopped by for a quick breakfast. I got severa...       3
# 8   We stopped here for some pastries while we wer...       3
# 9   Contrary to what other reviewers have written,...       4
# 10  My favorite restaurant in Paris. All meals are...       5
# ...

# %%
DataParis661a680[DataParis661a680.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataParis661a680[DataParis661a680.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 22  The Service was disappointing. The waiter let ...       1
# 34  Terrible service: we got inside and sat down, ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 681 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis681a700 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis681a700 = json_normalize(DataDictParis681a700['search']['business'] , 'reviews',  max_level=1)
DataParis681a700
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   5 Guys had better pray this place does not com...       5
# 1   Great chicken sandwich.  I added lettuce, toma...       5
# 2   12€ for bacon cheeseburger, fries and coke in ...       4
# 3   I've come to this place the last 2 times I've ...       5
# 4   Seafood was great. Warm food on a rainy day. S...       5
# 5   God awful food, but nice service. \n\nThe chic...       1
# 6   Awesome staff and very good risotto !!\n\nNice...       5
# 7   This restaurant is my favorite in all of Paris...       5
# 8   Excellent restaurant \nVery good place\nThe me...       5
# 9   I am surprised this has very few reviews here....       5
# 10  The skewered octopus was delicious, order it i...       4
# ...

# %%
DataParis681a700[DataParis681a700.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 38  The bagel was  pretty good, especially for a t...       2>

# %%
DataParis681a700[DataParis681a700.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 5  God awful food, but nice service. \n\nThe chic...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 701 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis701a720 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis701a720 = json_normalize(DataDictParis701a720['search']['business'] , 'reviews',  max_level=1)
DataParis701a720
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We stayed at Niepce Hotel. It was our last nig...       5
# 1   Decided to stay in for my one night stay in Pa...       4
# 2   What a meal! This place is a hidden gem that y...       5
# 3   We just got coffee and a coke.  My 23-year old...       5
# 4   Yummy! Our first dinner in Paris and it's one ...       5
# 5   Simply Great! Ate here multiple times during m...       5
# 6   Our first restaurant in Paris did not disappoi...       5
# 7   The restaurant nice, the staff is great to bri...       4
# 8   Okay.  So there's a common stereotype around F...       4
# 9   We happened to take a wrong turn and found thi...       5
# 10  We came here twice for breakfast because our h...       2
# ...

# %%
DataParis701a720[DataParis701a720.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 10  We came here twice for breakfast because our h...       2>

# %%
DataParis701a720[DataParis701a720.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 41  Terrible quality Chinese-run 'Japanese' restau...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 721 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis721a740 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis721a740 = json_normalize(DataDictParis721a740['search']['business'] , 'reviews',  max_level=1)
DataParis721a740
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Had our first dinner on our latest trip to Par...       5
# 1   My college friend recommended we try to place ...       4
# 2   This was our last night in Paris and the weath...       5
# 3   They don't do the Nutella expresso anymore! An...       2
# 4   Free WiFi, yes please.\nGood cappuccino from a...       5
# 5   Service and food here was next level. I was cr...       5
# 6   This place was heaven sent. We ate here on our...       5
# 7   Stoped in on a hot summer afternoon, while vac...       5
# 8   Apologies but review is a bit late... since my...       5
# 9   I had the most amazing experience here, with a...       5
# 10  We had a three course lunch here during a shor...       4
# ...

# %%
DataParis721a740[DataParis721a740.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 3   They don't do the Nutella expresso anymore! An...       2
# 27  Yea. No. Uninspired pre-cooked food served on ...       2>

# %%
DataParis721a740[DataParis721a740.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 741 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis741a760 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis741a760 = json_normalize(DataDictParis741a760['search']['business'] , 'reviews',  max_level=1)
DataParis741a760
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Five stars for the amazing fish soap that the ...       5
# 1   The ideal French bistro adding some flare to t...       5
# 2   - They speak English + have an English menu\n-...       4
# 3   This place opens early which is very nice if y...       5
# 4   I'm really not even sure where to begin! This ...       5
# 5   This place wAs an afterthought for us, but it ...       5
# 6   I come back to France twice a year and I alway...       5
# 7   Very good. I think they have a new menu everyd...       5
# 8   If you want a café crème in a quaint looking c...       1
# 9   It was my last night in Paris and I knew I wan...       4
# 10  Amazing small restaurant, with absolutely deli...       5
# ...

# %%
DataParis741a760[DataParis741a760.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataParis741a760[DataParis741a760.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 8  If you want a café crème in a quaint looking c...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 761 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis761a780 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis761a780 = json_normalize(DataDictParis761a780['search']['business'] , 'reviews',  max_level=1)
DataParis761a780
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   In a few words,\n\nThis was great: \n* Really ...       5
# 1   L'Encrier was recommended to me by my program ...       4
# 2   The food here is a solid 3-star, but the value...       4
# 3   La nourriture est délicieuse! Omg the best res...       5
# 4   Did we love this place??? Wi wi!!!!!! I wasn't...       5
# 5   This place was phenomenal. First off hats off ...       5
# 6   Recommended by our hotel's receptionist, La Ca...       5
# 7   Was recommended La Cantine by a friend! Sooooo...       5
# 8   Love this neighborhood bistro. First, the staf...       5
# 9   Ordered the escargot and had to come back a fe...       4
# 10  This place was extremely busy on a Saturday ni...       2
# ...

# %%
DataParis761a780[DataParis761a780.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 10  This place was extremely busy on a Saturday ni...       2
# 38  I ended up here without a plan, just chose it ...       2
# 52  Meh. Very inattentive and at times even brusk ...       2>

# %%
DataParis761a780[DataParis761a780.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 34  At the time of this review this place has 4.5 ...       1
# 35  Let's just say - disappointed and don't bother...       1
# 42  This was one of the worst meals I've had in Pa...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 781 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis781a800 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis781a800 = json_normalize(DataDictParis781a800['search']['business'] , 'reviews',  max_level=1)
DataParis781a800
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   During Ramadan, I only get one meal a day and ...       5
# 1   Great afghan food. Highly recommend making res...       5
# 2   Second time eating here which was just as good...       5
# 3   We were looking for a place to eat after visit...       5
# 4   This was, by far our favorite meal while we we...       5
# 5   Sister had mad cravings for cheese, and we dec...       3
# 6   This is a fantastic place for Indian food in t...       5
# 7   Delicious, affordable Indian food here! Close ...       4
# 8   The name is slightly deceptive - "Lakshmi Bhav...       5
# 9   One of the best and most memorable meals I hav...       5
# 10  One of the best meals we had in Paris...we wer...       5
# ...

# %%
DataParis781a800[DataParis781a800.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataParis781a800[DataParis781a800.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 30  We really had looked forward to trying this ne...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 801 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis801a820 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis801a820 = json_normalize(DataDictParis801a820['search']['business'] , 'reviews',  max_level=1)
DataParis801a820
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Really amazing place ! The owners/ server is r...       5
# 1   Amazing local bar. Great prices. Authentic nor...       5
# 2   Sweet owner, but the food lacked in quality. W...       1
# 3   Très bon\nExcellent service, excellente nourri...       4
# 4   We were taking a (phenomenal) macaron making c...       5
# 5   I was fortunate enough to have a local friend ...       5
# 6   This is a great find: very agreeable setting, ...       5
# 7   In early-February 2020 my husband and I went t...       5
# 8   Such a memorable meal. Obviously, there's a re...       5
# 9   This is one of the better Michelin star experi...       5
# 10  Best chicken and waffles joint in Paris. No ca...       5
# ...

# %%
DataParis801a820[DataParis801a820.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 35  I really wanted to like this place better, but...       2
# 47  Definitely not the best patisserie around. We ...       2>

# %%
DataParis801a820[DataParis801a820.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 2   Sweet owner, but the food lacked in quality. W...       1
# 42  I was beyond excited to come here due to the p...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 821 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis821a840 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis821a840 = json_normalize(DataDictParis821a840['search']['business'] , 'reviews',  max_level=1)
DataParis821a840
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   tl;dr: inventive, delicious, relaxed, low pric...       5
# 1   They were able to easily modify for gluten-fre...       4
# 2   I think we had on an off day experience here. ...       3
# 3   We ( family of 5) had the best time in this gr...       5
# 4   Excellent 3-course lunch, dessert and wine pai...       5
# 5   The food was unique and delicious. Service was...       5
# 6   Food:\nI ordered the Ribeye.  Ordered medium-r...       5
# 7   A lovely cafe. I stopped here to have a cafe c...       5
# 8   Thank god for Tabac de l'Université!! I was vi...       5
# 9   My favorite dinner experience this visit to Pa...       5
# 10  Small, intimate restaurant, with quality food ...       5
# ...

# %%
DataParis821a840[DataParis821a840.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 29  The cold brew coffee was not good--tasted like...       2
# 33  Writing on an average restaurant is probably t...       2>

# %%
DataParis821a840[DataParis821a840.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 23  Do not waste your time going here!!! Food is t...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 841 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis841a860 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis841a860 = json_normalize(DataDictParis841a860['search']['business'] , 'reviews',  max_level=1)
DataParis841a860
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   This is a in a square plaza at the base of Sac...       3
# 1   On my way up the stairs to visit the Sacré Coe...       5
# 2   Small cafe style restaurant. Most dining is ou...       4
# 3   Came for the carte blanche (six course tasting...       4
# 4   Understated, yet refined. Even with all the go...       5
# 5   Elegantly arranged next to each other, French ...       4
# 6   Fantastic. Excellent fish and chips; very, ver...       5
# 7   A few things about this place were really grea...       2
# 8   Decent French Brasserie. Great service and goo...       3
# 9   Great brand new bar nestled in a quiet street ...       5
# 10  Very nice bartenders, beautiful cocktails, coo...       5
# ...

# %%
DataParis841a860[DataParis841a860.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 7   A few things about this place were really grea...       2
# 35  EXPENSIVE...!!!  (and not worth it).\n\nI want...       2
# 38  Went in looking for something cheap with. Dece...       2>

# %%
DataParis841a860[DataParis841a860.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 34  Already a taste of scheming in the reviews, se...       1
# 36  Bad service. Expensive. Food is just okay. Not...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 861 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis861a880 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis861a880 = json_normalize(DataDictParis861a880['search']['business'] , 'reviews',  max_level=1)
DataParis861a880
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Great to see the rest of the world catching up...       5
# 1   5 stars because of a variety of reasons. As a ...       5
# 2   The burgers were mouthwatering and extremely f...       5
# 3   Popped into Fragments early one morning to sec...       5
# 4   An American style coffee shop in the Marais. V...       4
# 5   The most LA shop we've been to. Pretty small m...       4
# 6   Benoit is one of those classic French bistro b...       4
# 7   Came for lunch on a weekday - our waiter spoke...       4
# 8   If you want to go to a michelin star restauran...       3
# 9   Beautiful. Delicious Moroccan food. Lots of fl...       5
# 10  This place was AMAZING!!!!!! We got the lamb c...       5
# ...

# %%
DataParis861a880[DataParis861a880.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 50  We had to sit inside as all of the outside tab...       2>

# %%
DataParis861a880[DataParis861a880.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 881 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis881a900 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis881a900 = json_normalize(DataDictParis881a900['search']['business'] , 'reviews',  max_level=1)
DataParis881a900
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Food was affordable and good. Servers spoke En...       5
# 1   Not the first name I would have picked for a r...       4
# 2   Bohemian. Good steak and fries. Intellectual s...       4
# 3   I'll be straight up honest here - my favorite ...       3
# 4   Always excellent food and service.  I have bee...       5
# 5   Had high expectations for this place but the q...       3
# 6   Very chill spot!  The menu is pretty extensive...       4
# 7   I could not ask for a better dining experience...       5
# 8   €32 for a 3 course meal? This just might be th...       4
# 9   My wife and I found this little restaurant whi...       5
# 10  Wandurlust is hitting me hard right now, espec...       4
# ...

# %%
DataParis881a900[DataParis881a900.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 30  Was in the neighbourhood decided to stop by vi...       2>

# %%
DataParis881a900[DataParis881a900.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 901 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis901a920 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis901a920 = json_normalize(DataDictParis901a920['search']['business'] , 'reviews',  max_level=1)
DataParis901a920
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   In three words : Colombian soul food. \nDon't ...       5
# 1   Best restaurant in Paris! We were having a har...       5
# 2   Great food, great price, great people, and a g...       5
# 3   Delicious food, great atmosphere. And the wine...       4
# 4   Went here because of other Yelp reviews and wa...       3
# 5   I was visiting a nearby company for business a...       4
# 6   At the recommendation of our barista at Honor,...       5
# 7   Anthony Bourdain, if you've seen the Paris epi...       4
# 8   I was really excited to go to this restaurant ...       3
# 9   Little more than a small shop front with a cou...       5
# 10  Bonjour! This was our first meal in Paris and ...       4
# ...

# %%
DataParis901a920[DataParis901a920.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 24  A hype Parisian cafe in a prime shopping distr...       2>

# %%
DataParis901a920[DataParis901a920.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 921 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis921a940 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis921a940 = json_normalize(DataDictParis921a940['search']['business'] , 'reviews',  max_level=1)
DataParis921a940
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Woohoo!!!  I didn't think I'd find a real Span...       5
# 1   Great customer service and great choice for la...       4
# 2   The guy running this place is from Madrid and ...       4
# 3   I cant believe we were staying a block away an...       5
# 4   Stopped by for lunch during a visit to Notre D...       2
# 5   Wow! Awesome place to be in an Airbnb right ab...       5
# 6   What a wonderful place! My girlfriend and I we...       4
# 7   One of the beat Turkish restaurants in town, r...       5
# 8   Great location! Atmosphere was fantastic, as w...       5
# 9   Great meal and nice staff! First and foremost,...       5
# 10  Ate here not once but twice during my trip in ...       5
# ...

# %%
DataParis921a940[DataParis921a940.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 4   Stopped by for lunch during a visit to Notre D...       2
# 20  Came here with group of friends. We all had hi...       2
# 44  Baton Rouge got a fair amount of accolades bec...       2>

# %%
DataParis921a940[DataParis921a940.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 31  Don't walk away from this place, RUN!\nWas her...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 941 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis941a960 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis941a960 = json_normalize(DataDictParis941a960['search']['business'] , 'reviews',  max_level=1)
DataParis941a960
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I found this diamond of a restaurant on Yelp. ...       5
# 1   A delightful surprise!  I had the salad with d...       4
# 2   The beef bourguignon was excellent and my wife...       2
# 3   Up front, my perspective is that of an America...       5
# 4   The best steak and potatoes ya gratin I have e...       5
# 5   Great time to be had at CG!   So many factors ...       5
# 6   This was our first stop for good in Paris. It ...       5
# 7   Charming as hell (oops... I mean heck ) - quie...       4
# 8   People who visit me in Paris are always asking...       5
# 9   Delicious food, reasonable price and big porti...       5
# 10  On my second day visiting Paris, I stumbled up...       4
# ...

# %%
DataParis941a960[DataParis941a960.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 2   The beef bourguignon was excellent and my wife...       2
# 20  We arrived to this place being completely empt...       2
# 23  Totally disappointed.  We came in at 11pm and ...       2>

# %%
DataParis941a960[DataParis941a960.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 961 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis961a980 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis961a980 = json_normalize(DataDictParis961a980['search']['business'] , 'reviews',  max_level=1)
DataParis961a980
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I'm not going to lie- there was no way I was g...       3
# 1   Randomly came across this place on our walk to...       1
# 2   It's been a mixed experience and not at all wh...       1
# 3   Restaurant was recommended by local friends. S...       5
# 4   Although the chefs are talented at this restau...       1
# 5   It's a gem. It's the experience we were lookin...       5
# 6   American Tourist here.  \n\nSolid steak, price...       3
# 7   We started our night at the speakeasy that is ...       2
# 8   Coming from America I have a certain expectati...       2
# 9   We we're lucky enough to have been staying at ...       5
# 10  Hard to describe... Its like going home and as...       5
# ...

# %%
DataParis961a980[DataParis961a980.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 7  We started our night at the speakeasy that is ...       2
# 8  Coming from America I have a certain expectati...       2>

# %%
DataParis961a980[DataParis961a980.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 1   Randomly came across this place on our walk to...       1
# 2   It's been a mixed experience and not at all wh...       1
# 4   Although the chefs are talented at this restau...       1
# 32  Okay after reading all the fantastic reviews I...       1
# 34  This is a great restaurant unfortunately one o...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Paris", limit: 20, offset: 980 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictParis980a999 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataParis980a999 = json_normalize(DataDictParis980a999['search']['business'] , 'reviews',  max_level=1)
DataParis980a999
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   An awesome find in Paris! Was not expecting su...       5
# 1   Great little find while exploring new neighbor...       5
# 2   I've had better elsewhere and I wouldn't come ...       4
# 3   Thanks to fellow Yelpers we had dinner here to...       5
# 4   Great food! Great owners! My husband were in P...       5
# 5   Amazing restaurant and owners- the 2 brothers ...       5
# 6   Can I rate this place a 10 star please, just t...       5
# 7   Italian food on point! Came here to have a qui...       5
# 8   Review is for take away.\n\nGnocchi Sorentina ...       4
# 9   This was my absolute favorite place to go on m...       5
# 10  Found this place by completely by mistake.  Ba...       5
# ...

# %%
DataParis980a999[DataParis980a999.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataParis980a999[DataParis980a999.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %% [markdown]
# # Données Marseille

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille1a20 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille1a20 = json_normalize(DataDictMarseille1a20['search']['business'] , 'reviews',  max_level=1)
DataMarseille1a20
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   This place is sooo soo good.  It is located ri...       5
# 1   LOVED the cocktails here, with such a nice vie...       5
# 2   Great vib! Relaxed and good service good value...       5
# 3   We'd been working on the northern outskirts of...       5
# 4   Ok lunch in a pretty setting on the marina. Me...       3
# 5   Loved this place!  We wanted a fresh seafood p...       4
# 6   This has been our favorite dining experience i...       5
# 7   You just have to admire the one-man-army runni...       3
# 8   This place is absolutely amazing. It has 16 se...       5
# 9   After eating 3 course meals for dinner every n...       5
# 10  Small but great hole in the wall bar/bistro. N...       5
# ...

# %%
DataMarseille1a20[DataMarseille1a20.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille1a20[DataMarseille1a20.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 12  Worse chinese food ever! Don't go there.\nToo ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 21 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille21a40 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille21a40 = json_normalize(DataDictMarseille21a40['search']['business'] , 'reviews',  max_level=1)
DataMarseille21a40
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Very friendly and attentive place. You will ha...       4
# 1   This is the best restaurant in Marseille. In F...       5
# 2   Fourth time at this restaurant (which means I'...       2
# 3   My wife and I had the most scrumptious dinner ...       5
# 4   If you are looking to dine outdoors near the M...       4
# 5   This lovely bistro had wonderful outdoor seati...       5
# 6   What a great way to experience some true taste...       5
# 7   Fantastic food, simply prepared, excellent loc...       5
# 8   I came to here because of my B&B host recommen...       5
# 9   Très bon goût chez Guste!\nWorth th walk up hi...       5
# 10  This was an amazing find thanks to yelp. All t...       5
# ...

# %%
DataMarseille21a40[DataMarseille21a40.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 2   Fourth time at this restaurant (which means I'...       2
# 24  Average food, poor service. Had a jar of musse...       2>

# %%
DataMarseille21a40[DataMarseille21a40.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 14  We had a really bad experience just now. We or...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 41 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille41a60 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille41a60 = json_normalize(DataDictMarseille41a60['search']['business'] , 'reviews',  max_level=1)
DataMarseille41a60
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   This place is simply the definition of perfect...       5
# 1   I ordered seafoods spaghetti, I really don't l...       2
# 2   A little disappointed with our experience here...       2
# 3   The cute restaurant spills out onto the street...       4
# 4   An amazing simple Italian restaurant with such...       5
# 5   Had a wonderful swordfish carpaccio.  This was...       5
# 6   Great Italian food away from the tourist area....       4
# 7   Surprised to find a good Mexican restaurant on...       4
# 8   Another Tunisian restaurant, another jewel in ...       5
# 9   Our favorite restaurant in Marseille, where we...       5
# 10  Wonderful food and extremely friendly staff! I...       5
# ...

# %%
DataMarseille41a60[DataMarseille41a60.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 1   I ordered seafoods spaghetti, I really don't l...       2
# 2   A little disappointed with our experience here...       2
# 11  I wanted to like this place, I really did. Unf...       2
# 15  A few of the workers here are ok. They tried!!...       2
# 19  Very busy restaurant with a nice outdoor seati...       2>

# %%
DataMarseille41a60[DataMarseille41a60.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 14  This was the worst service and food we've had ...       1
# 27  Terrible service, they basically refused to se...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 61 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille61a80 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille61a80 = json_normalize(DataDictMarseille61a80['search']['business'] , 'reviews',  max_level=1)
DataMarseille61a80
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We had the most outstanding meal here: what a ...       5
# 1   Open late and on Sunday! Great place for a lat...       5
# 2   A good steakhouse in the trendy Cours Julien /...       3
# 3   Fantastic find! Very small kitchen, it was lik...       5
# 4   Dealt with our lack of French very patiently. ...       5
# 5   Went back again today just for wine post the d...       5
# 6   This night our search along the Old Port was f...       3
# 7   Incredible service and great fresh food. The o...       5
# 8   I'm leaning more towards a 2-star rating, but ...       3
# 9   3.5 stars!\nA little cafe located in a hidden ...       4
# 10  We went here strictly based on the yelp review...       5
# ...

# %%
DataMarseille61a80[DataMarseille61a80.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 41  Awful. Everything we received was borderline i...       2>

# %%
DataMarseille61a80[DataMarseille61a80.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 81 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille81a100 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille81a100 = json_normalize(DataDictMarseille81a100['search']['business'] , 'reviews',  max_level=1)
DataMarseille81a100
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Café Populaire in Marseille is located slightl...       5
# 1   Came here once with my colleagues and I was ve...       5
# 2   Great spot!\n\nThey even had a dancing crew ou...       4
# 3   Overrated\nI had heard so many great things ab...       3
# 4   Absolutely visit this restaurant when you are ...       5
# 5   I absolutely loved this place. Living not far ...       5
# 6   What an authentic delicious Lebanese food !! I...       5
# 7   Wonderful Traditional Magreb Food (North Afric...       5
# 8   Un mélange de cuisine chilienne et péruvienne ...       5
# 9   Ordered the Laap and mango sticky rice , so de...       5
# 10  According to my Airbnb host, Pizza Charly is M...       5
# ...

# %%
DataMarseille81a100[DataMarseille81a100.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 17  Our cruise ship docked at Marseille and we wan...       2
# 20  Let's be explicit: It's a tourist trap! I am s...       2>

# %%
DataMarseille81a100[DataMarseille81a100.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 101 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille101a120 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille101a120= json_normalize(DataDictMarseille101a120['search']['business'] , 'reviews',  max_level=1)
DataMarseille101a120
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   A must for seafood lovers. We came in for lunc...       5
# 1   Best king crab I've ever had. Service was frie...       5
# 2   It is such a great place to take real seafood!...       5
# 3   Cool little cafe. Very laidback and chill plac...       4
# 4   Great tasting food and fast, friendly, service...       5
# 5   Nice food but a little unorganized. If you ord...       4
# 6   Absolutely phenomenal, amazing, delicious, and...       5
# 7   Amidst the Creative Quarters, this little rest...       5
# 8   A bartender in Cour Julien recommended Café Vi...       4
# 9   Loved this little restaurant in the heart of M...       5
# 10  Amazing restaurant close to the Port Vieux. Th...       5
# ...

# %%
DataMarseille101a120[DataMarseille101a120.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 21  Not that good for the price (150 euro meal for...       2>

# %%
DataMarseille101a120[DataMarseille101a120.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 11  To be fair - we didn't eat there !   Sat down,...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 121 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille121a140 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille121a140= json_normalize(DataDictMarseille121a140['search']['business'] , 'reviews',  max_level=1)
DataMarseille121a140
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Stopped for lunch off the street. Great food, ...       5
# 1   One of the Best !\nI have been coming here for...       5
# 2   This restaurant was so lovely and delicious. I...       5
# 3   Personally, its one of the best foods I had in...       5
# 4   Nice, little place just outside the Opera Mars...       3
# 5   As a fellow burger enthusiast WOOOOOOW! This b...       5
# 6   Cmon yelpers. 4.5 out of 5 for this average af...       3
# 7   My husband and I laughed at ourselves for eati...       4
# 8   Wonderful dinner! My husband and I both had th...       5
# 9   Excellent dinner here. We arrived at 5 pm from...       4
# 10  What a pleasant night!5-star fusion mediterran...       5
# ...

# %%
DataMarseille121a140[DataMarseille121a140.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille121a140[DataMarseille121a140.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 141 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille141a160 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille141a160= json_normalize(DataDictMarseille141a160['search']['business'] , 'reviews',  max_level=1)
DataMarseille141a160
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   This is a perfect place for stupid tourists wh...       1
# 1   Could be the best couscous of Marseilles, a fa...       3
# 2   Absolutely delicious food and ridiculously lar...       4
# 3   Lovey dinner and spectacular view.  Duck was a...       5
# 4   We were excited to eat here to celebrate Fathe...       1
# 5   Stunning little seaside restaurant in Marseill...       3
# 6   I arrived late in Marseille and I was worried ...       5
# 7   Le Mas Lulli - this local pub/diner serves hea...       4
# 8   Delicious international cuisine! We were surpr...       5
# 9   Great service!! (the young lady was very sweet...       5
# 10  Quite disappointed with the quality of the foo...       3
# ...

# %%
DataMarseille141a160[DataMarseille141a160.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille141a160[DataMarseille141a160.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 0  This is a perfect place for stupid tourists wh...       1
# 4  We were excited to eat here to celebrate Fathe...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 161 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille161a180 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille161a180= json_normalize(DataDictMarseille161a180['search']['business'] , 'reviews',  max_level=1)
DataMarseille161a180
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Interesting little spot. I stopped in as a sol...       4
# 1   My husband and I had dinner here on a weeknigh...       5
# 2   Fantastic food, the owner is very nice and ext...       5
# 3   We came here on a Sunday afternoon around 130P...       4
# 4   I had a wonderful time dining here. The place ...       4
# 5   Surprisingly good lunch food. Very tasty pizza...       4
# 6   I don't see how such an awful restaurant can g...       1
# 7   Very nice place, service was very thoughtful. ...       4
# 8   I absolutely adore this place. From the exotic...       5
# 9   I happened upon L'Effet Clochette this afterno...       4
# 10  Excellent prixe-fix menu and wonderful wine.  ...       5
# ...

# %%
DataMarseille161a180[DataMarseille161a180.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille161a180[DataMarseille161a180.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 6   I don't see how such an awful restaurant can g...       1
# 17  Food is good but basic menu does not showcase ...       1
# 28  Horrible service! The waiters are rude and ver...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 181 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille181a200 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille181a200= json_normalize(DataDictMarseille181a200['search']['business'] , 'reviews',  max_level=1)
DataMarseille181a200
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   This restaurant is exquisite. The staff is so ...       5
# 1   We had an amazing dinner here on our last nigh...       5
# 2   One of my go to things to do when travelling t...       5
# 3   I loved it, big burgers, a lot of french fries...       5
# 4   Just what a burger place needs to be cheap hot...       5
# 5   This is the type of restaurant that I wish I c...       5
# 6   After visited the soap shop and picked up some...       5
# 7   Great value for money!\n\nWonderfull simple bu...       4
# 8   We dined at AM in 2015, on rare snowy night in...       5
# 9   What a surprising and delicious voyage !\nWe t...       5
# 10  tried the lunch tasting menu, what a great exp...       4
# ...

# %%
DataMarseille181a200[DataMarseille181a200.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille181a200[DataMarseille181a200.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 201 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille201a220 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille201a220 = json_normalize(DataDictMarseille201a220['search']['business'] , 'reviews',  max_level=1)
DataMarseille201a220
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  We picked up food, the guy is very nice and fr...       5
# 1  A near-perfect brunch. Great ambiance, a lovel...       4
# 2  Wow, after reading the reviews here we decided...       1
# 3  Good quality, good price, Vegetarian-friendly....       4
# 4  Was trying to help an old guy in the neighborh...       1
# 5  This is one of my favorite bars in Marseille, ...       5
# 6  I had probably the worst *tartar* in my life a...       1
# 7  A nice equipe, a good welcome, an atmosphere O...       4

# %%
DataMarseille201a220[DataMarseille201a220.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille201a220[DataMarseille201a220.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  Wow, after reading the reviews here we decided...       1
# 4  Was trying to help an old guy in the neighborh...       1
# 6  I had probably the worst *tartar* in my life a...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 221 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille221a240 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille221a240 = json_normalize(DataDictMarseille221a240['search']['business'] , 'reviews',  max_level=1)
DataMarseille221a240
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   A great dinner (exceptional the buillabaisse) ...       5
# 1   I wanted to try this place for a long time.\nF...       3
# 2   Just a few doors from our hotel - made the loc...       5
# 3   Fresh seafood, quick service, and reasonable p...       4
# 4   Excellent seafood! The clam pasta was one of t...       4
# 5   I went here in the evening before dinner time,...       5
# 6   Sometimes you hit the jackpot! We were wonderi...       5
# 7   Kind service and delicious food. I had vegetar...       5
# 8   One of the best places for steak. The sizes ar...       5
# 9   It's a great little place that's conveniently ...       4
# 10  In a lot of places in the world falafel is jus...       4
# ...

# %%
DataMarseille221a240[DataMarseille221a240.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille221a240[DataMarseille221a240.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 241 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille241a260 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille241a260 = json_normalize(DataDictMarseille241a260['search']['business'] , 'reviews',  max_level=1)
DataMarseille241a260
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   The lamb couscous is simply amazing. I order i...       5
# 1   A wonderful lunch locale with mouthwatering ro...       5
# 2   Without a doubt, this is the best restaurant f...       5
# 3   We stayed right above this restaurant in an Ai...       5
# 4   Fantastic meal and inviting staff.  Atmosphere...       5
# 5   This restaurant has very nice location, and at...       3
# 6   We were in Marseille for a week and loved this...       5
# 7   Wonderful little restaurant, specializing in w...       5
# 8   I had just about given up trying to find a goo...       5
# 9   After 10 days of French, Italian food it feels...       4
# 10  Good Indian !\nReviewer is new to Marseille, h...       4
# ...

# %%
DataMarseille241a260[DataMarseille241a260.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 16  Rip off. Good location, albeit touristy.\nUni ...       2>

# %%
DataMarseille241a260[DataMarseille241a260.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 17  You should avoid here as much as possible. \n\...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 261 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille261a280 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille261a280 = json_normalize(DataDictMarseille261a280['search']['business'] , 'reviews',  max_level=1)
DataMarseille261a280
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   O Tacos is o my goodness comfort food bliss. T...       5
# 1   Perfect location when you are keen on boats, m...       5
# 2   So awesome! All organic, simple, delicious and...       5
# 3   This place was really good. I am allergic to d...       5
# 4   I really do not get the name of this place. Gr...       3
# 5   Pros:\n-Good service\n-Clean\n-Nice atmosphere...       3
# 6   Really great dinner! Had the falafel, sausage ...       5
# 7   So missed Steak'n Shake! Been more than a year...       5
# 8   After walking up the hill to see the interesti...       5
# 9   Went on an afternoon during the World Cup so n...       4
# 10  Such a cool, well run bar for drinks or food. ...       5

# %%
DataMarseille261a280[DataMarseille261a280.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille261a280[DataMarseille261a280.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 281 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille281a300 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille281a300 = json_normalize(DataDictMarseille281a300['search']['business'] , 'reviews',  max_level=1)
DataMarseille281a300
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   double check hours! open saturday nights from ...       5
# 1   Food was delicious and service was great! I go...       5
# 2   We arrived today and needed somewhere close to...       3
# 3   When arrive a Friday evening at 9h30 pm to hav...       3
# 4   I wouldn't go here again. Pretty spot but the ...       2
# 5   My boyfriend and I ate here on a recent trip t...       4
# 6   I had the fish and chips. Everything arrived p...       3
# 7   Yes. Best burgers. Haven't tried too many rest...       5
# 8   A great hidden gem! It was our first night in ...       5
# 9   Took us a while to find something exciting clo...       5
# 10  What a great treasure!  Order at the kitchen, ...       5
# ...

# %%
DataMarseille281a300[DataMarseille281a300.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 4   I wouldn't go here again. Pretty spot but the ...       2
# 13  First off the food was okay. Not worthy of the...       2>

# %%
DataMarseille281a300[DataMarseille281a300.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 14  Ordered something that had an ingredient in it...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 301 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille301a320 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille301a320 = json_normalize(DataDictMarseille301a320['search']['business'] , 'reviews',  max_level=1)
DataMarseille301a320
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We only had two nights in Marseille and our ho...       5
# 1   Impeccable, delightful and inspiring.    Do no...       5
# 2   We arrived without a reservation our first nig...       5
# 3   For those of you who are unfamiliar, these are...       3
# 4   * Classic Bretonne creperie *\n\nA little bit ...       4
# 5   Beautiful music, warm atmosphere, delicious crêpe       4
# 6   Probably the best Thai food I have ever had. D...       5
# 7   The staff are so friendly and didn't mind that...       5
# 8   This is the best place we had in our 4 nights ...       5
# 9   Stopped in for lunch on Easter Sunday afternoo...       5
# 10  What a lovely place! I found it by accident wh...       5
# ...

# %%
DataMarseille301a320[DataMarseille301a320.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille301a320[DataMarseille301a320.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 321 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille321a340 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille321a340 = json_normalize(DataDictMarseille321a340['search']['business'] , 'reviews',  max_level=1)
DataMarseille321a340
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Innovative food , really original , although n...       5
# 1   May not be "traditional" but all our dishes we...       5
# 2   Nice place right in front of the plage. Food i...       4
# 3   Much better than expected. The Moules frites w...       4
# 4   On an honest scale, the food was a 4.  But add...       5
# 5   A great lunch spot. I had the red mullett and ...       5
# 6   Delicious food and a very friendly owner to ma...       5
# 7   This restaurant serves quintessentially French...       5
# 8   Since I was early, I was one of only two table...       4
# 9   We are visiting Marseille from America, and st...       5
# 10  Delicious. One of the best meals we have had y...       5
# ...

# %%
DataMarseille321a340[DataMarseille321a340.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille321a340[DataMarseille321a340.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 341 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille341a360 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille341a360 = json_normalize(DataDictMarseille341a360['search']['business'] , 'reviews',  max_level=1)
DataMarseille341a360
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Chami is a Syrian restaurant in the 3rd arrond...       4
# 1  Food poison!! Run run away don't go here. WORS...       1
# 2  Love this place.  Personalized attention from ...       5

# %%
DataMarseille341a360[DataMarseille341a360.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille341a360[DataMarseille341a360.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 1  Food poison!! Run run away don't go here. WORS...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 361 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille361a380 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille361a380 = json_normalize(DataDictMarseille361a380['search']['business'] , 'reviews',  max_level=1)
DataMarseille361a380
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   I went to O'Tacos because I had few options at...       1
# 1   We stayed at the Hotel Petit Nice Passedat, bu...       5
# 2   I loved this place! Originally, I found this r...       5
# 3   Service was great. The owner couple was full o...       4
# 4   O-pho was O-K. What were we supposed to do whe...       3
# 5   Delicious stop, loved the dumplings and egg ro...       5
# 6   The food was absolutely awful. Worst Pho I've ...       1
# 7   I love this restaurant.  As a first-time visit...       5
# 8   La Villa\n\n77+\n\nLa Villa\n\n4.3\n\n(156)\n\...       1
# 9   Good service and food that hit the spot. Betwe...       4
# 10  I had read a nice review about this place onli...       1
# ...

# %%
DataMarseille361a380[DataMarseille361a380.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 11  Well it started off with me ordering "a glass"...       2
# 12  Very much mediocre if not super market level s...       2>

# %%
DataMarseille361a380[DataMarseille361a380.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 0   I went to O'Tacos because I had few options at...       1
# 6   The food was absolutely awful. Worst Pho I've ...       1
# 8   La Villa\n\n77+\n\nLa Villa\n\n4.3\n\n(156)\n\...       1
# 10  I had read a nice review about this place onli...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 381 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille381a400 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille381a400 = json_normalize(DataDictMarseille381a400['search']['business'] , 'reviews',  max_level=1)
DataMarseille381a400
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Just a perfect evening in a perfect place\nExc...       4
# 1   The service is superb. Waiter was super friend...       5
# 2   Came in for breakfast at 9:30am but unfortunat...       4
# 3   We stopped in to have dessert and enjoy free w...       3
# 4   Nice place for enjoying a good pizza.desserts,...       3
# 5   I stayed at the Novotel Prado for a conference...       4
# 6   Tried contacting in regards to booking a confe...       1
# 7   You know, doing the sightseeing thing is tirin...       5
# 8   Awesome wine shop in one of the most beautiful...       5
# 9   A Rarity in Marseille\nThere are not that many...       4
# 10  Placed was closed in the middle of a Thursday ...       1

# %%
DataMarseille381a400[DataMarseille381a400.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille381a400[DataMarseille381a400.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 6   Tried contacting in regards to booking a confe...       1
# 10  Placed was closed in the middle of a Thursday ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 401 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille401a420 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille401a420 = json_normalize(DataDictMarseille401a420['search']['business'] , 'reviews',  max_level=1)
DataMarseille401a420
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  We went to the Rue des Trois Rois to have lunc...       3
# 1  Outstanding sandwiches and incredible homemade...       5
# 2  Tiny super cozy cafe - perfect for grabbing a ...       5
# 3  really a favorite of my copines et moi!  The s...       5
# 4  Excellent food, ambiance, and service! The lam...       4
# 5  Delicious seafood restaurant with a beautiful ...       4
# 6  This is a great place where food, site, servic...       5
# 7  Tasty vegan and gluten free option. After stru...       4

# %%
DataMarseille401a420[DataMarseille401a420.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille401a420[DataMarseille401a420.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 421 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille421a440 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille421a440= json_normalize(DataDictMarseille421a440['search']['business'] , 'reviews',  max_level=1)
DataMarseille421a440
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Traditional Japanese\nVery good sushi. These p...       4
# 1   The meal we had was one of the best we had so ...       4
# 2   Really nice. We shared a white pizza to start-...       4
# 3   Had a great lunch here. Situated across the st...       4
# 4   We chose 28 Euro menu. Cesare Salad was really...       2
# 5   This place is a sweet place to start the day i...       4
# 6   Service was so rude we just got up and left be...       1
# 7   We came in a recommendation from a local. This...       5
# 8   There are two restaurants.  One is a store fro...       5
# 9   Adele was so sweet and kind! And the ravioli a...       5
# 10  Super pub !\nCe pub était là avant que les pub...       5
# ...

# %%
DataMarseille421a440[DataMarseille421a440.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 4   We chose 28 Euro menu. Cesare Salad was really...       2
# 12  Don't Remember Much...\nI had visited the webs...       2>

# %%
DataMarseille421a440[DataMarseille421a440.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 6  Service was so rude we just got up and left be...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 441 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille441a460 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille441a460 = json_normalize(DataDictMarseille441a460['search']['business'] , 'reviews',  max_level=1)
DataMarseille441a460
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Great value with a casual atmosphere. One plat...       5
# 1   Super tasty döner, unbelievably affordable pri...       5
# 2   The food at this location is very reasonably p...       5
# 3   Very good view! You can look whole beautiful v...       5
# 4   Taste good, especially the appetizer tofu with...       4
# 5   Terrible environment and food. It is not a aut...       1
# 6   Disgusting and unsanitary! DO NOT GO HERE! \n\...       1
# 7   Excellent burger, excellent fries, good servic...       5
# 8   A really sweet little place. \n\nPros:\n-The s...       5
# 9   We had 2 cups of cappuccino. The cups where di...       2
# 10  Stopped here for a lunch, the Grilled Octopus ...       4
# ...

# %%
DataMarseille441a460[DataMarseille441a460.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 9   We had 2 cups of cappuccino. The cups where di...       2
# 12  Had an absolutely mediocre steak frites here f...       2>

# %%
DataMarseille441a460[DataMarseille441a460.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 5  Terrible environment and food. It is not a aut...       1
# 6  Disgusting and unsanitary! DO NOT GO HERE! \n\...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 461 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille461a480 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille461a480 = json_normalize(DataDictMarseille461a480['search']['business'] , 'reviews',  max_level=1)
DataMarseille461a480
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Could not find this restaurant! Looks like it'...       1
# 1  sweaty restaurant with an outdoor decoration v...       4
# 2  we had a delightful dinner here - the location...       3
# 3  We loved our experience here! Simplistic yet c...       5
# 4  well ????????\ni dont think that if you name y...       1

# %%
DataMarseille461a480[DataMarseille461a480.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille461a480[DataMarseille461a480.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 0  Could not find this restaurant! Looks like it'...       1
# 4  well ????????\ni dont think that if you name y...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 481 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille481a500 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille481a500 = json_normalize(DataDictMarseille481a500['search']['business'] , 'reviews',  max_level=1)
DataMarseille481a500
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Oh... my... god... \na must if you're in marse...       5
# 1   An old waiting room at the Saint Charles train...       2
# 2   Excellent!\nI was visiting France 2 weeks ago ...       4
# 3   a magical night\nyes it was we reserved our ta...       5
# 4   A perfect place for Saturday or Sunday lunch w...       4
# 5   Excellent\nThe best place i have ever been in ...       5
# 6   We wished had found this place earlier. It's r...       4
# 7   Good Food & Service, nice, clean and very conv...       5
# 8   Found this place while walking in the old port...       4
# 9   Dined here for dinner. The plate du jour was r...       5
# 10  First time I have ever had Corsican food, so I...       4

# %%
DataMarseille481a500[DataMarseille481a500.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 1  An old waiting room at the Saint Charles train...       2>

# %%
DataMarseille481a500[DataMarseille481a500.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 501 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille501a520 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille501a520 = json_normalize(DataDictMarseille501a520['search']['business'] , 'reviews',  max_level=1)
DataMarseille501a520
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We had bouillabaisse and a calamari salad\nFor...       3
# 1   Stopped in for lunch and it was an excellent c...       4
# 2   This cafe has a special place in my heart. I w...       4
# 3   My local host told me his number one choice fo...       5
# 4   I discovered this place by accident during the...       5
# 5   The worst ever !! I celebrated my 50th bday he...       1
# 6   I really enjoyed this place! It was close to a...       4
# 7   For 15.50 euros, you can have a homey multiple...       4
# 8   Stopped in with a family of 4 for a late after...       3
# 9   Adorable restaurant/store/cafe/art gallery in ...       3
# 10  Great alley location, off the beaten path. Del...       4
# ...

# %%
DataMarseille501a520[DataMarseille501a520.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille501a520[DataMarseille501a520.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 5  The worst ever !! I celebrated my 50th bday he...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 521 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille521a540 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille521a540 = json_normalize(DataDictMarseille521a540['search']['business'] , 'reviews',  max_level=1)
DataMarseille521a540
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Great view from panoramic window on first floo...       2
# 1  I would NEVER come here ....\n\nTried to make ...       1
# 2  The very best of Marseille.  Well represented ...       5
# 3  A random pitstop for lunch. Looked touristy bu...       3
# 4  All the worst things about hipsters crammed in...       1
# 5  This place is an amazing place to eat. I got a...       5
# 6  Outstanding customer service. Very friendly. I...       5
# 7  Super well located café across the Marseille S...       2
# 8  The owner gave me ice for my water bottle when...       5
# 9  Apart from the fact that the food tested great...       5

# %%
DataMarseille521a540[DataMarseille521a540.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 0  Great view from panoramic window on first floo...       2
# 7  Super well located café across the Marseille S...       2>

# %%
DataMarseille521a540[DataMarseille521a540.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 1  I would NEVER come here ....\n\nTried to make ...       1
# 4  All the worst things about hipsters crammed in...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 541 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille541a560 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille541a560 = json_normalize(DataDictMarseille541a560['search']['business'] , 'reviews',  max_level=1)
DataMarseille541a560
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Buffet style Middle eastern (Egyptian?) food. ...       5
# 1  We stopped on for breakfast around 10:30am on ...       5
# 2  decent place in the center of Marseille. in th...       4
# 3  This affordable and simple pizzeria has absolu...       5
# 4  Definitely was impressed by this place! First ...       5
# 5  Perfect.\n\nWent there for a beer and fries. G...       5
# 6  Very friendly and fast service. Great location...       5
# 7  "They do their best, they do what they can\nTh...       5

# %%
DataMarseille541a560[DataMarseille541a560.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille541a560[DataMarseille541a560.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 561 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille561a580 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille561a580 = json_normalize(DataDictMarseille561a580['search']['business'] , 'reviews',  max_level=1)
DataMarseille561a580
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Five years ago I stumbled on this tiny stall s...       4
# 1  Came here with a large group and 3 kids. The w...       4
# 2  It's not easy to find good, authentic Mexican ...       4
# 3  Horrible place with a very bad attitude of Ara...       1

# %%
DataMarseille561a580[DataMarseille561a580.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille561a580[DataMarseille561a580.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  Horrible place with a very bad attitude of Ara...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 581 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille581a600 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille581a600 = json_normalize(DataDictMarseille581a600['search']['business'] , 'reviews',  max_level=1)
DataMarseille581a600
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   We had an excellent meal here for our annivers...       5
# 1   Service and food are amazing. The owner/chef m...       5
# 2   A nice assortment of well cooked Italian cuisi...       4
# 3   Amazing place! All the food is very delicious!...       5
# 4   Nice place to enjoy good thai food...meals are...       4
# 5   I recently discovered this place and I am very...       4
# 6   Wonderful restaurant off of Rue du Prado in Ma...       5
# 7   Wanted to order 2 Pad Thais.\nWas told after t...       1
# 8   Not a great gastronomic, but a good restaurant...       4
# 9   Fabulous Japanese food prepared by an Irish wo...       4
# 10  Lovely jewel on a quiet corner. Owner super ni...       4
# ...

# %%
DataMarseille581a600[DataMarseille581a600.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille581a600[DataMarseille581a600.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 7  Wanted to order 2 Pad Thais.\nWas told after t...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 601 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille601a620 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille601a620 = json_normalize(DataDictMarseille601a620['search']['business'] , 'reviews',  max_level=1)
DataMarseille601a620
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Really good pizzas.  I usually get the Pizza M...       5
# 1   This off-the-beaten-path spot is one worth hea...       5
# 2   Benjamin thank you for your hospitality I was ...       5
# 3   We had the day's special:  steak with herbs & ...       4
# 4   Reasonably priced, delicious food in huge port...       4
# 5   Authentic Tunisian bistro right at the old por...       5
# 6   Situated in front of the bar called La Samarit...       2
# 7   Stopped here for coffee after a long day of wa...       5
# 8   I found Sard'In via TripAdvisor while I was in...       3
# 9   My husband and I were in Marseille for the las...       4
# 10  I would give Sard'in 4.5 stars! My parents and...       5
# ...

# %%
DataMarseille601a620[DataMarseille601a620.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 6  Situated in front of the bar called La Samarit...       2>

# %%
DataMarseille601a620[DataMarseille601a620.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 621 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille621a640 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille621a640 = json_normalize(DataDictMarseille621a640['search']['business'] , 'reviews',  max_level=1)
DataMarseille621a640
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Before commenting on the food, I will echo the...       4
# 1   Please, please, please... Come to this place i...       5
# 2   On a recent trip to Marseille we decided to tr...       1
# 3   An American Foodie working two weeks in our HQ...       3
# 4   This was my first time visiting Marseille so I...       3
# 5   For a quick coffee and a bite Le Soleil is the...       3
# 6   I desperately wanted to like this place!  I lo...       2
# 7   Feels like a chain but it was solid. Charcuter...       4
# 8   We try not to be the Ugly Americans. We didn't...       1
# 9   We loved this restaurant while visiting from S...       5
# 10  Delicious sushi with fresh fish and reasonable...       4
# ...

# %%
DataMarseille621a640[DataMarseille621a640.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 6  I desperately wanted to like this place!  I lo...       2>

# %%
DataMarseille621a640[DataMarseille621a640.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  On a recent trip to Marseille we decided to tr...       1
# 8  We try not to be the Ugly Americans. We didn't...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 641 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille641a660 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille641a660 = json_normalize(DataDictMarseille641a660['search']['business'] , 'reviews',  max_level=1)
DataMarseille641a660
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  This is definitely my favourite restaurant tha...       5
# 1  The lunch we had here were definitely the best...       4
# 2  I would like to give CDE 5+ stars. We had an a...       5
# 3  Just had Vapiano delivered via Uber Eats. We s...       4
# 4  We came here in the late afternoon when everyw...       2
# 5  Super yummy!! We usually order here over deliv...       5
# 6  It was okish. My friends got the muscles which...       3
# 7  While waiting for a boat departure with time t...       4
# 8  RUN RUN RUN.  Worst meal in France.   Bouillab...       1
# 9  This is a simple restaurant with delicious foo...       5

# %%
DataMarseille641a660[DataMarseille641a660.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 4  We came here in the late afternoon when everyw...       2>

# %%
DataMarseille641a660[DataMarseille641a660.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 8  RUN RUN RUN.  Worst meal in France.   Bouillab...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 661 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille661a680 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille661a680 = json_normalize(DataDictMarseille661a680['search']['business'] , 'reviews',  max_level=1)
DataMarseille661a680
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Rice was excellent, palak was savory, kofte wa...       3
# 1   It's a restaurant with homemade food made by t...       5
# 2   This place always held my curiosity because it...       3
# 3   The price is quite good for appetizer, main co...       4
# 4   This place is terrible. I've never left my ent...       1
# 5   Turn around, now don't do it. Food was terribl...       1
# 6   All of the other reviews are from many years a...       1
# 7   We had the wine, starter, main dish, and desse...       4
# 8   We were here at 9:30 and thank God they still ...       5
# 9   We wandered in and were delighted by the real ...       4
# 10  This place is so worth the money! For only 5.5...       5

# %%
DataMarseille661a680[DataMarseille661a680.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille661a680[DataMarseille661a680.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 4  This place is terrible. I've never left my ent...       1
# 5  Turn around, now don't do it. Food was terribl...       1
# 6  All of the other reviews are from many years a...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 681 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille681a700 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille681a700 = json_normalize(DataDictMarseille681a700['search']['business'] , 'reviews',  max_level=1)
DataMarseille681a700
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   Absolument magnifique! All of the food was fan...       5
# 1   I really enjoyed visiting Chez Gilda.  The pla...       4
# 2   Blerk!  As everyone says, yes, it is very conv...       1
# 3   A place named for a biere should have a bar !\...       2
# 4   THE place to go when you are with good friends...       4
# 5   I came here for a hearty lunch of the Rib Eye ...       4
# 6   Had seafood lunch today. Squid and octopus was...       2
# 7   Great place with very friendly waiters.\nThe f...       5
# 8   A funny thing happened to me on the way to the...       5
# 9   Visited Marseille back in March. Wanted to fin...       4
# 10  Amazing food. Even better service. Excellent a...       5

# %%
DataMarseille681a700[DataMarseille681a700.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  A place named for a biere should have a bar !\...       2
# 6  Had seafood lunch today. Squid and octopus was...       2>

# %%
DataMarseille681a700[DataMarseille681a700.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  Blerk!  As everyone says, yes, it is very conv...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 701 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille701a720 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille701a720 = json_normalize(DataDictMarseille701a720['search']['business'] , 'reviews',  max_level=1)
DataMarseille701a720
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Had the Menu du Jour which consists of the dis...       5
# 1  It was a beautiful summer day in Marseille, I ...       3
# 2  Well I came here by chance originally wanting ...       4
# 3  I was on my way to find the famous Calanques n...       4
# 4  Server was very nice and quick to take our ord...       2
# 5  Overpriced, poor quality food. Rude, slow serv...       1
# 6  Best " pan bagnat " of marseille! Period. Furt...       5

# %%
DataMarseille701a720[DataMarseille701a720.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 4  Server was very nice and quick to take our ord...       2>

# %%
DataMarseille701a720[DataMarseille701a720.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 5  Overpriced, poor quality food. Rude, slow serv...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 721 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille721a740 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille721a740 = json_normalize(DataDictMarseille721a740['search']['business'] , 'reviews',  max_level=1)
DataMarseille721a740
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Great location with an outstanding view, unfor...       4
# 1  Good place to chill/drink a coffee\nAfter shop...       3
# 2  Do yourself a favor and skip all the touristy ...       5
# 3  I would give this five stars for service, ambi...       4
# 4  We just stopped for a glass of wine before goi...       3
# 5  Good service, great view of the museum and par...       4
# 6  Nice atmosphere just off the harbor. \n\nI had...       4
# 7  3.5 hours waiting for food.  Was out with the ...       1

# %%
DataMarseille721a740[DataMarseille721a740.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille721a740[DataMarseille721a740.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 7  3.5 hours waiting for food.  Was out with the ...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 741 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille741a760 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille741a760 = json_normalize(DataDictMarseille741a760['search']['business'] , 'reviews',  max_level=1)
DataMarseille741a760
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  My family and I were in Marseilles for vacatio...       2
# 1  Recommended among many websites, but honestly ...       2
# 2  Very high quality food and wine.\nThe fish was...       4
# 3  Just wonderful! The hosts are sweet South Indi...       5
# 4  My husband and I walked around and when we spe...       3
# 5  Average food but very decent value for money. ...       3

# %%
DataMarseille741a760[DataMarseille741a760.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 0  My family and I were in Marseilles for vacatio...       2
# 1  Recommended among many websites, but honestly ...       2>

# %%
DataMarseille741a760[DataMarseille741a760.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 761 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille761a780 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille761a780 = json_normalize(DataDictMarseille761a780['search']['business'] , 'reviews',  max_level=1)
DataMarseille761a780
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  We had a scrumptious lunch here yesterday - tw...       5
# 1  Good place to grab a quick bagel or sandwich (...       3
# 2  We tried tonight this place. We were eating ph...       4

# %%
DataMarseille761a780[DataMarseille761a780.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille761a780[DataMarseille761a780.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 781 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille781a800 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille781a800 = json_normalize(DataDictMarseille781a800['search']['business'] , 'reviews',  max_level=1)
DataMarseille781a800
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  This is a small cafe with friendly staff along...       4
# 1  This restorant is a hidden pearl of Marseille,...       5
# 2  We were eating an excellent pizza and good pas...       5
# 3  We did take out and their pizzas were amazing!...       5
# 4  If you want to try the real bouillebasse - tra...       4
# 5  When visiting Marseille, bouillabaisse is an o...       5
# 6  This restaurant is outstanding. You can have a...       5
# 7  went there for diner and not impressed at all....       2

# %%
DataMarseille781a800[DataMarseille781a800.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 7  went there for diner and not impressed at all....       2>

# %%
DataMarseille781a800[DataMarseille781a800.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 801 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille801a820 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille801a820 = json_normalize(DataDictMarseille801a820['search']['business'] , 'reviews',  max_level=1)
DataMarseille801a820
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Death by happiness. So good. Unique plates and...       5
# 1  A nice family run place tucked away inside fro...       4
# 2  Must make reservations to eat here for lunch o...       4
# 3  Une expérience culinaire... mais pas un repas\...       3
# 4  This was really close to our AirBnB so we gave...       5
# 5  Found this pizza spot near our airbnb. Since w...       5

# %%
DataMarseille801a820[DataMarseille801a820.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille801a820[DataMarseille801a820.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 821 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille821a840 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille821a840 = json_normalize(DataDictMarseille821a840['search']['business'] , 'reviews',  max_level=1)
DataMarseille821a840
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Descent and correct price level. However the c...       3
# 1  Our original restaurant choice was too busy- w...       5
# 2  DON'T WASTE YOUR TIME.\nStood up in line for a...       2
# 3  This is the first time here in Marseille it wa...       1

# %%
DataMarseille821a840[DataMarseille821a840.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  DON'T WASTE YOUR TIME.\nStood up in line for a...       2>

# %%
DataMarseille821a840[DataMarseille821a840.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 3  This is the first time here in Marseille it wa...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 841 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille841a860 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille841a860 = json_normalize(DataDictMarseille841a860['search']['business'] , 'reviews',  max_level=1)
DataMarseille841a860
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Perfect! Each and every dish we've ordered exc...       5
# 1  After a two hour Segway tour, we look for a pl...       5
# 2  Le Montmartre serves okay food -- it's not bad...       3
# 3  Le Petit Matelot is a nice little French resta...       4
# 4  best pizza I've ever had in my life.  I apolog...       5
# 5  Chez Noel may look like a family-friendly loca...       1
# 6  nice restaurant with fast service and plenty o...       4
# 7  This happened to be a random choice. We were o...       5
# 8  Excellent shawarma - taste reminded me of Shaw...       4
# 9  Tasty dishes at a fair price. Run by a nice fa...       4

# %%
DataMarseille841a860[DataMarseille841a860.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille841a860[DataMarseille841a860.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 5  Chez Noel may look like a family-friendly loca...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 861 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille861a880 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille861a880 = json_normalize(DataDictMarseille861a880['search']['business'] , 'reviews',  max_level=1)
DataMarseille861a880
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  The classic cheeseburger was absolutely delici...       3
# 1  Outstanding food, wine, drink, service and amb...       5
# 2  Great ambiance and lots of outdoor seating. Sh...       5
# 3  Had reservations nearby later and so stopped b...       3
# 4  Love chicken ville. Fresh crispy chicken! I lo...       4

# %%
DataMarseille861a880[DataMarseille861a880.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille861a880[DataMarseille861a880.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 881 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille881a900 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille881a900 = json_normalize(DataDictMarseille881a900['search']['business'] , 'reviews',  max_level=1)
DataMarseille881a900
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  text  rating
# 0   The food was fine. They have a great formule f...       3
# 1   If I could give this place 0 stars I would. Th...       1
# 2   La langoustine\n\nI would give zero stars if I...       1
# 3   Amazing meal with wonderful people tonight on ...       5
# 4   Yup, it's Indian food in Marseille.  As other ...       3
# 5   Restaurant overheated and very crowded: The at...       4
# 6   I've eaten here twice now, once for lunch in 2...       3
# 7   Best meal I had in Marseille, for 20 euros! Fr...       5
# 8                    la meilleure pizza de Marseille.       5
# 9   Excellent restaurant and destination! If you'r...       5
# 10  Closest to the hotel, fast, uncomplicated and ...       4
# ...

# %%
DataMarseille881a900[DataMarseille881a900.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille881a900[DataMarseille881a900.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 1   If I could give this place 0 stars I would. Th...       1
# 2   La langoustine\n\nI would give zero stars if I...       1
# 11  Never again...\nNice terrasse and reasonable p...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 901 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille901a920 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille901a920 = json_normalize(DataDictMarseille901a920['search']['business'] , 'reviews',  max_level=1)
DataMarseille901a920
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Had a great lunch by the Old Port here. Our wa...       4
# 1  A bit overpriced and the food was ok. The wait...       2
# 2  WORST restaurant in marseille.  Food sucked an...       1
# 3  We have eaten there as a flight crew spending ...       3
# 4  Okay food offered here.  I wouldn't say that i...       3
# 5  We went with some friends to start the night o...       4
# 6  Honestly, one of the most unpleasant experienc...       1

# %%
DataMarseille901a920[DataMarseille901a920.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 1  A bit overpriced and the food was ok. The wait...       2>

# %%
DataMarseille901a920[DataMarseille901a920.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 2  WORST restaurant in marseille.  Food sucked an...       1
# 6  Honestly, one of the most unpleasant experienc...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 921 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille921a940 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille921a940 = json_normalize(DataDictMarseille921a940['search']['business'] , 'reviews',  max_level=1)
DataMarseille921a940
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Nice atmosphere right on the water in the Old ...       3
# 1  We only went here for beers while we waited fo...       2
# 2  A surprising complex in a side street about a ...       4

# %%
DataMarseille921a940[DataMarseille921a940.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 1  We only went here for beers while we waited fo...       2>

# %%
DataMarseille921a940[DataMarseille921a940.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 941 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille941a960 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille941a960 = json_normalize(DataDictMarseille941a960['search']['business'] , 'reviews',  max_level=1)
DataMarseille941a960
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Secret classic of Marseille, a place for all, ...       5
# 1  So sad that my memory of this beautiful town i...       1
# 2  The service in this place SUCKS!!!  The food i...       1
# 3  Racist.\n\nIt's a great place if you're not vi...       1
# 4  We had some high-quality, amazing crepes at Am...       4
# 5  The worst Service I have ever seen. Good luck ...       1
# 6  Hi hello my friend and I went here to get a co...       1

# %%
DataMarseille941a960[DataMarseille941a960.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille941a960[DataMarseille941a960.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                 text  rating
# 1  So sad that my memory of this beautiful town i...       1
# 2  The service in this place SUCKS!!!  The food i...       1
# 3  Racist.\n\nIt's a great place if you're not vi...       1
# 5  The worst Service I have ever seen. Good luck ...       1
# 6  Hi hello my friend and I went here to get a co...       1>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 961 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille961a980 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille961a980 = json_normalize(DataDictMarseille961a980['search']['business'] , 'reviews',  max_level=1)
DataMarseille961a980
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Absolutely lovely! This little place gave deli...       5
# 1  Nice little spot for coffee and sweets just ne...       3
# 2  We dined as a party of 5 and enjoyed several d...       3
# 3  We have for a long time been looking for some ...       4
# 4  I just did one last night and although it was ...       3

# %%
DataMarseille961a980[DataMarseille961a980.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille961a980[DataMarseille961a980.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
from config import api_key

#Definition du header
header = {'Authorization' : 'bearer {}'.format(api_key)}

#Construction  de la request
transport = RequestsHTTPTransport(url = 'https://api.yelp.com/v3/graphql' , headers = header, use_json = True)

#Creation du client
client =  Client(transport = transport , fetch_schema_from_transport = True)

#Definition de query
query = gql('''
{
  search(term: "restaurants", location: "Marseille", limit: 20, offset: 980 ) {
    business {
      name
      id
      reviews {
        text
        rating        
      }      
    }
  }
}
''')

response_query = client.execute(query)
DataDictMarseille980a999 = response_query
#Print query
print('-'*50)
print(response_query)
# Out:
# --------------------------------------------------
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille980a999 = json_normalize(DataDictMarseille980a999['search']['business'] , 'reviews',  max_level=1)
DataMarseille980a999
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                 text  rating
# 0  Nice beach side (feet in the sand!) cafe. Good...       4
# 1  Excellent, authentic Japanese restaurant with ...       5
# 2  We almost turned away from this little bakery ...       4
# 3  A nice discovery in the heart of the "Panier",...       5

# %%
DataMarseille980a999[DataMarseille980a999.rating == 2].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %%
DataMarseille980a999[DataMarseille980a999.rating == 1].sum
# Out:
# <bound method DataFrame.sum of Empty DataFrame
# Columns: [text, rating]
# Index: []>

# %% [markdown]
# # Sélection des 200 restaurants  avec avis d'insatisfaction

# %%
from pandas.io.json import json_normalize
DataMarseille41a60b = json_normalize(DataDictMarseille41a60['search'] , 'business',  max_level=1)
DataMarseille41a60b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          name                      id  \
# 0            Bonheur du Temps  sBm-p5kXfWcG-BFcBK0cMw
# 1        Le Bistrot des Dames  OKfhL5e5AYjz1MZh0NXCpA
# 2         La Maison Du Refuge  dq_gd0wW67t8TYwbnwOLKw
# 3                    Tako-San  286RZjFKcZFR7hsJ2W5s9A
# 4                        Axum  GvHGP3oi_CAstDDCkWXWUA
# 5               La Cantinetta  2wJvohGrV0VuLVzBkgrnAg
# 6                       TA&CO  OLQgN5-wN8BOm9lpeXEp_w
# 7                Sur le Pouce  BlCke5gXOiaeEfLs-gd3VA
# 8                 César Place  rCGAq1AU-l9YzIXQnU02Fw
# 9   Mama Shelter - Restaurant  VrsUIeKX1c8J0mG5jYOnVw
# 10           La Côte de Boeuf  P8lycs-He3pcX9T3XZYlaw
# 11                     Elyssa  0EPEOczx-pGPso0Ird5DFQ
# 12               La Casertane  FJzDFQwywtYzF-bnfTu0FQ
# ...

# %%
DataMarseille41a60
# Out:
#                                                  text  rating
# 0   This place is simply the definition of perfect...       5
# 1   I ordered seafoods spaghetti, I really don't l...       2
# 2   A little disappointed with our experience here...       2
# 3   The cute restaurant spills out onto the street...       4
# 4   An amazing simple Italian restaurant with such...       5
# 5   Had a wonderful swordfish carpaccio.  This was...       5
# 6   Great Italian food away from the tourist area....       4
# 7   Surprised to find a good Mexican restaurant on...       4
# 8   Another Tunisian restaurant, another jewel in ...       5
# 9   Our favorite restaurant in Marseille, where we...       5
# 10  Wonderful food and extremely friendly staff! I...       5
# 11  I wanted to like this place, I really did. Unf...       2
# 12  Wow, probably the best pizza I've ever had. No...       5
# 13  I had a late night dinner for one last night a...       5
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille361a380b = json_normalize(DataDictMarseille361a380['search'] , 'business',  max_level=1)
DataMarseille361a380b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                         name                      id  \
# 0                    MetSens  1VjuGiHmw2O9TPLVPmzdmg
# 1                    O'Tacos  ivlSP19OnkxP2_uug3dwAg
# 2   Le Môle Passedat - Mucem  eEKuURwKhCOSFzmR1AeJKQ
# 3                   Chez Ida  CmHI3dv9Ek4ns9KY-mxM5A
# 4                      Ô-Pho  BE-86rESbhc89tnXcVDdwA
# 5         Brasserie le Cours  vsl5F0_7VxyQjf88vfsbag
# 6                   Kortchma  kzkzxJ4dHcgg-UUp8iz1Qg
# 7                 Le 26 Café  dUT7a54W04FeX34SIuSskg
# 8                   La Villa  UNFTRdli2TBj99V-y656YA
# 9       Bistrot des 2 filles  cI-YFqzcnyydNSaBpt_1lA
# 10                   Le Souk  mkv2IP7wFoOl6fU45HrCqA
# 11             Arigato Sushi  zBIhUIO9XRlQlV4tyE_ACQ
# 12             La Préfecture  Zsfv8U1dHF2xjmJQ-UZwLw
# ...

# %%
DataMarseille361a380
# Out:
#                                                  text  rating
# 0   I went to O'Tacos because I had few options at...       1
# 1   We stayed at the Hotel Petit Nice Passedat, bu...       5
# 2   I loved this place! Originally, I found this r...       5
# 3   Service was great. The owner couple was full o...       4
# 4   O-pho was O-K. What were we supposed to do whe...       3
# 5   Delicious stop, loved the dumplings and egg ro...       5
# 6   The food was absolutely awful. Worst Pho I've ...       1
# 7   I love this restaurant.  As a first-time visit...       5
# 8   La Villa\n\n77+\n\nLa Villa\n\n4.3\n\n(156)\n\...       1
# 9   Good service and food that hit the spot. Betwe...       4
# 10  I had read a nice review about this place onli...       1
# 11  Well it started off with me ordering "a glass"...       2
# 12  Very much mediocre if not super market level s...       2
# 13  Good pizza! We had anchovy and cheese pizzas, ...       4
# ...

# %%
from pandas.io.json import json_normalize
DataMarseille941a960b = json_normalize(DataDictMarseille941a960['search'] , 'business',  max_level=1)
DataMarseille941a960b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                      name                      id  \
# 0               Le System  TUbBM7f12M5sq-NOmm_gqA
# 1           Le Café Barok  oqXy5AwJ4rX5rDOVUSVQ7g
# 2                   Peron  kaJTCYtQFM7SZwcKkQv-uw
# 3              McDonald's  BvuVkLKjDcxgyxghviuHdg
# 4             Le Sampiero  5VeQo2imc76pg0DM0OPpDw
# 5      La Maison des Thés  74w0MtvA9f57b0ZQQhP5lw
# 6   Les Saveurs du Vesuve  2KgGufbD2Xu0dGz54v1oQg
# 7      Bar des Maraîchers  rbjvfIdFmaVvYlI0UK_3Yg
# 8    Café Tournez la Page  ySHgvHiN0bWlx8x8koeBsQ
# 9                L'escale  Wf-7bJszS2n6REXGbrwK2w
# 10                 KIM BA  9PenhB83wXDpJtsh1A9bsg
# 11         La Samaritaine  f-xr8Dg4n-hMc5_9Jtpq0w
# 12  Ambassade de Bretagne  gFfkMqE-1QKYlL5z6wn8Aw
# 13                Le Rhul  BOKvD2zWFup_4yQ7X9ktgA
# ...

# %%
DataMarseille941a960
# Out:
#                                                 text  rating
# 0  Secret classic of Marseille, a place for all, ...       5
# 1  So sad that my memory of this beautiful town i...       1
# 2  The service in this place SUCKS!!!  The food i...       1
# 3  Racist.\n\nIt's a great place if you're not vi...       1
# 4  We had some high-quality, amazing crepes at Am...       4
# 5  The worst Service I have ever seen. Good luck ...       1
# 6  Hi hello my friend and I went here to get a co...       1

# %%
from pandas.io.json import json_normalize
DataParis161a180b = json_normalize(DataDictParis161a180['search'] , 'business',  max_level=1)
DataParis161a180b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                       name                      id  \
# 0                 Freddy's  3drmuEM-hbUqOXVmZRtF4g
# 1          La Poule au Pot  JlPLkE5YaR4LzZIB-7J7ZA
# 2             Le Bonaparte  WhX_u6d2GY1xmWNPiTcYCA
# 3          Restaurant Mumi  3cNLpk5HmmnXptjwg-KN-w
# 4               The Family  4TZ92lo35VPqjrAvOVkQmQ
# 5             Les Papilles  4UO8M5flLUR5-TxGdSma0Q
# 6       La Grande Cremerie  hTClaTbijWdvdSyHxRIiPQ
# 7                 Derrière  QNQ4teRXk5Wx1GFLT3Y9sA
# 8             Le Black Dog  3Mg4L7o7Og9aajb7tee2sQ
# 9              Le Pas Sage  2pzucMcXawD5XB0LA277aA
# 10                 Sequana  R38fKm8cPHPBCovE9ThGVA
# 11           Les Ursulines  RY3_k4QoLUOasgJApmqqsg
# 12  Brasserie de la Bourse  ML5YEWSl3K-5-2vO35RVpQ
# 13           Tour d'Argent  Tb6siRZNm2X7GLiPXWpLLg
# ...

# %%
DataParis161a180
# Out:
#                                                  text  rating
# 0   Wanna snuggle up to someone while sharing an i...       5
# 1   Went here on a whim and it was a wise choice! ...       5
# 2   Stumbled upon Freddy's on our first night in P...       5
# 3   La Poule au Pot made our last night in Paris r...       5
# 4   Our experience was excellent. The food was ter...       4
# 5   Noooooo, no no. Was really excited to try this...       1
# 6   Stopped by for a very late dinner a few evenin...       4
# 7   *Caveat- this is a review from an American tou...       2
# 8   Le Bonaparte is fine. Nothing incredible. Food...       3
# 9   MUMI is seriously such an awesome place! And i...       5
# 10  This restaurant is a find.  We had an amazing ...       5
# 11  Great food. Great service. Bad sommelier. Cork...       3
# 12  Great staff, funny and engaging.   Strong know...       5
# 13  Great food, good people... enjoyed this little...       5
# ...

# %%
from pandas.io.json import json_normalize
DataParis221a240b = json_normalize(DataDictParis221a240['search'] , 'business',  max_level=1)
DataParis221a240b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                              name                      id  \
# 0                         Fajitas  AtaYhOa_2laBNl21ON2b2Q
# 1             Le Relais du Louvre  OwosN0FUG0ZgFjvlMwtPNQ
# 2           Le Bistrot des Halles  RpKOe8ImcDJCgrNL3nhJRQ
# 3                        Paperboy  pNBQYpNDOjkKEBJYeznV8A
# 4                     Le Parisien  zaaBsIRG3osbGdjY1_KMpQ
# 5                    Les Cocottes  K-cAB9sz9UoopOP0APEi0g
# 6                         Rumeurs  XW5s4lEwq0ehG4ZerRR_WQ
# 7               Chungking Express  2cdGE8MLkA30R7ceI5c-Ig
# 8      L'Avant Comptoir du Marché  cZuI00Kuql1yDqBloKLsQQ
# 9           Le Bistrot des Vosges  15tUXLav_KIRjszu8IJJ3w
# 10                        Kintaro  UWHeLbOm-R1NPv1-kKGBJw
# 11                      L'Ange 20  weiNgy7k32W5fmZoTaF-Bw
# ...

# %%
DataParis221a240
# Out:
#                                                  text  rating
# 0   After 12 days in Europe these Californians wer...       5
# 1   Fajitas had quick service, friendly staff and ...       4
# 2   The food and service was very good! Definitely...       5
# 3   We had to get the snails since that is what al...       5
# 4   Wonderful food and kind and friendly service. ...       4
# 5   Le Relais du Louvre is a small, casual brasser...       4
# 6   I am a big fan of hidden gems. The Les Halles ...       5
# 7   I ate here many years ago, when I lived in Par...       1
# 8   Stopped into this bistro for lunch on a rainy ...       5
# 9   Just got back to my Airbnb from brunch here an...       5
# 10  An absolute must if you love fresh amazing foo...       5
# 11  This place i just OK.  No idea why people give...       3
# 12  We were disappointed when we found out Chez I'...       4
# 13  Very nice service and good appetizers, unfortu...       2
# ...

# %%
from pandas.io.json import json_normalize
DataParis521a540b = json_normalize(DataDictParis521a540['search'] , 'business',  max_level=1)
DataParis521a540b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                              name                      id  \
# 0                   Coffee Crêpes  xC7G4mw7QC2yZ5anEkdiZQ
# 1                       Evi Evane  v_-WpN3rTlcVtk4ZBqilkg
# 2                         Ralph's  69Jp-YKmgfan9SWC36zgxA
# 3   La Petite Maison dans la Cour  jZdsCv-E1XZEFI42l2o9uA
# 4                     Darôme Diet  9uoVYNCpkFjVnsXk3CXGXQ
# 5                   Maison Maison  cQimiW65cqlLZbObNDXtrA
# 6                       Fuji Yaki  u-PsbIdHlea2tcgVpwPJsQ
# 7               Brasserie du Quai  _3Fl0Dlm5oeiqW3hMzqcjA
# 8                     Chez Mamane  8jHjG5meQIK8xWuPqSTzTA
# 9         L'Atelier Maître Albert  KtJpK3WXMZJdPmULmkT2Zg
# 10                 Le Trente Neuf  hV6slTGzHOKS4XJrhl2vQw
# 11  Le Comptoir des Petits Champs  i5hU4vIQ0Y1-N5eFEJdZQw
# ...

# %%
DataParis521a540
# Out:
#                                                  text  rating
# 0   We stopped in for coffee and crepes. Very nice...       5
# 1   A nice little spot right on the Seine river ac...       4
# 2   I have ordered the crepe Eiffel Tower which su...       1
# 3   Cute place by Jardin de Luxembourg.\nWe were l...       5
# 4   Some of the best food we've eaten in Paris. A ...       5
# 5   This place is a treasure. We are Americans in ...       5
# 6   Walked in on a Thursday night without a reserv...       4
# 7   I am happy to say that Ralph has improved sinc...       4
# 8   My mom and I are regulars at RL in Chicago so ...       4
# 9   Ambiance 5 star --\nThrow back music and great...       5
# 10  Had lunch here two days ago. Lovely location o...       1
# 11  This spot is delightful, right on the Seine. T...       5
# 12  After eating French food non-stop for a week a...       5
# 13  We go to some of the best sushi restaurants im...       5
# ...

# %%
from pandas.io.json import json_normalize
DataParis541a560b = json_normalize(DataDictParis541a560['search'] , 'business',  max_level=1)
DataParis541a560b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                    name                      id  \
# 0                Verjus  yxnz1df8WuKm3ZapRmLmIw
# 1           Chez Marcel  ZdQsis9ahsuQS6Q4OPACDQ
# 2              Studio 5  1eiwl5TL9mrsvPVJ25tBtQ
# 3               Pascade  pGqT1g6bwybH2iLrx_buWw
# 4          A Jean Nicot  RIVd8n0kAZedJLD4-eFZ2g
# 5        Café Oberkampf  VcIrvLK8x-qyeZf0qTvv6A
# 6        Le Bon Pêcheur  kGCB1YFIkkeOMN4Yh8iUXQ
# 7          La Gaufrerie  3USDPQztKvPsb8sFQt7SXg
# 8          La Farnesina  EP4jsS2LS_-Ixnt6Ro9u-w
# 9            Café Latin  InDDoIYyj_jSkGxG5mFM6A
# 10           Casa Festa  N_jgNOwG-6zOMSkYSUiT6w
# 11  Le Clos Bourguignon  AFDrNbFyVE2easI82eTyvw
# 12               Monjul  uKBYjnxBSa3sqzdUfwcO9A
# 13    Restaurant Cartet  Np5C485NLuY-a5YZmnvk8Q
# 14     La Reine de Saba  -REmuFE-SZ0sltoq45COWw
# ...

# %%
DataParis541a560
# Out:
#                                                  text  rating
# 0   Handydandy yelp Paris has pointed us in the ri...       5
# 1   After reading reviews of Verjus my impression ...       4
# 2   A great experience for a decadent night in Par...       5
# 3   We went to this restaurant after a recommendat...       5
# 4   Chez Marcel was recommendended by the concierg...       4
# 5   Rude front staff, we didn't have a reservation...       1
# 6   Yumm! All I can say. Real American burgers and...       5
# 7   You come here for...\n- An amazing happy hour:...       4
# 8   Good burgers, but the fries were dry.\nThe moj...       3
# 9   Came here for lunch and it exceeded all expect...       5
# 10  When I say I had the best meal of my life here...       5
# 11  Absolutely phenomenal from start to finish! Do...       5
# 12  Thanks to other Yelpers. \n\nBookmarked this s...       4
# 13  Ducked into A Jean Nicot after a day at the Lo...       3
# ...

# %%
from pandas.io.json import json_normalize
DataParis761a780b = json_normalize(DataDictParis761a780['search'] , 'business',  max_level=1)
DataParis761a780b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                    name                      id  \
# 0                             L'Encrier  xqviTHiJ2y0RZPt0sd655A
# 1                     La Cave Gourmande  H45IsXGTW0XjG0-yRlGPJg
# 2                 La Cantine du Troquet  lAhmNKOAU5wEs2RXjyaPrg
# 3                             Le Compas  UUXX7Xou0d3Ulc5uqoRkyA
# 4                    La Clef des Champs  g1dS9NzImmvGHfT3EVOB5w
# 5                           Le Consulat  k0gvp5leDd0J-T47PNs2VA
# 6   Le P'tit Bréguet : Bistro Auvergnat  E6w1IPRUgGUHCle0ViG_ZA
# 7                          Le Pure Café  Vv0ucGDiug3Ghm_0JhjD1g
# 8                             Moustache  EYmNuRZd5tzCsOdyZ2Sa8Q
# 9                       Le Roi de Pique  pQPK-eoMbVgcQE5ZlEreAg
# 10                       Arnaud Nicolas  egX8nlHUZceWCPDVdx9raw
# ...

# %%
DataParis761a780
# Out:
#                                                  text  rating
# 0   In a few words,\n\nThis was great: \n* Really ...       5
# 1   L'Encrier was recommended to me by my program ...       4
# 2   The food here is a solid 3-star, but the value...       4
# 3   La nourriture est délicieuse! Omg the best res...       5
# 4   Did we love this place??? Wi wi!!!!!! I wasn't...       5
# 5   This place was phenomenal. First off hats off ...       5
# 6   Recommended by our hotel's receptionist, La Ca...       5
# 7   Was recommended La Cantine by a friend! Sooooo...       5
# 8   Love this neighborhood bistro. First, the staf...       5
# 9   Ordered the escargot and had to come back a fe...       4
# 10  This place was extremely busy on a Saturday ni...       2
# 11  Very nice place on a very busy point on Montga...       4
# 12  Seriously, the cutest and coziest restaurant i...       5
# 13  Craving mussels.  \n\nAnd of course the need t...       3
# ...

# %%
from pandas.io.json import json_normalize
DataParis841a860b = json_normalize(DataDictParis841a860['search'] , 'business',  max_level=1)
DataParis841a860b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                         name                      id  \
# 0    Au Soleil de Montmartre  P-PN0AvGbfUY0RQ3dfvMEA
# 1                  Le Clos Y  f63kX8v4ZU2Bog87CFfB_g
# 2               Les Parigots  6m9bnpfICHZ3OKk8wI0AYg
# 3          L'Opium du Peuple  hjBrDDbPi9DYthw4O8gcyA
# 4                Sherry Butt  tPzmM4YATQCoO2gdJlqx1Q
# 5                Arrivederci  KR1VJk1OghZWJsn1xKPPmQ
# 6                Le Clarence  XWa3IcDRMD18mHaM-qHifQ
# 7                  Le Toucan  Pbu-w96FDZFtI4To-TiI0Q
# 8               Crêpe Avenue  sNAk5Xw8D3_kfkwhQh8jZw
# 9              Il Far'niente  r39BodmVjx3QWhXdjR79Zw
# 10                      Aïda  kpxcH7VsExHmbjzRHgizVw
# 11                     Bakus  saVu2caUFKP0d7rvkPYLFQ
# 12     Restaurant du Paradis  ubMI8fIuV6RGHB7AZInYLA
# ...

# %%
DataParis841a860
# Out:
#                                                  text  rating
# 0   This is a in a square plaza at the base of Sac...       3
# 1   On my way up the stairs to visit the Sacré Coe...       5
# 2   Small cafe style restaurant. Most dining is ou...       4
# 3   Came for the carte blanche (six course tasting...       4
# 4   Understated, yet refined. Even with all the go...       5
# 5   Elegantly arranged next to each other, French ...       4
# 6   Fantastic. Excellent fish and chips; very, ver...       5
# 7   A few things about this place were really grea...       2
# 8   Decent French Brasserie. Great service and goo...       3
# 9   Great brand new bar nestled in a quiet street ...       5
# 10  Very nice bartenders, beautiful cocktails, coo...       5
# 11  Such a cozy spot for fantastic drinks! I've ha...       5
# 12  Not too bad of a bar but did like the drinks a...       4
# 13  Fantastic, unpretentious cocktail bar tucked a...       5
# ...

# %%
from pandas.io.json import json_normalize
DataParis961a980b = json_normalize(DataDictParis961a980['search'] , 'business',  max_level=1)
DataParis961a980b
# Out:
# C:\Users\jcrro\anaconda3\envs\EnvP6\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                   name                      id  \
# 0        Le Café de la Grande Epicerie  TPAyE7qUuRtDEVdawJZgZw
# 1                            Le Corona  gWsY1MjdhUui_B_ZTscbRw
# 2                Le Bon Saint Pourçain  pLyFREqONgH02yxGsiu5rg
# 3                             Beefclub  JE06tQJBvW9e2sJoLvk_AQ
# 4                       Les Botanistes  93X9oxhfmXg2A9kf_CqSKA
# 5                             Chouette  iwbkYfgaQZDK8PqQxwkS7g
# 6                       La Renaissance  fogzrllMKyv7ltUoVv6YcA
# 7                La Cantine du Troquet  jCcSFT44X8mlGJxnryWPMg
# 8                               Lucien  YCL_HXD-STkvoIM9MMBYbw
# 9                        Le Petit Broc  fEhDPSbDXvK8hdGcC03rpA
# 10                           Assanabel  GHiH1vban9pwNGq9kTUWHw
# ...

# %%
DataParis961a980
# Out:
#                                                  text  rating
# 0   I'm not going to lie- there was no way I was g...       3
# 1   Randomly came across this place on our walk to...       1
# 2   It's been a mixed experience and not at all wh...       1
# 3   Restaurant was recommended by local friends. S...       5
# 4   Although the chefs are talented at this restau...       1
# 5   It's a gem. It's the experience we were lookin...       5
# 6   American Tourist here.  \n\nSolid steak, price...       3
# 7   We started our night at the speakeasy that is ...       2
# 8   Coming from America I have a certain expectati...       2
# 9   We we're lucky enough to have been staying at ...       5
# 10  Hard to describe... Its like going home and as...       5
# 11  Stumbled on this place based on Yelp review an...       5
# 12  Had a phenomenal experience with our group of ...       5
# 13  The food was delicious. The staff did assist u...       5
# ...

# %%
DataAvisInsatisfaction1 = pd.concat([DataParis161a180, DataParis221a240])
DataAvisInsatisfaction1
# Out:
#                                                  text  rating
# 0   Wanna snuggle up to someone while sharing an i...       5
# 1   Went here on a whim and it was a wise choice! ...       5
# 2   Stumbled upon Freddy's on our first night in P...       5
# 3   La Poule au Pot made our last night in Paris r...       5
# 4   Our experience was excellent. The food was ter...       4
# ..                                                ...     ...
# 54  The largest portions we had on our trip. The s...       4
# 55  Great staff, clean, and great atmosphere. \n\n...       4
# 56  Came here for a last minute dinner with a grou...       4
# 57  Great local spot. Staff was friendly and food ...       5
# 58  Horrible experience.  Sat at the bar for 90 mi...       1
#
# [119 rows x 2 columns]

# %%
DataAvisInsatisfaction2 = pd.concat([DataParis521a540, DataParis541a560])
DataAvisInsatisfaction2
# Out:
#                                                  text  rating
# 0   We stopped in for coffee and crepes. Very nice...       5
# 1   A nice little spot right on the Seine river ac...       4
# 2   I have ordered the crepe Eiffel Tower which su...       1
# 3   Cute place by Jardin de Luxembourg.\nWe were l...       5
# 4   Some of the best food we've eaten in Paris. A ...       5
# ..                                                ...     ...
# 46  The host was so friendly and my husband said t...       5
# 47  Eat before going to the Louvre or at the downs...       3
# 48  Beefbar is the best-looking restaurant I've ev...       5
# 49  AMERICANS BEWARE. Our server ripped us off by ...       1
# 50  This place is a must go. First of all, it's gr...       5
#
# [99 rows x 2 columns]

# %%
DataAvisInsatisfaction3 = pd.concat([DataParis761a780, DataParis841a860])
DataAvisInsatisfaction3
# Out:
#                                                  text  rating
# 0   In a few words,\n\nThis was great: \n* Really ...       5
# 1   L'Encrier was recommended to me by my program ...       4
# 2   The food here is a solid 3-star, but the value...       4
# 3   La nourriture est délicieuse! Omg the best res...       5
# 4   Did we love this place??? Wi wi!!!!!! I wasn't...       5
# ..                                                ...     ...
# 42  Super nice and good little restaurant for lunc...       5
# 43  This was the nicest place we went to in Paris....       5
# 44  The food was great, the atmosphere was right a...       5
# 45  Stayed in the Latin Q this time round and want...       5
# 46  Amazing food & service. Large portions and foo...       5
#
# [102 rows x 2 columns]

# %%
DataAvisInsatisfaction4 = pd.concat([DataParis961a980, DataMarseille41a60])
DataAvisInsatisfaction4
# Out:
#                                                  text  rating
# 0   I'm not going to lie- there was no way I was g...       3
# 1   Randomly came across this place on our walk to...       1
# 2   It's been a mixed experience and not at all wh...       1
# 3   Restaurant was recommended by local friends. S...       5
# 4   Although the chefs are talented at this restau...       1
# ..                                                ...     ...
# 24  Had an absolute blast here. We were staying at...       5
# 25  Great Italian restaurant at the heart of Marse...       5
# 26  Just off the main Harbor tourist street with a...       4
# 27  Terrible service, they basically refused to se...       1
# 28  Great outdoor seating on the water. Stopped in...       5
#
# [79 rows x 2 columns]

# %%
DataAvisInsatisfaction5 = pd.concat([DataMarseille361a380, DataMarseille941a960])
DataAvisInsatisfaction5
# Out:
#                                                  text  rating
# 0   I went to O'Tacos because I had few options at...       1
# 1   We stayed at the Hotel Petit Nice Passedat, bu...       5
# 2   I loved this place! Originally, I found this r...       5
# 3   Service was great. The owner couple was full o...       4
# 4   O-pho was O-K. What were we supposed to do whe...       3
# 5   Delicious stop, loved the dumplings and egg ro...       5
# 6   The food was absolutely awful. Worst Pho I've ...       1
# 7   I love this restaurant.  As a first-time visit...       5
# 8   La Villa\n\n77+\n\nLa Villa\n\n4.3\n\n(156)\n\...       1
# 9   Good service and food that hit the spot. Betwe...       4
# 10  I had read a nice review about this place onli...       1
# 11  Well it started off with me ordering "a glass"...       2
# 12  Very much mediocre if not super market level s...       2
# 13  Good pizza! We had anchovy and cheese pizzas, ...       4
# ...

# %%
DataAvisInsatisfactionA = pd.concat([DataAvisInsatisfaction1, DataAvisInsatisfaction2])
DataAvisInsatisfactionA
# Out:
#                                                  text  rating
# 0   Wanna snuggle up to someone while sharing an i...       5
# 1   Went here on a whim and it was a wise choice! ...       5
# 2   Stumbled upon Freddy's on our first night in P...       5
# 3   La Poule au Pot made our last night in Paris r...       5
# 4   Our experience was excellent. The food was ter...       4
# ..                                                ...     ...
# 46  The host was so friendly and my husband said t...       5
# 47  Eat before going to the Louvre or at the downs...       3
# 48  Beefbar is the best-looking restaurant I've ev...       5
# 49  AMERICANS BEWARE. Our server ripped us off by ...       1
# 50  This place is a must go. First of all, it's gr...       5
#
# [218 rows x 2 columns]

# %%
DataAvisInsatisfactionB = pd.concat([DataAvisInsatisfaction3, DataAvisInsatisfaction4])
DataAvisInsatisfactionB
# Out:
#                                                  text  rating
# 0   In a few words,\n\nThis was great: \n* Really ...       5
# 1   L'Encrier was recommended to me by my program ...       4
# 2   The food here is a solid 3-star, but the value...       4
# 3   La nourriture est délicieuse! Omg the best res...       5
# 4   Did we love this place??? Wi wi!!!!!! I wasn't...       5
# ..                                                ...     ...
# 24  Had an absolute blast here. We were staying at...       5
# 25  Great Italian restaurant at the heart of Marse...       5
# 26  Just off the main Harbor tourist street with a...       4
# 27  Terrible service, they basically refused to se...       1
# 28  Great outdoor seating on the water. Stopped in...       5
#
# [181 rows x 2 columns]

# %%
DataAvisInsatisfactionAB = pd.concat([DataAvisInsatisfactionA, DataAvisInsatisfactionB])
DataAvisInsatisfactionAB
# Out:
#                                                  text  rating
# 0   Wanna snuggle up to someone while sharing an i...       5
# 1   Went here on a whim and it was a wise choice! ...       5
# 2   Stumbled upon Freddy's on our first night in P...       5
# 3   La Poule au Pot made our last night in Paris r...       5
# 4   Our experience was excellent. The food was ter...       4
# ..                                                ...     ...
# 24  Had an absolute blast here. We were staying at...       5
# 25  Great Italian restaurant at the heart of Marse...       5
# 26  Just off the main Harbor tourist street with a...       4
# 27  Terrible service, they basically refused to se...       1
# 28  Great outdoor seating on the water. Stopped in...       5
#
# [399 rows x 2 columns]

# %%
DataAvisInsatisfactionParisMarseille = pd.concat([DataAvisInsatisfactionAB, DataAvisInsatisfaction5])
DataAvisInsatisfactionParisMarseille
# Out:
#                                                  text  rating
# 0   Wanna snuggle up to someone while sharing an i...       5
# 1   Went here on a whim and it was a wise choice! ...       5
# 2   Stumbled upon Freddy's on our first night in P...       5
# 3   La Poule au Pot made our last night in Paris r...       5
# 4   Our experience was excellent. The food was ter...       4
# ..                                                ...     ...
# 2   The service in this place SUCKS!!!  The food i...       1
# 3   Racist.\n\nIt's a great place if you're not vi...       1
# 4   We had some high-quality, amazing crepes at Am...       4
# 5   The worst Service I have ever seen. Good luck ...       1
# 6   Hi hello my friend and I went here to get a co...       1
#
# [423 rows x 2 columns]

# %%
DataAvisInsatisfactionParisMarseille.to_csv('P6_01_2_DataAvisInsatisfactionParisMarseille.csv', index = False)

# %%
DataAvisInsatisfactionParisMarseille[DataAvisInsatisfactionParisMarseille.rating == 5].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 0   Wanna snuggle up to someone while sharing an i...       5
# 1   Went here on a whim and it was a wise choice! ...       5
# 2   Stumbled upon Freddy's on our first night in P...       5
# 3   La Poule au Pot made our last night in Paris r...       5
# 9   MUMI is seriously such an awesome place! And i...       5
# ..                                                ...     ...
# 7   I love this restaurant.  As a first-time visit...       5
# 14  MUST try - steak that is aged and cooked so we...       5
# 15  I came last year with my uncle and the place i...       5
# 16  We only ordered refreshments but what stood ou...       5
# 0   Secret classic of Marseille, a place for all, ...       5
#
# [245 rows x 2 columns]>

# %%
DataAvisInsatisfactionParisMarseille[DataAvisInsatisfactionParisMarseille.rating == 4].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 4   Our experience was excellent. The food was ter...       4
# 6   Stopped by for a very late dinner a few evenin...       4
# 14  Small cafe offering lunch and dinner in a bist...       4
# 18  Great little neighborhood spot serving organic...       4
# 35  Man, AT beat me to this one! He was the first ...       4
# ..                                                ...     ...
# 26  Just off the main Harbor tourist street with a...       4
# 3   Service was great. The owner couple was full o...       4
# 9   Good service and food that hit the spot. Betwe...       4
# 13  Good pizza! We had anchovy and cheese pizzas, ...       4
# 4   We had some high-quality, amazing crepes at Am...       4
#
# [90 rows x 2 columns]>

# %%
DataAvisInsatisfactionParisMarseille[DataAvisInsatisfactionParisMarseille.rating == 3].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 8   Le Bonaparte is fine. Nothing incredible. Food...       3
# 11  Great food. Great service. Bad sommelier. Cork...       3
# 49  My husband and I popped into this cute cafe af...       3
# 52  Located on the northern tip of the Ile de la C...       3
# 11  This place i just OK.  No idea why people give...       3
# 27  No pretense ~ this restaurant delivers on exac...       3
# 31  The restaurant is setup like a giant cafeteria...       3
# 52  The atmosphere was nice and it seemed to attra...       3
# 33  OVERALL: I really debated about this rating, b...       3
# 8   Good burgers, but the fries were dry.\nThe moj...       3
# 13  Ducked into A Jean Nicot after a day at the Lo...       3
# 24  The atmosphere was very calm. Nice place to un...       3
# 39  Slow service..ok food, small portions \n\nRude...       3
# 47  Eat before going to the Louvre or at the downs...       3
# ...

# %%
DataAvisInsatisfactionParisMarseille[DataAvisInsatisfactionParisMarseille.rating == 2].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 7   *Caveat- this is a review from an American tou...       2
# 40  What a let down! Stuffy, old fashioned, past i...       2
# 41  Here's what is great about Tour d"Argent. The ...       2
# 13  Very nice service and good appetizers, unfortu...       2
# 14  This place was just average. The mushroom soup...       2
# 30  We are Ramen Lovers, we have tried ramen in ma...       2
# 49  We were, of course, drawn by the history of th...       2
# 16  We had a nice sneeze platter to start. That wa...       2
# 33  Happened to stumble upon this cute restaurant,...       2
# 45  They are open from 10.30 am - not from 8.30 li...       2
# 10  This place was extremely busy on a Saturday ni...       2
# 38  I ended up here without a plan, just chose it ...       2
# 52  Meh. Very inattentive and at times even brusk ...       2
# 7   A few things about this place were really grea...       2
# ...

# %%
DataAvisInsatisfactionParisMarseille[DataAvisInsatisfactionParisMarseille.rating == 1].sum
# Out:
# <bound method DataFrame.sum of                                                  text  rating
# 5   Noooooo, no no. Was really excited to try this...       1
# 22  This place succeeded in one thing with flying ...       1
# 44  I came. I sat after speaking to wait staff abo...       1
# 7   I ate here many years ago, when I lived in Par...       1
# 36  Reused bread in basket w jam on it. When told ...       1
# 58  Horrible experience.  Sat at the bar for 90 mi...       1
# 2   I have ordered the crepe Eiffel Tower which su...       1
# 10  Had lunch here two days ago. Lovely location o...       1
# 19  Went here yesterday because of the great revie...       1
# 43  Stopped by for a Matcha Croissant and it was t...       1
# 5   Rude front staff, we didn't have a reservation...       1
# 26  This is the absolute worst "Italian" restauran...       1
# 30  I was here with my 2 sisters, one of which it ...       1
# 32  Our experience was horrible. The taller man sa...       1
# ...

# %%
#  Données  DataAvisInsatisfaction
DataAvisInsatisfaction = pd.read_csv('P6_01_2_DataAvisInsatisfactionParisMarseille.csv', sep = ',', low_memory=False )
print('forme des données DataAvisInsatisfaction: ', DataAvisInsatisfaction.shape)
DataAvisInsatisfaction.head(10)
# Out:
# forme des données DataAvisInsatisfaction:  (423, 2)
#                                                 text  rating
# 0  Wanna snuggle up to someone while sharing an i...       5
# 1  Went here on a whim and it was a wise choice! ...       5
# 2  Stumbled upon Freddy's on our first night in P...       5
# 3  La Poule au Pot made our last night in Paris r...       5
# 4  Our experience was excellent. The food was ter...       4
# 5  Noooooo, no no. Was really excited to try this...       1
# 6  Stopped by for a very late dinner a few evenin...       4
# 7  *Caveat- this is a review from an American tou...       2
# 8  Le Bonaparte is fine. Nothing incredible. Food...       3
# 9  MUMI is seriously such an awesome place! And i...       5
